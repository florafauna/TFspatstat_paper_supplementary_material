# %% [markdown]
# # Train the NI model using Google Colab

# %%
import tensorflow as tf
from google.colab import drive, files
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import StandardScaler
import pickle

# %% [markdown]
# # An image/varigoram generator class
#
# *   generates new images or variograms at the end of each epoch
# *   returns images (`vgram=False`) or vgrams (`vgram=True`)

# %%
class ImageVariogramGenerator(tf.keras.utils.Sequence):
    def __init__(self, path_prefix, path_suffix='', batch_size=256, random_shuffle=True,
                 flip_transpose = True,
                 test=False, replicates=10,
                 vgrams = True,
                 scale_y=True, Scaler=StandardScaler,
                 verbose = True):
        self.Rin_chols = tf.convert_to_tensor(np.load(path_prefix + '_chols.npy' + path_suffix),
                                              dtype="float32")
        self.Rin_alphaMat = tf.convert_to_tensor(np.load(path_prefix + '_alphaMat.npy' + path_suffix),
                                                 dtype="float32")
        self.Rin_thetaGrid= tf.convert_to_tensor(np.load(path_prefix + '_thetaGrid.npy' + path_suffix),
                                                 dtype="float32")
        self.Rin_y = tf.convert_to_tensor(np.load(path_prefix + '_y.npy' + path_suffix),
                                          dtype="float32")
        ## scale y
        self.scale_y = scale_y
        self.Scaler = Scaler
        if self.scale_y:
            self.scaler_y = self.Scaler().fit(self.Rin_y)
            self.Rin_y = self.scaler_y.transform(self.Rin_y)

        self.m = replicates
        self.nObs = self.Rin_chols.shape[0]
        self.N = int(np.sqrt(self.nObs))
        self.nTheta = len(self.Rin_thetaGrid)
        self.nLambda = self.Rin_alphaMat.shape[0]
        self.nChunk = self.m * self.nLambda
        
        self.batch_size = batch_size
        self.random_shuffle = random_shuffle
        if vgrams and flip_transpose:
            self.flip_transpose = False
            tf.print("!! ignore 'flip_transpose = True' because 'vgrams = True'")
            self.vg, self.dist, self.w = None, None, None
        else:
            self.flip_transpose = flip_transpose
        self.test = test
        self.verbose = verbose

        self.vgrams = vgrams
        self.im, self.y = None, None
        
        self.on_epoch_end()

    def flip_transpose_fn(self):
        """ augment data by flipping and rotating the images"""
        if self.verbose:
          tf.print(', add 7 flips/transposes', end='')
        r1 = tf.reverse(self.im, axis=[1])
        r2 = tf.reverse(self.im, axis=[2])
        r3 = tf.reverse(self.im, axis=[1,2])
        t0 = tf.transpose(self.im, perm=[0,2,1,3])
        t1 = tf.transpose(r1, perm=[0,2,1,3])
        t2 = tf.transpose(r2, perm=[0,2,1,3])
        t3 = tf.transpose(r3, perm=[0,2,1,3])
        self.im = tf.concat([self.im, r1, r2, r3, t0, t1, t2, t3], axis=0)
        self.y = tf.tile(self.y, [8,1])
        
    def generate_im(self):
        """simulate images from training parameter configurations"""
        if self.verbose:
          tf.print('generate data', end='')
        if self.test:
            normal = random_test(shape=[self.nTheta, self.nObs, self.nChunk, 2])
        else:
            normal = tf.random.normal(shape=[self.nTheta, self.nObs, self.nChunk, 2])
            
        bigG = tf.linalg.matmul(a=tf.transpose(self.Rin_chols, [2,0,1]),
                                b=normal[:,:,:,0]) 
        bigG = tf.reshape(bigG, [self.nTheta, self.nObs, self.nLambda, self.m])
        bigG = tf.transpose(bigG, [1,3,2,0])
        # bigG.shape: nObs, m, nLambda, nTheta
        
        # Rin_alphaMat.shape: nLambda, nTheta
        alphaArray = tf.reshape(self.Rin_alphaMat, [1, 1, self.nLambda, self.nTheta])
        alphaArray = tf.tile(alphaArray, [self.nObs, self.m, 1, 1])
        
        self.im = tf.sqrt(1-alphaArray) * bigG + \
            tf.sqrt(alphaArray) * tf.reshape(normal[:,:,:,1], alphaArray.shape)
        self.im = tf.reshape(self.im, [self.nObs, self.m*self.nLambda*self.nTheta])
        self.im = tf.reshape(tf.transpose(self.im), [self.m*self.nLambda*self.nTheta, self.N, self.N])
        self.im = tf.expand_dims(self.im, 3)
        
        # Rin_y: [lambda, theta]
        self.y = tf.reshape(self.Rin_y, [self.nTheta, self.nLambda, 2, 1])
        self.y = tf.transpose(self.y, [2, 3, 1, 0])
        self.y = tf.tile(self.y, [1, self.m, 1, 1])
        self.y = tf.transpose(tf.reshape(self.y, [2, self.m*self.nLambda*self.nTheta]))

    def squared_diff(self, i, im):
        """ compute the sqared difference when shifting image. Helper function for vgram()"""
        # self.x: input data with shape NHWC
        # i: int index to go out
        dist = np.sqrt(i**2 + np.arange(0,i+1)**2)
        if i == 1:
            ix = [[i, 0], [i, -i]]
            iy = [[0, i], [i,  i]]
        else:
            ix = [[i, k] for k in range(1,i)]
            ix.insert(0, [i, 0])
            ix.append([i, -i])
            iy = [[k, i] for k in range(1,i)]
            iy.insert(0, [0, i])
            iy.append([i, i])
        diff = []
        w = np.zeros(len(dist))
        for j in range(len(dist)):
            w[j] = (im.shape[1]-ix[j][0]) * (im.shape[2]-iy[j][0]) * 2
            if j == 0:
                tmp = [tf.expand_dims(
                    tf.reduce_sum(tf.math.squared_difference(im[:, ix[j][k]:, iy[j][k]:, :],
                                                             im[:, 0:(im.shape[1]-ix[j][k]), 0:(im.shape[2]-iy[j][k]), :]),
                                  axis=[1,2]), axis=2)
                       for k in range(2)]
                tmp = tf.expand_dims(tf.reduce_sum(tf.concat(tmp, axis=2), axis=2), axis=2)
            elif j == len(dist)-1:
                tmp1 = tf.expand_dims(
                    tf.reduce_sum(tf.math.squared_difference(im[:, ix[j][0]:, iy[j][0]:, :],
                                                             im[:, 0:(im.shape[1]-ix[j][0]), 0:(im.shape[2]-iy[j][0]), :]),
                                  axis=[1,2]), axis=2)
                tmp2 = tf.expand_dims(
                    tf.reduce_sum(tf.math.squared_difference(im[:, 0:(im.shape[1]-ix[j][0]), iy[j][0]:, :],
                                                             im[:, ix[j][0]:, 0:(im.shape[2]-iy[j][0]), :]),
                                  axis=[1,2]), axis=2)
                tmp = tf.expand_dims(tf.reduce_sum(tf.concat([tmp1, tmp2], axis=2), axis=2), axis=2)
            else:
                w[j] *= 2
                tmp1 = [tf.expand_dims(
                    tf.reduce_sum(tf.math.squared_difference(im[:, ix[j][k]:, iy[j][k]:, :],
                                                             im[:, 0:(im.shape[1]-ix[j][k]), 0:(im.shape[2]-iy[j][k]), :]),
                                  axis=[1,2]), axis=2)
                        for k in range(2)]
                tmp1 = tf.expand_dims(tf.reduce_sum(tf.concat(tmp1, axis=2), axis=2), axis=2)
                tmp2 = [tf.expand_dims( # x shifted in other direction ..
                    tf.reduce_sum(tf.math.squared_difference(im[:, 0:(im.shape[1]-ix[j][k]), iy[j][k]:, :],
                                                             im[:, ix[j][k]:, 0:(im.shape[2]-iy[j][k]), :]),
                                  axis=[1,2]), axis=2)
                        for k in range(2)]
                tmp2 = tf.expand_dims(tf.reduce_sum(tf.concat(tmp2, axis=2), axis=2), axis=2)
                tmp = tf.expand_dims(tf.reduce_sum(tf.concat([tmp1, tmp2], axis=2), axis=2), axis=2)
            diff.append(tmp / w[j])
        diff = tf.concat(diff, axis=2)
        return diff, dist, w

    def vgram(self, im=None, verbose=None):
        """compute variograms from images"""
        if im is None:
            return_flag = False
            im = self.im
        else:
            return_flag = True
        if verbose is None:
            verbose = self.verbose
        if verbose:
            if not return_flag:
                tf.print(', vgrams', end='')
            else:
                tf.print('vgrams.')
        diff, dist, w = self.squared_diff(i=1, im=im)
        for i in range(2, im.shape[1]): # probably tf.map_fn would be faster
            tmp_diff, tmp_dist, tmp_w = self.squared_diff(i=i, im=im)
            diff = tf.concat([diff, tmp_diff], axis=2)
            dist = np.concatenate([dist, tmp_dist])
            w    = np.concatenate([w, tmp_w])
        # sort according to dist
        ind  = tf.argsort(dist)
        diff = tf.gather(diff, ind, axis=2)
        dist = tf.gather(dist, ind)
        w    = tf.gather(w,    ind)
        # combine results with same dist
        diff = tf.cast(diff, dtype=tf.float32)
        w = tf.cast(w, dtype=tf.float32)
        uni = tf.unique(dist)[1]
        dist = tf.math.segment_sum(dist, uni)
        tmp1 = tf.transpose(diff * tf.tile(tf.reshape(w, [1,1,len(w)]),
                                           [diff.shape[0],diff.shape[1],1]), [2,0,1])
        diff = tf.transpose(tf.math.segment_sum(tmp1, uni), [1,2,0])
        w = tf.math.segment_sum(w, uni)
        diff /= tf.tile(tf.reshape(w, [1,1,len(w)]), [diff.shape[0],diff.shape[1], 1])
                        
        vg = tf.transpose(tf.expand_dims(diff, 3), [0,2,3,1]) / 2
        if return_flag:
            return vg, dist, w
        else:
            self.vg   = vg # NWH(=1)C
            self.dist = dist
            self.w    = w
            
    def on_epoch_end(self):
      """generate new data at the end of each epoch"""
        self.generate_im()
        if self.vgrams:
            self.vgram()
            #self.im = None # free memory
        elif self.flip_transpose:
            self.flip_transpose_fn()
        if self.random_shuffle:
            if self.verbose:
                tf.print(', shuffle', end='')
            indices = tf.range(start=0, limit=tf.shape(self.y)[0], dtype=tf.int32)
            indices = tf.random.shuffle(indices)
            self.y = tf.gather(self.y, indices)
            self.im = tf.gather(self.im, indices)
            if self.vgrams:
                self.vg = tf.gather(self.vg, indices)
        if self.verbose:
              tf.print('.')
             

    def __len__(self):
        leng, rem = divmod(self.y.shape[0], self.batch_size)
        return (leng + (1 if rem > 0 else 0))

    def __getitem__(self,i):
        start = i*self.batch_size
        end = start + self.batch_size
        if self.vgrams:
            x = self.vg[start:end,:,:,:]
        else:
            x = self.im[start:end,:,:,:]
        y = self.y[start:end,:]
        return x, y

# %% [markdown]
# # Load data input for generator.
#
# *   can be generated with `makeTrainingData.R`

# %%
# !mkdir -p npy
# !wget -P npy/ https://www.dropbox.com/s/5d4ze60wg4b81ed/training_201_200_alphaMat.npy?dl=1
# !wget -P npy/ https://www.dropbox.com/s/3wp3du0u45sbxcd/training_201_200_chols.npy?dl=1
# !wget -P npy/ https://www.dropbox.com/s/0ya8ukx7vuy9fr4/training_201_200_thetaGrid.npy?dl=1
# !wget -P npy/ https://www.dropbox.com/s/7m31iqek7mhnqno/training_201_200_y.npy?dl=1
# Out:
# --2020-11-10 18:14:36--  https://www.dropbox.com/s/5d4ze60wg4b81ed/training_201_200_alphaMat.npy?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.1, 2620:100:6019:1::a27d:401
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/5d4ze60wg4b81ed/training_201_200_alphaMat.npy [following]
# --2020-11-10 18:14:36--  https://www.dropbox.com/s/dl/5d4ze60wg4b81ed/training_201_200_alphaMat.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucb58c0ea166d0823a6889d769ae.dl.dropboxusercontent.com/cd/0/get/BC9iFspxu2dUgYShwHKwucvfd4cTs7GXw3aWM1u9Fk5WPhO29qqbifMGJ88mnvfSJUkeLRQeEeu0AjIoLtjMVlKL3dwZL6i6SU-GEIZmHHTVCOm-HcFyqZN5If9ljgYO6rw/file?dl=1# [following]
# --2020-11-10 18:14:36--  https://ucb58c0ea166d0823a6889d769ae.dl.dropboxusercontent.com/cd/0/get/BC9iFspxu2dUgYShwHKwucvfd4cTs7GXw3aWM1u9Fk5WPhO29qqbifMGJ88mnvfSJUkeLRQeEeu0AjIoLtjMVlKL3dwZL6i6SU-GEIZmHHTVCOm-HcFyqZN5If9ljgYO6rw/file?dl=1
# Resolving ucb58c0ea166d0823a6889d769ae.dl.dropboxusercontent.com (ucb58c0ea166d0823a6889d769ae.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:6019:15::a27d:40f
# Connecting to ucb58c0ea166d0823a6889d769ae.dl.dropboxusercontent.com (ucb58c0ea166d0823a6889d769ae.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 321728 (314K) [application/binary]
# Saving to: ‘npy/training_201_200_alphaMat.npy?dl=1.1’
#
# training_201_200_al 100%[===================>] 314.19K  --.-KB/s    in 0.006s
#
# 2020-11-10 18:14:37 (55.1 MB/s) - ‘npy/training_201_200_alphaMat.npy?dl=1.1’ saved [321728/321728]
#
# --2020-11-10 18:14:37--  https://www.dropbox.com/s/3wp3du0u45sbxcd/training_201_200_chols.npy?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.1, 2620:100:6019:1::a27d:401
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/3wp3du0u45sbxcd/training_201_200_chols.npy [following]
# --2020-11-10 18:14:37--  https://www.dropbox.com/s/dl/3wp3du0u45sbxcd/training_201_200_chols.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc5d08090ec1e7acbd4c4ce29506.dl.dropboxusercontent.com/cd/0/get/BC_6szz82-JOj1oByqp4iJ_XbFWZeG3dpMcP3CKd-htBHNk3Fp7gxJQy6UmxRUmOGxI0biHNcPs78_ra12FGhoNLjFqyv05lIcy4ilL-Hz68WB9cLlGsBD0faOtxyqwzqYk/file?dl=1# [following]
# --2020-11-10 18:14:37--  https://uc5d08090ec1e7acbd4c4ce29506.dl.dropboxusercontent.com/cd/0/get/BC_6szz82-JOj1oByqp4iJ_XbFWZeG3dpMcP3CKd-htBHNk3Fp7gxJQy6UmxRUmOGxI0biHNcPs78_ra12FGhoNLjFqyv05lIcy4ilL-Hz68WB9cLlGsBD0faOtxyqwzqYk/file?dl=1
# Resolving uc5d08090ec1e7acbd4c4ce29506.dl.dropboxusercontent.com (uc5d08090ec1e7acbd4c4ce29506.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:601c:15::a27d:60f
# Connecting to uc5d08090ec1e7acbd4c4ce29506.dl.dropboxusercontent.com (uc5d08090ec1e7acbd4c4ce29506.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104857728 (100M) [application/binary]
# Saving to: ‘npy/training_201_200_chols.npy?dl=1.1’
#
# training_201_200_ch 100%[===================>] 100.00M   119MB/s    in 0.8s
#
# 2020-11-10 18:14:39 (119 MB/s) - ‘npy/training_201_200_chols.npy?dl=1.1’ saved [104857728/104857728]
#
# --2020-11-10 18:14:39--  https://www.dropbox.com/s/0ya8ukx7vuy9fr4/training_201_200_thetaGrid.npy?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.1, 2620:100:6019:1::a27d:401
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/0ya8ukx7vuy9fr4/training_201_200_thetaGrid.npy [following]
# --2020-11-10 18:14:39--  https://www.dropbox.com/s/dl/0ya8ukx7vuy9fr4/training_201_200_thetaGrid.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc73b650d7a67ea402006fee64e5.dl.dropboxusercontent.com/cd/0/get/BC8nBO5qWJzn5qo1al4BwuYJD47lvRl7Eg5pGvNLFnVmJdTLn51XPZzJ7ZQzXLtL4IAYpfFqYtJjg0LGxmRwGJNOO3sUh0Fy18xNuS464Bw2J6COLL31VxV6HCB0z7dAFTE/file?dl=1# [following]
# --2020-11-10 18:14:39--  https://uc73b650d7a67ea402006fee64e5.dl.dropboxusercontent.com/cd/0/get/BC8nBO5qWJzn5qo1al4BwuYJD47lvRl7Eg5pGvNLFnVmJdTLn51XPZzJ7ZQzXLtL4IAYpfFqYtJjg0LGxmRwGJNOO3sUh0Fy18xNuS464Bw2J6COLL31VxV6HCB0z7dAFTE/file?dl=1
# Resolving uc73b650d7a67ea402006fee64e5.dl.dropboxusercontent.com (uc73b650d7a67ea402006fee64e5.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:601c:15::a27d:60f
# Connecting to uc73b650d7a67ea402006fee64e5.dl.dropboxusercontent.com (uc73b650d7a67ea402006fee64e5.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1728 (1.7K) [application/binary]
# Saving to: ‘npy/training_201_200_thetaGrid.npy?dl=1.1’
#
# training_201_200_th 100%[===================>]   1.69K  --.-KB/s    in 0s
#
# 2020-11-10 18:14:40 (287 MB/s) - ‘npy/training_201_200_thetaGrid.npy?dl=1.1’ saved [1728/1728]
#
# --2020-11-10 18:14:40--  https://www.dropbox.com/s/7m31iqek7mhnqno/training_201_200_y.npy?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.1, 2620:100:6019:1::a27d:401
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/7m31iqek7mhnqno/training_201_200_y.npy [following]
# --2020-11-10 18:14:40--  https://www.dropbox.com/s/dl/7m31iqek7mhnqno/training_201_200_y.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce52b9f4ae81e69619ef7da8b5d.dl.dropboxusercontent.com/cd/0/get/BC-z9IZa2QdCFSMBwX6H7xxEKGix9di5oorWddeh_bflASh2Gub9U68KE7ZdDIdk3e7Yah-iHdjNqigIvFpGQ3_u4ze1O3FODAZ0xFqShIXl3QoIz_mVQrHmuw73dRPYHp0/file?dl=1# [following]
# --2020-11-10 18:14:40--  https://uce52b9f4ae81e69619ef7da8b5d.dl.dropboxusercontent.com/cd/0/get/BC-z9IZa2QdCFSMBwX6H7xxEKGix9di5oorWddeh_bflASh2Gub9U68KE7ZdDIdk3e7Yah-iHdjNqigIvFpGQ3_u4ze1O3FODAZ0xFqShIXl3QoIz_mVQrHmuw73dRPYHp0/file?dl=1
# Resolving uce52b9f4ae81e69619ef7da8b5d.dl.dropboxusercontent.com (uce52b9f4ae81e69619ef7da8b5d.dl.dropboxusercontent.com)... 162.125.80.15, 2620:100:6019:15::a27d:40f
# Connecting to uce52b9f4ae81e69619ef7da8b5d.dl.dropboxusercontent.com (uce52b9f4ae81e69619ef7da8b5d.dl.dropboxusercontent.com)|162.125.80.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 643328 (628K) [application/binary]
# Saving to: ‘npy/training_201_200_y.npy?dl=1.1’
#
# training_201_200_y. 100%[===================>] 628.25K   696KB/s    in 0.9s
#
# 2020-11-10 18:14:42 (696 KB/s) - ‘npy/training_201_200_y.npy?dl=1.1’ saved [643328/643328]

# %% [markdown]
# Make instance of generator...

# %%
generator = ImageVariogramGenerator(path_prefix = 'npy/training_201_200', path_suffix='?dl=1', replicates=3, vgrams=False, flip_transpose = True, random_shuffle=True)
## each epoch trains with this amount of images:
print('im.shape: ', generator.im.shape, ', y.shape', generator.y.shape)
# Out:
# generate data, add 7 flips/transposes, shuffle.
# im.shape:  (964800, 16, 16, 1) , y.shape (964800, 2)

# %% [markdown]
# # Define and train model

# %%
model1 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=128, kernel_size=10, input_shape=(16,16,1), activation='relu'),
    tf.keras.layers.Conv2D(filters=128, kernel_size=5, activation='relu'),
    tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(500, activation='relu'),
    tf.keras.layers.Dense(2),
])
model1.compile(optimizer= tf.keras.optimizers.Adam(),
               loss=tf.keras.losses.MeanAbsoluteError(),
               metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath='model_NI',
    save_weights_only=False, monitor='loss', mode='min', save_best_only=True)

# %%
# %%time
history1 = model1.fit(x=generator, epochs=1000, batch_size = 200, callbacks=[checkpoint_callback], verbose=2)
# Out:
# Epoch 1/1000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.3713 - root_mean_squared_error: 0.5128
# generate data, add 7 flips/transposes, shuffle.
# Epoch 2/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.2697 - root_mean_squared_error: 0.3967
# generate data, add 7 flips/transposes, shuffle.
# Epoch 3/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.2285 - root_mean_squared_error: 0.3476
# generate data, add 7 flips/transposes, shuffle.
# Epoch 4/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.2168 - root_mean_squared_error: 0.3333
# generate data, add 7 flips/transposes, shuffle.
# Epoch 5/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.2084 - root_mean_squared_error: 0.3225
# generate data, add 7 flips/transposes, shuffle.
# Epoch 6/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.2062 - root_mean_squared_error: 0.3210
# generate data, add 7 flips/transposes, shuffle.
# Epoch 7/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.2016 - root_mean_squared_error: 0.3145
# generate data, add 7 flips/transposes, shuffle.
# Epoch 8/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1979 - root_mean_squared_error: 0.3102
# generate data, add 7 flips/transposes, shuffle.
# Epoch 9/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1965 - root_mean_squared_error: 0.3089
# generate data, add 7 flips/transposes, shuffle.
# Epoch 10/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1948 - root_mean_squared_error: 0.3069
# generate data, add 7 flips/transposes, shuffle.
# Epoch 11/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1920 - root_mean_squared_error: 0.3031
# generate data, add 7 flips/transposes, shuffle.
# Epoch 12/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1905 - root_mean_squared_error: 0.3022
# generate data, add 7 flips/transposes, shuffle.
# Epoch 13/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1890 - root_mean_squared_error: 0.3004
# generate data, add 7 flips/transposes, shuffle.
# Epoch 14/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1872 - root_mean_squared_error: 0.2978
# generate data, add 7 flips/transposes, shuffle.
# Epoch 15/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1868 - root_mean_squared_error: 0.2972
# generate data, add 7 flips/transposes, shuffle.
# Epoch 16/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1855 - root_mean_squared_error: 0.2961
# generate data, add 7 flips/transposes, shuffle.
# Epoch 17/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1843 - root_mean_squared_error: 0.2942
# generate data, add 7 flips/transposes, shuffle.
# Epoch 18/1000
# 3769/3769 - 22s - loss: 0.1849 - root_mean_squared_error: 0.2960
# generate data, add 7 flips/transposes, shuffle.
# Epoch 19/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1829 - root_mean_squared_error: 0.2929
# generate data, add 7 flips/transposes, shuffle.
# Epoch 20/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1811 - root_mean_squared_error: 0.2904
# generate data, add 7 flips/transposes, shuffle.
# Epoch 21/1000
# 3769/3769 - 22s - loss: 0.1817 - root_mean_squared_error: 0.2918
# generate data, add 7 flips/transposes, shuffle.
# Epoch 22/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1794 - root_mean_squared_error: 0.2886
# generate data, add 7 flips/transposes, shuffle.
# Epoch 23/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1782 - root_mean_squared_error: 0.2878
# generate data, add 7 flips/transposes, shuffle.
# Epoch 24/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1774 - root_mean_squared_error: 0.2871
# generate data, add 7 flips/transposes, shuffle.
# Epoch 25/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1773 - root_mean_squared_error: 0.2873
# generate data, add 7 flips/transposes, shuffle.
# Epoch 26/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1757 - root_mean_squared_error: 0.2857
# generate data, add 7 flips/transposes, shuffle.
# Epoch 27/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1748 - root_mean_squared_error: 0.2841
# generate data, add 7 flips/transposes, shuffle.
# Epoch 28/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1747 - root_mean_squared_error: 0.2842
# generate data, add 7 flips/transposes, shuffle.
# Epoch 29/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1741 - root_mean_squared_error: 0.2832
# generate data, add 7 flips/transposes, shuffle.
# Epoch 30/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1736 - root_mean_squared_error: 0.2831
# generate data, add 7 flips/transposes, shuffle.
# Epoch 31/1000
# 3769/3769 - 22s - loss: 0.1747 - root_mean_squared_error: 0.2842
# generate data, add 7 flips/transposes, shuffle.
# Epoch 32/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1723 - root_mean_squared_error: 0.2817
# generate data, add 7 flips/transposes, shuffle.
# Epoch 33/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1722 - root_mean_squared_error: 0.2812
# generate data, add 7 flips/transposes, shuffle.
# Epoch 34/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1709 - root_mean_squared_error: 0.2798
# generate data, add 7 flips/transposes, shuffle.
# Epoch 35/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1706 - root_mean_squared_error: 0.2797
# generate data, add 7 flips/transposes, shuffle.
# Epoch 36/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1703 - root_mean_squared_error: 0.2792
# generate data, add 7 flips/transposes, shuffle.
# Epoch 37/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1696 - root_mean_squared_error: 0.2778
# generate data, add 7 flips/transposes, shuffle.
# Epoch 38/1000
# 3769/3769 - 22s - loss: 0.1696 - root_mean_squared_error: 0.2785
# generate data, add 7 flips/transposes, shuffle.
# Epoch 39/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1694 - root_mean_squared_error: 0.2780
# generate data, add 7 flips/transposes, shuffle.
# Epoch 40/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1690 - root_mean_squared_error: 0.2774
# generate data, add 7 flips/transposes, shuffle.
# Epoch 41/1000
# 3769/3769 - 22s - loss: 0.1690 - root_mean_squared_error: 0.2780
# generate data, add 7 flips/transposes, shuffle.
# Epoch 42/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1685 - root_mean_squared_error: 0.2768
# generate data, add 7 flips/transposes, shuffle.
# Epoch 43/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1679 - root_mean_squared_error: 0.2758
# generate data, add 7 flips/transposes, shuffle.
# Epoch 44/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1677 - root_mean_squared_error: 0.2763
# generate data, add 7 flips/transposes, shuffle.
# Epoch 45/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1676 - root_mean_squared_error: 0.2759
# generate data, add 7 flips/transposes, shuffle.
# Epoch 46/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1669 - root_mean_squared_error: 0.2753
# generate data, add 7 flips/transposes, shuffle.
# Epoch 47/1000
# 3769/3769 - 22s - loss: 0.1670 - root_mean_squared_error: 0.2753
# generate data, add 7 flips/transposes, shuffle.
# Epoch 48/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1664 - root_mean_squared_error: 0.2737
# generate data, add 7 flips/transposes, shuffle.
# Epoch 49/1000
# 3769/3769 - 22s - loss: 0.1664 - root_mean_squared_error: 0.2741
# generate data, add 7 flips/transposes, shuffle.
# Epoch 50/1000
# 3769/3769 - 22s - loss: 0.1671 - root_mean_squared_error: 0.2748
# generate data, add 7 flips/transposes, shuffle.
# Epoch 51/1000
# 3769/3769 - 22s - loss: 0.1669 - root_mean_squared_error: 0.2752
# generate data, add 7 flips/transposes, shuffle.
# Epoch 52/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1660 - root_mean_squared_error: 0.2740
# generate data, add 7 flips/transposes, shuffle.
# Epoch 53/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1653 - root_mean_squared_error: 0.2728
# generate data, add 7 flips/transposes, shuffle.
# Epoch 54/1000
# 3769/3769 - 22s - loss: 0.1658 - root_mean_squared_error: 0.2738
# generate data, add 7 flips/transposes, shuffle.
# Epoch 55/1000
# 3769/3769 - 22s - loss: 0.1655 - root_mean_squared_error: 0.2738
# generate data, add 7 flips/transposes, shuffle.
# Epoch 56/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1653 - root_mean_squared_error: 0.2730
# generate data, add 7 flips/transposes, shuffle.
# Epoch 57/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1651 - root_mean_squared_error: 0.2735
# generate data, add 7 flips/transposes, shuffle.
# Epoch 58/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1647 - root_mean_squared_error: 0.2722
# generate data, add 7 flips/transposes, shuffle.
# Epoch 59/1000
# 3769/3769 - 22s - loss: 0.1651 - root_mean_squared_error: 0.2729
# generate data, add 7 flips/transposes, shuffle.
# Epoch 60/1000
# 3769/3769 - 22s - loss: 0.1649 - root_mean_squared_error: 0.2727
# generate data, add 7 flips/transposes, shuffle.
# Epoch 61/1000
# 3769/3769 - 22s - loss: 0.1649 - root_mean_squared_error: 0.2725
# generate data, add 7 flips/transposes, shuffle.
# Epoch 62/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1643 - root_mean_squared_error: 0.2718
# generate data, add 7 flips/transposes, shuffle.
# Epoch 63/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1643 - root_mean_squared_error: 0.2724
# generate data, add 7 flips/transposes, shuffle.
# Epoch 64/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1641 - root_mean_squared_error: 0.2714
# generate data, add 7 flips/transposes, shuffle.
# Epoch 65/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1633 - root_mean_squared_error: 0.2714
# generate data, add 7 flips/transposes, shuffle.
# Epoch 66/1000
# 3769/3769 - 22s - loss: 0.1637 - root_mean_squared_error: 0.2710
# generate data, add 7 flips/transposes, shuffle.
# Epoch 67/1000
# 3769/3769 - 22s - loss: 0.1637 - root_mean_squared_error: 0.2715
# generate data, add 7 flips/transposes, shuffle.
# Epoch 68/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1631 - root_mean_squared_error: 0.2704
# generate data, add 7 flips/transposes, shuffle.
# Epoch 69/1000
# 3769/3769 - 22s - loss: 0.1638 - root_mean_squared_error: 0.2717
# generate data, add 7 flips/transposes, shuffle.
# Epoch 70/1000
# 3769/3769 - 22s - loss: 0.1635 - root_mean_squared_error: 0.2711
# generate data, add 7 flips/transposes, shuffle.
# Epoch 71/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1625 - root_mean_squared_error: 0.2697
# generate data, add 7 flips/transposes, shuffle.
# Epoch 72/1000
# 3769/3769 - 22s - loss: 0.1626 - root_mean_squared_error: 0.2700
# generate data, add 7 flips/transposes, shuffle.
# Epoch 73/1000
# 3769/3769 - 22s - loss: 0.1630 - root_mean_squared_error: 0.2713
# generate data, add 7 flips/transposes, shuffle.
# Epoch 74/1000
# 3769/3769 - 22s - loss: 0.1626 - root_mean_squared_error: 0.2708
# generate data, add 7 flips/transposes, shuffle.
# Epoch 75/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1624 - root_mean_squared_error: 0.2704
# generate data, add 7 flips/transposes, shuffle.
# Epoch 76/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1621 - root_mean_squared_error: 0.2699
# generate data, add 7 flips/transposes, shuffle.
# Epoch 77/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1613 - root_mean_squared_error: 0.2689
# generate data, add 7 flips/transposes, shuffle.
# Epoch 78/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1604 - root_mean_squared_error: 0.2685
# generate data, add 7 flips/transposes, shuffle.
# Epoch 79/1000
# 3769/3769 - 22s - loss: 0.1605 - root_mean_squared_error: 0.2682
# generate data, add 7 flips/transposes, shuffle.
# Epoch 80/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1603 - root_mean_squared_error: 0.2683
# generate data, add 7 flips/transposes, shuffle.
# Epoch 81/1000
# 3769/3769 - 22s - loss: 0.1606 - root_mean_squared_error: 0.2688
# generate data, add 7 flips/transposes, shuffle.
# Epoch 82/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1595 - root_mean_squared_error: 0.2668
# generate data, add 7 flips/transposes, shuffle.
# Epoch 83/1000
# 3769/3769 - 22s - loss: 0.1602 - root_mean_squared_error: 0.2681
# generate data, add 7 flips/transposes, shuffle.
# Epoch 84/1000
# 3769/3769 - 22s - loss: 0.1599 - root_mean_squared_error: 0.2679
# generate data, add 7 flips/transposes, shuffle.
# Epoch 85/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1593 - root_mean_squared_error: 0.2670
# generate data, add 7 flips/transposes, shuffle.
# Epoch 86/1000
# 3769/3769 - 22s - loss: 0.1597 - root_mean_squared_error: 0.2669
# generate data, add 7 flips/transposes, shuffle.
# Epoch 87/1000
# 3769/3769 - 22s - loss: 0.1594 - root_mean_squared_error: 0.2663
# generate data, add 7 flips/transposes, shuffle.
# Epoch 88/1000
# 3769/3769 - 22s - loss: 0.1593 - root_mean_squared_error: 0.2670
# generate data, add 7 flips/transposes, shuffle.
# Epoch 89/1000
# 3769/3769 - 22s - loss: 0.1597 - root_mean_squared_error: 0.2671
# generate data, add 7 flips/transposes, shuffle.
# Epoch 90/1000
# 3769/3769 - 22s - loss: 0.1598 - root_mean_squared_error: 0.2672
# generate data, add 7 flips/transposes, shuffle.
# Epoch 91/1000
# 3769/3769 - 22s - loss: 0.1598 - root_mean_squared_error: 0.2675
# generate data, add 7 flips/transposes, shuffle.
# Epoch 92/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1589 - root_mean_squared_error: 0.2664
# generate data, add 7 flips/transposes, shuffle.
# Epoch 93/1000
# 3769/3769 - 22s - loss: 0.1590 - root_mean_squared_error: 0.2672
# generate data, add 7 flips/transposes, shuffle.
# Epoch 94/1000
# 3769/3769 - 22s - loss: 0.1589 - root_mean_squared_error: 0.2661
# generate data, add 7 flips/transposes, shuffle.
# Epoch 95/1000
# 3769/3769 - 22s - loss: 0.1591 - root_mean_squared_error: 0.2667
# generate data, add 7 flips/transposes, shuffle.
# Epoch 96/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1588 - root_mean_squared_error: 0.2664
# generate data, add 7 flips/transposes, shuffle.
# Epoch 97/1000
# 3769/3769 - 22s - loss: 0.1590 - root_mean_squared_error: 0.2668
# generate data, add 7 flips/transposes, shuffle.
# Epoch 98/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1585 - root_mean_squared_error: 0.2661
# generate data, add 7 flips/transposes, shuffle.
# Epoch 99/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1581 - root_mean_squared_error: 0.2647
# generate data, add 7 flips/transposes, shuffle.
# Epoch 100/1000
# 3769/3769 - 22s - loss: 0.1582 - root_mean_squared_error: 0.2657
# generate data, add 7 flips/transposes, shuffle.
# Epoch 101/1000
# 3769/3769 - 22s - loss: 0.1582 - root_mean_squared_error: 0.2664
# generate data, add 7 flips/transposes, shuffle.
# Epoch 102/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1579 - root_mean_squared_error: 0.2650
# generate data, add 7 flips/transposes, shuffle.
# Epoch 103/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1576 - root_mean_squared_error: 0.2642
# generate data, add 7 flips/transposes, shuffle.
# Epoch 104/1000
# 3769/3769 - 22s - loss: 0.1583 - root_mean_squared_error: 0.2657
# generate data, add 7 flips/transposes, shuffle.
# Epoch 105/1000
# 3769/3769 - 22s - loss: 0.1583 - root_mean_squared_error: 0.2657
# generate data, add 7 flips/transposes, shuffle.
# Epoch 106/1000
# 3769/3769 - 22s - loss: 0.1582 - root_mean_squared_error: 0.2662
# generate data, add 7 flips/transposes, shuffle.
# Epoch 107/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1575 - root_mean_squared_error: 0.2648
# generate data, add 7 flips/transposes, shuffle.
# Epoch 108/1000
# 3769/3769 - 22s - loss: 0.1587 - root_mean_squared_error: 0.2664
# generate data, add 7 flips/transposes, shuffle.
# Epoch 109/1000
# 3769/3769 - 22s - loss: 0.1583 - root_mean_squared_error: 0.2658
# generate data, add 7 flips/transposes, shuffle.
# Epoch 110/1000
# 3769/3769 - 22s - loss: 0.1584 - root_mean_squared_error: 0.2660
# generate data, add 7 flips/transposes, shuffle.
# Epoch 111/1000
# 3769/3769 - 22s - loss: 0.1583 - root_mean_squared_error: 0.2658
# generate data, add 7 flips/transposes, shuffle.
# Epoch 112/1000
# 3769/3769 - 22s - loss: 0.1586 - root_mean_squared_error: 0.2665
# generate data, add 7 flips/transposes, shuffle.
# Epoch 113/1000
# 3769/3769 - 22s - loss: 0.1577 - root_mean_squared_error: 0.2650
# generate data, add 7 flips/transposes, shuffle.
# Epoch 114/1000
# 3769/3769 - 22s - loss: 0.1579 - root_mean_squared_error: 0.2653
# generate data, add 7 flips/transposes, shuffle.
# Epoch 115/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1570 - root_mean_squared_error: 0.2645
# generate data, add 7 flips/transposes, shuffle.
# Epoch 116/1000
# 3769/3769 - 22s - loss: 0.1580 - root_mean_squared_error: 0.2667
# generate data, add 7 flips/transposes, shuffle.
# Epoch 117/1000
# 3769/3769 - 22s - loss: 0.1575 - root_mean_squared_error: 0.2648
# generate data, add 7 flips/transposes, shuffle.
# Epoch 118/1000
# 3769/3769 - 22s - loss: 0.1570 - root_mean_squared_error: 0.2646
# generate data, add 7 flips/transposes, shuffle.
# Epoch 119/1000
# 3769/3769 - 22s - loss: 0.1576 - root_mean_squared_error: 0.2648
# generate data, add 7 flips/transposes, shuffle.
# Epoch 120/1000
# 3769/3769 - 22s - loss: 0.1576 - root_mean_squared_error: 0.2649
# generate data, add 7 flips/transposes, shuffle.
# Epoch 121/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1566 - root_mean_squared_error: 0.2639
# generate data, add 7 flips/transposes, shuffle.
# Epoch 122/1000
# 3769/3769 - 22s - loss: 0.1581 - root_mean_squared_error: 0.2656
# generate data, add 7 flips/transposes, shuffle.
# Epoch 123/1000
# 3769/3769 - 22s - loss: 0.1571 - root_mean_squared_error: 0.2638
# generate data, add 7 flips/transposes, shuffle.
# Epoch 124/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1565 - root_mean_squared_error: 0.2632
# generate data, add 7 flips/transposes, shuffle.
# Epoch 125/1000
# 3769/3769 - 22s - loss: 0.1567 - root_mean_squared_error: 0.2634
# generate data, add 7 flips/transposes, shuffle.
# Epoch 126/1000
# 3769/3769 - 22s - loss: 0.1568 - root_mean_squared_error: 0.2643
# generate data, add 7 flips/transposes, shuffle.
# Epoch 127/1000
# 3769/3769 - 22s - loss: 0.1565 - root_mean_squared_error: 0.2636
# generate data, add 7 flips/transposes, shuffle.
# Epoch 128/1000
# 3769/3769 - 22s - loss: 0.1569 - root_mean_squared_error: 0.2642
# generate data, add 7 flips/transposes, shuffle.
# Epoch 129/1000
# 3769/3769 - 22s - loss: 0.1567 - root_mean_squared_error: 0.2649
# generate data, add 7 flips/transposes, shuffle.
# Epoch 130/1000
# 3769/3769 - 22s - loss: 0.1568 - root_mean_squared_error: 0.2635
# generate data, add 7 flips/transposes, shuffle.
# Epoch 131/1000
# 3769/3769 - 22s - loss: 0.1574 - root_mean_squared_error: 0.2651
# generate data, add 7 flips/transposes, shuffle.
# Epoch 132/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1563 - root_mean_squared_error: 0.2628
# generate data, add 7 flips/transposes, shuffle.
# Epoch 133/1000
# 3769/3769 - 22s - loss: 0.1567 - root_mean_squared_error: 0.2639
# generate data, add 7 flips/transposes, shuffle.
# Epoch 134/1000
# 3769/3769 - 22s - loss: 0.1567 - root_mean_squared_error: 0.2636
# generate data, add 7 flips/transposes, shuffle.
# Epoch 135/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1561 - root_mean_squared_error: 0.2628
# generate data, add 7 flips/transposes, shuffle.
# Epoch 136/1000
# 3769/3769 - 22s - loss: 0.1566 - root_mean_squared_error: 0.2644
# generate data, add 7 flips/transposes, shuffle.
# Epoch 137/1000
# 3769/3769 - 22s - loss: 0.1564 - root_mean_squared_error: 0.2636
# generate data, add 7 flips/transposes, shuffle.
# Epoch 138/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1560 - root_mean_squared_error: 0.2631
# generate data, add 7 flips/transposes, shuffle.
# Epoch 139/1000
# 3769/3769 - 22s - loss: 0.1565 - root_mean_squared_error: 0.2633
# generate data, add 7 flips/transposes, shuffle.
# Epoch 140/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1556 - root_mean_squared_error: 0.2628
# generate data, add 7 flips/transposes, shuffle.
# Epoch 141/1000
# 3769/3769 - 22s - loss: 0.1562 - root_mean_squared_error: 0.2629
# generate data, add 7 flips/transposes, shuffle.
# Epoch 142/1000
# 3769/3769 - 22s - loss: 0.1562 - root_mean_squared_error: 0.2634
# generate data, add 7 flips/transposes, shuffle.
# Epoch 143/1000
# 3769/3769 - 22s - loss: 0.1560 - root_mean_squared_error: 0.2633
# generate data, add 7 flips/transposes, shuffle.
# Epoch 144/1000
# 3769/3769 - 22s - loss: 0.1559 - root_mean_squared_error: 0.2629
# generate data, add 7 flips/transposes, shuffle.
# Epoch 145/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1550 - root_mean_squared_error: 0.2616
# generate data, add 7 flips/transposes, shuffle.
# Epoch 146/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1550 - root_mean_squared_error: 0.2618
# generate data, add 7 flips/transposes, shuffle.
# Epoch 147/1000
# 3769/3769 - 22s - loss: 0.1560 - root_mean_squared_error: 0.2636
# generate data, add 7 flips/transposes, shuffle.
# Epoch 148/1000
# 3769/3769 - 22s - loss: 0.1556 - root_mean_squared_error: 0.2624
# generate data, add 7 flips/transposes, shuffle.
# Epoch 149/1000
# 3769/3769 - 22s - loss: 0.1558 - root_mean_squared_error: 0.2626
# generate data, add 7 flips/transposes, shuffle.
# Epoch 150/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1550 - root_mean_squared_error: 0.2618
# generate data, add 7 flips/transposes, shuffle.
# Epoch 151/1000
# 3769/3769 - 22s - loss: 0.1555 - root_mean_squared_error: 0.2633
# generate data, add 7 flips/transposes, shuffle.
# Epoch 152/1000
# 3769/3769 - 22s - loss: 0.1552 - root_mean_squared_error: 0.2630
# generate data, add 7 flips/transposes, shuffle.
# Epoch 153/1000
# 3769/3769 - 22s - loss: 0.1550 - root_mean_squared_error: 0.2615
# generate data, add 7 flips/transposes, shuffle.
# Epoch 154/1000
# 3769/3769 - 22s - loss: 0.1553 - root_mean_squared_error: 0.2624
# generate data, add 7 flips/transposes, shuffle.
# Epoch 155/1000
# 3769/3769 - 22s - loss: 0.1551 - root_mean_squared_error: 0.2618
# generate data, add 7 flips/transposes, shuffle.
# Epoch 156/1000
# 3769/3769 - 22s - loss: 0.1553 - root_mean_squared_error: 0.2631
# generate data, add 7 flips/transposes, shuffle.
# Epoch 157/1000
# 3769/3769 - 22s - loss: 0.1550 - root_mean_squared_error: 0.2620
# generate data, add 7 flips/transposes, shuffle.
# Epoch 158/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1549 - root_mean_squared_error: 0.2621
# generate data, add 7 flips/transposes, shuffle.
# Epoch 159/1000
# 3769/3769 - 22s - loss: 0.1553 - root_mean_squared_error: 0.2627
# generate data, add 7 flips/transposes, shuffle.
# Epoch 160/1000
# 3769/3769 - 22s - loss: 0.1551 - root_mean_squared_error: 0.2618
# generate data, add 7 flips/transposes, shuffle.
# Epoch 161/1000
# 3769/3769 - 22s - loss: 0.1552 - root_mean_squared_error: 0.2620
# generate data, add 7 flips/transposes, shuffle.
# Epoch 162/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1548 - root_mean_squared_error: 0.2619
# generate data, add 7 flips/transposes, shuffle.
# Epoch 163/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1544 - root_mean_squared_error: 0.2612
# generate data, add 7 flips/transposes, shuffle.
# Epoch 164/1000
# 3769/3769 - 22s - loss: 0.1551 - root_mean_squared_error: 0.2621
# generate data, add 7 flips/transposes, shuffle.
# Epoch 165/1000
# 3769/3769 - 22s - loss: 0.1553 - root_mean_squared_error: 0.2627
# generate data, add 7 flips/transposes, shuffle.
# Epoch 166/1000
# 3769/3769 - 22s - loss: 0.1548 - root_mean_squared_error: 0.2621
# generate data, add 7 flips/transposes, shuffle.
# Epoch 167/1000
# 3769/3769 - 22s - loss: 0.1545 - root_mean_squared_error: 0.2615
# generate data, add 7 flips/transposes, shuffle.
# Epoch 168/1000
# 3769/3769 - 22s - loss: 0.1544 - root_mean_squared_error: 0.2618
# generate data, add 7 flips/transposes, shuffle.
# Epoch 169/1000
# 3769/3769 - 22s - loss: 0.1546 - root_mean_squared_error: 0.2616
# generate data, add 7 flips/transposes, shuffle.
# Epoch 170/1000
# 3769/3769 - 22s - loss: 0.1545 - root_mean_squared_error: 0.2613
# generate data, add 7 flips/transposes, shuffle.
# Epoch 171/1000
# 3769/3769 - 22s - loss: 0.1545 - root_mean_squared_error: 0.2616
# generate data, add 7 flips/transposes, shuffle.
# Epoch 172/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1544 - root_mean_squared_error: 0.2618
# generate data, add 7 flips/transposes, shuffle.
# Epoch 173/1000
# 3769/3769 - 22s - loss: 0.1545 - root_mean_squared_error: 0.2620
# generate data, add 7 flips/transposes, shuffle.
# Epoch 174/1000
# 3769/3769 - 22s - loss: 0.1547 - root_mean_squared_error: 0.2619
# generate data, add 7 flips/transposes, shuffle.
# Epoch 175/1000
# 3769/3769 - 22s - loss: 0.1546 - root_mean_squared_error: 0.2620
# generate data, add 7 flips/transposes, shuffle.
# Epoch 176/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1542 - root_mean_squared_error: 0.2613
# generate data, add 7 flips/transposes, shuffle.
# Epoch 177/1000
# 3769/3769 - 22s - loss: 0.1544 - root_mean_squared_error: 0.2615
# generate data, add 7 flips/transposes, shuffle.
# Epoch 178/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1542 - root_mean_squared_error: 0.2613
# generate data, add 7 flips/transposes, shuffle.
# Epoch 179/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1541 - root_mean_squared_error: 0.2609
# generate data, add 7 flips/transposes, shuffle.
# Epoch 180/1000
# 3769/3769 - 22s - loss: 0.1543 - root_mean_squared_error: 0.2609
# generate data, add 7 flips/transposes, shuffle.
# Epoch 181/1000
# 3769/3769 - 22s - loss: 0.1545 - root_mean_squared_error: 0.2610
# generate data, add 7 flips/transposes, shuffle.
# Epoch 182/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1539 - root_mean_squared_error: 0.2607
# generate data, add 7 flips/transposes, shuffle.
# Epoch 183/1000
# 3769/3769 - 22s - loss: 0.1540 - root_mean_squared_error: 0.2609
# generate data, add 7 flips/transposes, shuffle.
# Epoch 184/1000
# 3769/3769 - 22s - loss: 0.1543 - root_mean_squared_error: 0.2613
# generate data, add 7 flips/transposes, shuffle.
# Epoch 185/1000
# 3769/3769 - 22s - loss: 0.1545 - root_mean_squared_error: 0.2624
# generate data, add 7 flips/transposes, shuffle.
# Epoch 186/1000
# 3769/3769 - 22s - loss: 0.1541 - root_mean_squared_error: 0.2614
# generate data, add 7 flips/transposes, shuffle.
# Epoch 187/1000
# 3769/3769 - 22s - loss: 0.1542 - root_mean_squared_error: 0.2616
# generate data, add 7 flips/transposes, shuffle.
# Epoch 188/1000
# 3769/3769 - 22s - loss: 0.1543 - root_mean_squared_error: 0.2609
# generate data, add 7 flips/transposes, shuffle.
# Epoch 189/1000
# 3769/3769 - 22s - loss: 0.1545 - root_mean_squared_error: 0.2616
# generate data, add 7 flips/transposes, shuffle.
# Epoch 190/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1539 - root_mean_squared_error: 0.2602
# generate data, add 7 flips/transposes, shuffle.
# Epoch 191/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1535 - root_mean_squared_error: 0.2611
# generate data, add 7 flips/transposes, shuffle.
# Epoch 192/1000
# 3769/3769 - 22s - loss: 0.1541 - root_mean_squared_error: 0.2609
# generate data, add 7 flips/transposes, shuffle.
# Epoch 193/1000
# 3769/3769 - 22s - loss: 0.1540 - root_mean_squared_error: 0.2603
# generate data, add 7 flips/transposes, shuffle.
# Epoch 194/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1534 - root_mean_squared_error: 0.2595
# generate data, add 7 flips/transposes, shuffle.
# Epoch 195/1000
# 3769/3769 - 22s - loss: 0.1536 - root_mean_squared_error: 0.2603
# generate data, add 7 flips/transposes, shuffle.
# Epoch 196/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1533 - root_mean_squared_error: 0.2595
# generate data, add 7 flips/transposes, shuffle.
# Epoch 197/1000
# 3769/3769 - 22s - loss: 0.1539 - root_mean_squared_error: 0.2604
# generate data, add 7 flips/transposes, shuffle.
# Epoch 198/1000
# 3769/3769 - 22s - loss: 0.1540 - root_mean_squared_error: 0.2615
# generate data, add 7 flips/transposes, shuffle.
# Epoch 199/1000
# 3769/3769 - 22s - loss: 0.1536 - root_mean_squared_error: 0.2610
# generate data, add 7 flips/transposes, shuffle.
# Epoch 200/1000
# 3769/3769 - 22s - loss: 0.1541 - root_mean_squared_error: 0.2612
# generate data, add 7 flips/transposes, shuffle.
# Epoch 201/1000
# 3769/3769 - 22s - loss: 0.1533 - root_mean_squared_error: 0.2600
# generate data, add 7 flips/transposes, shuffle.
# Epoch 202/1000
# 3769/3769 - 22s - loss: 0.1545 - root_mean_squared_error: 0.2617
# generate data, add 7 flips/transposes, shuffle.
# Epoch 203/1000
# 3769/3769 - 22s - loss: 0.1537 - root_mean_squared_error: 0.2601
# generate data, add 7 flips/transposes, shuffle.
# Epoch 204/1000
# 3769/3769 - 22s - loss: 0.1535 - root_mean_squared_error: 0.2604
# generate data, add 7 flips/transposes, shuffle.
# Epoch 205/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1529 - root_mean_squared_error: 0.2596
# generate data, add 7 flips/transposes, shuffle.
# Epoch 206/1000
# 3769/3769 - 22s - loss: 0.1537 - root_mean_squared_error: 0.2602
# generate data, add 7 flips/transposes, shuffle.
# Epoch 207/1000
# 3769/3769 - 22s - loss: 0.1535 - root_mean_squared_error: 0.2601
# generate data, add 7 flips/transposes, shuffle.
# Epoch 208/1000
# 3769/3769 - 22s - loss: 0.1534 - root_mean_squared_error: 0.2601
# generate data, add 7 flips/transposes, shuffle.
# Epoch 209/1000
# 3769/3769 - 22s - loss: 0.1533 - root_mean_squared_error: 0.2603
# generate data, add 7 flips/transposes, shuffle.
# Epoch 210/1000
# 3769/3769 - 22s - loss: 0.1534 - root_mean_squared_error: 0.2604
# generate data, add 7 flips/transposes, shuffle.
# Epoch 211/1000
# 3769/3769 - 22s - loss: 0.1534 - root_mean_squared_error: 0.2603
# generate data, add 7 flips/transposes, shuffle.
# Epoch 212/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1529 - root_mean_squared_error: 0.2596
# generate data, add 7 flips/transposes, shuffle.
# Epoch 213/1000
# 3769/3769 - 22s - loss: 0.1534 - root_mean_squared_error: 0.2605
# generate data, add 7 flips/transposes, shuffle.
# Epoch 214/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1529 - root_mean_squared_error: 0.2600
# generate data, add 7 flips/transposes, shuffle.
# Epoch 215/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1528 - root_mean_squared_error: 0.2600
# generate data, add 7 flips/transposes, shuffle.
# Epoch 216/1000
# 3769/3769 - 22s - loss: 0.1533 - root_mean_squared_error: 0.2607
# generate data, add 7 flips/transposes, shuffle.
# Epoch 217/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1525 - root_mean_squared_error: 0.2592
# generate data, add 7 flips/transposes, shuffle.
# Epoch 218/1000
# 3769/3769 - 22s - loss: 0.1526 - root_mean_squared_error: 0.2595
# generate data, add 7 flips/transposes, shuffle.
# Epoch 219/1000
# 3769/3769 - 22s - loss: 0.1528 - root_mean_squared_error: 0.2596
# generate data, add 7 flips/transposes, shuffle.
# Epoch 220/1000
# 3769/3769 - 22s - loss: 0.1526 - root_mean_squared_error: 0.2592
# generate data, add 7 flips/transposes, shuffle.
# Epoch 221/1000
# 3769/3769 - 22s - loss: 0.1528 - root_mean_squared_error: 0.2598
# generate data, add 7 flips/transposes, shuffle.
# Epoch 222/1000
# 3769/3769 - 22s - loss: 0.1528 - root_mean_squared_error: 0.2594
# generate data, add 7 flips/transposes, shuffle.
# Epoch 223/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1521 - root_mean_squared_error: 0.2581
# generate data, add 7 flips/transposes, shuffle.
# Epoch 224/1000
# 3769/3769 - 22s - loss: 0.1529 - root_mean_squared_error: 0.2595
# generate data, add 7 flips/transposes, shuffle.
# Epoch 225/1000
# 3769/3769 - 22s - loss: 0.1526 - root_mean_squared_error: 0.2599
# generate data, add 7 flips/transposes, shuffle.
# Epoch 226/1000
# 3769/3769 - 22s - loss: 0.1530 - root_mean_squared_error: 0.2604
# generate data, add 7 flips/transposes, shuffle.
# Epoch 227/1000
# 3769/3769 - 22s - loss: 0.1526 - root_mean_squared_error: 0.2594
# generate data, add 7 flips/transposes, shuffle.
# Epoch 228/1000
# 3769/3769 - 22s - loss: 0.1528 - root_mean_squared_error: 0.2588
# generate data, add 7 flips/transposes, shuffle.
# Epoch 229/1000
# 3769/3769 - 22s - loss: 0.1524 - root_mean_squared_error: 0.2595
# generate data, add 7 flips/transposes, shuffle.
# Epoch 230/1000
# 3769/3769 - 22s - loss: 0.1531 - root_mean_squared_error: 0.2599
# generate data, add 7 flips/transposes, shuffle.
# Epoch 231/1000
# 3769/3769 - 22s - loss: 0.1533 - root_mean_squared_error: 0.2607
# generate data, add 7 flips/transposes, shuffle.
# Epoch 232/1000
# 3769/3769 - 22s - loss: 0.1529 - root_mean_squared_error: 0.2603
# generate data, add 7 flips/transposes, shuffle.
# Epoch 233/1000
# 3769/3769 - 22s - loss: 0.1528 - root_mean_squared_error: 0.2592
# generate data, add 7 flips/transposes, shuffle.
# Epoch 234/1000
# 3769/3769 - 22s - loss: 0.1531 - root_mean_squared_error: 0.2603
# generate data, add 7 flips/transposes, shuffle.
# Epoch 235/1000
# 3769/3769 - 22s - loss: 0.1527 - root_mean_squared_error: 0.2597
# generate data, add 7 flips/transposes, shuffle.
# Epoch 236/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1520 - root_mean_squared_error: 0.2581
# generate data, add 7 flips/transposes, shuffle.
# Epoch 237/1000
# 3769/3769 - 22s - loss: 0.1523 - root_mean_squared_error: 0.2589
# generate data, add 7 flips/transposes, shuffle.
# Epoch 238/1000
# 3769/3769 - 22s - loss: 0.1524 - root_mean_squared_error: 0.2595
# generate data, add 7 flips/transposes, shuffle.
# Epoch 239/1000
# 3769/3769 - 22s - loss: 0.1522 - root_mean_squared_error: 0.2590
# generate data, add 7 flips/transposes, shuffle.
# Epoch 240/1000
# 3769/3769 - 22s - loss: 0.1520 - root_mean_squared_error: 0.2589
# generate data, add 7 flips/transposes, shuffle.
# Epoch 241/1000
# 3769/3769 - 22s - loss: 0.1524 - root_mean_squared_error: 0.2595
# generate data, add 7 flips/transposes, shuffle.
# Epoch 242/1000
# 3769/3769 - 22s - loss: 0.1522 - root_mean_squared_error: 0.2591
# generate data, add 7 flips/transposes, shuffle.
# Epoch 243/1000
# 3769/3769 - 22s - loss: 0.1530 - root_mean_squared_error: 0.2603
# generate data, add 7 flips/transposes, shuffle.
# Epoch 244/1000
# 3769/3769 - 22s - loss: 0.1525 - root_mean_squared_error: 0.2601
# generate data, add 7 flips/transposes, shuffle.
# Epoch 245/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1517 - root_mean_squared_error: 0.2576
# generate data, add 7 flips/transposes, shuffle.
# Epoch 246/1000
# 3769/3769 - 22s - loss: 0.1530 - root_mean_squared_error: 0.2608
# generate data, add 7 flips/transposes, shuffle.
# Epoch 247/1000
# 3769/3769 - 22s - loss: 0.1524 - root_mean_squared_error: 0.2590
# generate data, add 7 flips/transposes, shuffle.
# Epoch 248/1000
# 3769/3769 - 22s - loss: 0.1520 - root_mean_squared_error: 0.2581
# generate data, add 7 flips/transposes, shuffle.
# Epoch 249/1000
# 3769/3769 - 22s - loss: 0.1521 - root_mean_squared_error: 0.2588
# generate data, add 7 flips/transposes, shuffle.
# Epoch 250/1000
# 3769/3769 - 22s - loss: 0.1524 - root_mean_squared_error: 0.2594
# generate data, add 7 flips/transposes, shuffle.
# Epoch 251/1000
# 3769/3769 - 22s - loss: 0.1525 - root_mean_squared_error: 0.2594
# generate data, add 7 flips/transposes, shuffle.
# Epoch 252/1000
# 3769/3769 - 22s - loss: 0.1525 - root_mean_squared_error: 0.2594
# generate data, add 7 flips/transposes, shuffle.
# Epoch 253/1000
# 3769/3769 - 22s - loss: 0.1520 - root_mean_squared_error: 0.2588
# generate data, add 7 flips/transposes, shuffle.
# Epoch 254/1000
# 3769/3769 - 22s - loss: 0.1517 - root_mean_squared_error: 0.2580
# generate data, add 7 flips/transposes, shuffle.
# Epoch 255/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1516 - root_mean_squared_error: 0.2586
# generate data, add 7 flips/transposes, shuffle.
# Epoch 256/1000
# 3769/3769 - 22s - loss: 0.1520 - root_mean_squared_error: 0.2593
# generate data, add 7 flips/transposes, shuffle.
# Epoch 257/1000
# 3769/3769 - 22s - loss: 0.1517 - root_mean_squared_error: 0.2584
# generate data, add 7 flips/transposes, shuffle.
# Epoch 258/1000
# 3769/3769 - 22s - loss: 0.1526 - root_mean_squared_error: 0.2597
# generate data, add 7 flips/transposes, shuffle.
# Epoch 259/1000
# 3769/3769 - 22s - loss: 0.1520 - root_mean_squared_error: 0.2593
# generate data, add 7 flips/transposes, shuffle.
# Epoch 260/1000
# 3769/3769 - 22s - loss: 0.1522 - root_mean_squared_error: 0.2594
# generate data, add 7 flips/transposes, shuffle.
# Epoch 261/1000
# 3769/3769 - 22s - loss: 0.1522 - root_mean_squared_error: 0.2592
# generate data, add 7 flips/transposes, shuffle.
# Epoch 262/1000
# 3769/3769 - 22s - loss: 0.1519 - root_mean_squared_error: 0.2582
# generate data, add 7 flips/transposes, shuffle.
# Epoch 263/1000
# 3769/3769 - 22s - loss: 0.1518 - root_mean_squared_error: 0.2582
# generate data, add 7 flips/transposes, shuffle.
# Epoch 264/1000
# 3769/3769 - 22s - loss: 0.1520 - root_mean_squared_error: 0.2588
# generate data, add 7 flips/transposes, shuffle.
# Epoch 265/1000
# 3769/3769 - 22s - loss: 0.1517 - root_mean_squared_error: 0.2580
# generate data, add 7 flips/transposes, shuffle.
# Epoch 266/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1516 - root_mean_squared_error: 0.2581
# generate data, add 7 flips/transposes, shuffle.
# Epoch 267/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1512 - root_mean_squared_error: 0.2580
# generate data, add 7 flips/transposes, shuffle.
# Epoch 268/1000
# 3769/3769 - 22s - loss: 0.1514 - root_mean_squared_error: 0.2579
# generate data, add 7 flips/transposes, shuffle.
# Epoch 269/1000
# 3769/3769 - 22s - loss: 0.1517 - root_mean_squared_error: 0.2577
# generate data, add 7 flips/transposes, shuffle.
# Epoch 270/1000
# 3769/3769 - 22s - loss: 0.1515 - root_mean_squared_error: 0.2588
# generate data, add 7 flips/transposes, shuffle.
# Epoch 271/1000
# 3769/3769 - 22s - loss: 0.1517 - root_mean_squared_error: 0.2588
# generate data, add 7 flips/transposes, shuffle.
# Epoch 272/1000
# 3769/3769 - 22s - loss: 0.1517 - root_mean_squared_error: 0.2591
# generate data, add 7 flips/transposes, shuffle.
# Epoch 273/1000
# 3769/3769 - 22s - loss: 0.1518 - root_mean_squared_error: 0.2584
# generate data, add 7 flips/transposes, shuffle.
# Epoch 274/1000
# 3769/3769 - 22s - loss: 0.1516 - root_mean_squared_error: 0.2583
# generate data, add 7 flips/transposes, shuffle.
# Epoch 275/1000
# 3769/3769 - 22s - loss: 0.1520 - root_mean_squared_error: 0.2594
# generate data, add 7 flips/transposes, shuffle.
# Epoch 276/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1510 - root_mean_squared_error: 0.2577
# generate data, add 7 flips/transposes, shuffle.
# Epoch 277/1000
# 3769/3769 - 22s - loss: 0.1514 - root_mean_squared_error: 0.2581
# generate data, add 7 flips/transposes, shuffle.
# Epoch 278/1000
# 3769/3769 - 22s - loss: 0.1511 - root_mean_squared_error: 0.2573
# generate data, add 7 flips/transposes, shuffle.
# Epoch 279/1000
# 3769/3769 - 22s - loss: 0.1515 - root_mean_squared_error: 0.2588
# generate data, add 7 flips/transposes, shuffle.
# Epoch 280/1000
# 3769/3769 - 22s - loss: 0.1519 - root_mean_squared_error: 0.2590
# generate data, add 7 flips/transposes, shuffle.
# Epoch 281/1000
# 3769/3769 - 22s - loss: 0.1515 - root_mean_squared_error: 0.2587
# generate data, add 7 flips/transposes, shuffle.
# Epoch 282/1000
# 3769/3769 - 22s - loss: 0.1518 - root_mean_squared_error: 0.2586
# generate data, add 7 flips/transposes, shuffle.
# Epoch 283/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1509 - root_mean_squared_error: 0.2580
# generate data, add 7 flips/transposes, shuffle.
# Epoch 284/1000
# 3769/3769 - 22s - loss: 0.1514 - root_mean_squared_error: 0.2578
# generate data, add 7 flips/transposes, shuffle.
# Epoch 285/1000
# 3769/3769 - 22s - loss: 0.1509 - root_mean_squared_error: 0.2574
# generate data, add 7 flips/transposes, shuffle.
# Epoch 286/1000
# 3769/3769 - 22s - loss: 0.1511 - root_mean_squared_error: 0.2584
# generate data, add 7 flips/transposes, shuffle.
# Epoch 287/1000
# 3769/3769 - 22s - loss: 0.1513 - root_mean_squared_error: 0.2585
# generate data, add 7 flips/transposes, shuffle.
# Epoch 288/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1509 - root_mean_squared_error: 0.2569
# generate data, add 7 flips/transposes, shuffle.
# Epoch 289/1000
# 3769/3769 - 22s - loss: 0.1514 - root_mean_squared_error: 0.2581
# generate data, add 7 flips/transposes, shuffle.
# Epoch 290/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1507 - root_mean_squared_error: 0.2574
# generate data, add 7 flips/transposes, shuffle.
# Epoch 291/1000
# 3769/3769 - 22s - loss: 0.1507 - root_mean_squared_error: 0.2573
# generate data, add 7 flips/transposes, shuffle.
# Epoch 292/1000
# 3769/3769 - 22s - loss: 0.1511 - root_mean_squared_error: 0.2580
# generate data, add 7 flips/transposes, shuffle.
# Epoch 293/1000
# 3769/3769 - 22s - loss: 0.1512 - root_mean_squared_error: 0.2586
# generate data, add 7 flips/transposes, shuffle.
# Epoch 294/1000
# 3769/3769 - 22s - loss: 0.1507 - root_mean_squared_error: 0.2576
# generate data, add 7 flips/transposes, shuffle.
# Epoch 295/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1507 - root_mean_squared_error: 0.2572
# generate data, add 7 flips/transposes, shuffle.
# Epoch 296/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1505 - root_mean_squared_error: 0.2568
# generate data, add 7 flips/transposes, shuffle.
# Epoch 297/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1502 - root_mean_squared_error: 0.2564
# generate data, add 7 flips/transposes, shuffle.
# Epoch 298/1000
# 3769/3769 - 22s - loss: 0.1504 - root_mean_squared_error: 0.2566
# generate data, add 7 flips/transposes, shuffle.
# Epoch 299/1000
# 3769/3769 - 22s - loss: 0.1507 - root_mean_squared_error: 0.2571
# generate data, add 7 flips/transposes, shuffle.
# Epoch 300/1000
# 3769/3769 - 22s - loss: 0.1505 - root_mean_squared_error: 0.2564
# generate data, add 7 flips/transposes, shuffle.
# Epoch 301/1000
# 3769/3769 - 22s - loss: 0.1507 - root_mean_squared_error: 0.2571
# generate data, add 7 flips/transposes, shuffle.
# Epoch 302/1000
# 3769/3769 - 22s - loss: 0.1513 - root_mean_squared_error: 0.2581
# generate data, add 7 flips/transposes, shuffle.
# Epoch 303/1000
# 3769/3769 - 22s - loss: 0.1513 - root_mean_squared_error: 0.2584
# generate data, add 7 flips/transposes, shuffle.
# Epoch 304/1000
# 3769/3769 - 22s - loss: 0.1509 - root_mean_squared_error: 0.2574
# generate data, add 7 flips/transposes, shuffle.
# Epoch 305/1000
# 3769/3769 - 22s - loss: 0.1510 - root_mean_squared_error: 0.2577
# generate data, add 7 flips/transposes, shuffle.
# Epoch 306/1000
# 3769/3769 - 22s - loss: 0.1505 - root_mean_squared_error: 0.2576
# generate data, add 7 flips/transposes, shuffle.
# Epoch 307/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1502 - root_mean_squared_error: 0.2568
# generate data, add 7 flips/transposes, shuffle.
# Epoch 308/1000
# 3769/3769 - 22s - loss: 0.1514 - root_mean_squared_error: 0.2588
# generate data, add 7 flips/transposes, shuffle.
# Epoch 309/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1501 - root_mean_squared_error: 0.2568
# generate data, add 7 flips/transposes, shuffle.
# Epoch 310/1000
# 3769/3769 - 22s - loss: 0.1510 - root_mean_squared_error: 0.2583
# generate data, add 7 flips/transposes, shuffle.
# Epoch 311/1000
# 3769/3769 - 22s - loss: 0.1508 - root_mean_squared_error: 0.2577
# generate data, add 7 flips/transposes, shuffle.
# Epoch 312/1000
# 3769/3769 - 22s - loss: 0.1507 - root_mean_squared_error: 0.2573
# generate data, add 7 flips/transposes, shuffle.
# Epoch 313/1000
# 3769/3769 - 22s - loss: 0.1502 - root_mean_squared_error: 0.2569
# generate data, add 7 flips/transposes, shuffle.
# Epoch 314/1000
# 3769/3769 - 22s - loss: 0.1506 - root_mean_squared_error: 0.2571
# generate data, add 7 flips/transposes, shuffle.
# Epoch 315/1000
# 3769/3769 - 22s - loss: 0.1510 - root_mean_squared_error: 0.2580
# generate data, add 7 flips/transposes, shuffle.
# Epoch 316/1000
# 3769/3769 - 22s - loss: 0.1507 - root_mean_squared_error: 0.2577
# generate data, add 7 flips/transposes, shuffle.
# Epoch 317/1000
# 3769/3769 - 22s - loss: 0.1509 - root_mean_squared_error: 0.2583
# generate data, add 7 flips/transposes, shuffle.
# Epoch 318/1000
# 3769/3769 - 22s - loss: 0.1506 - root_mean_squared_error: 0.2576
# generate data, add 7 flips/transposes, shuffle.
# Epoch 319/1000
# 3769/3769 - 22s - loss: 0.1507 - root_mean_squared_error: 0.2574
# generate data, add 7 flips/transposes, shuffle.
# Epoch 320/1000
# 3769/3769 - 22s - loss: 0.1505 - root_mean_squared_error: 0.2576
# generate data, add 7 flips/transposes, shuffle.
# Epoch 321/1000
# 3769/3769 - 22s - loss: 0.1505 - root_mean_squared_error: 0.2572
# generate data, add 7 flips/transposes, shuffle.
# Epoch 322/1000
# 3769/3769 - 22s - loss: 0.1508 - root_mean_squared_error: 0.2585
# generate data, add 7 flips/transposes, shuffle.
# Epoch 323/1000
# 3769/3769 - 22s - loss: 0.1506 - root_mean_squared_error: 0.2568
# generate data, add 7 flips/transposes, shuffle.
# Epoch 324/1000
# 3769/3769 - 22s - loss: 0.1502 - root_mean_squared_error: 0.2575
# generate data, add 7 flips/transposes, shuffle.
# Epoch 325/1000
# 3769/3769 - 22s - loss: 0.1505 - root_mean_squared_error: 0.2573
# generate data, add 7 flips/transposes, shuffle.
# Epoch 326/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 23s - loss: 0.1500 - root_mean_squared_error: 0.2567
# generate data, add 7 flips/transposes, shuffle.
# Epoch 327/1000
# ...
# generate data, add 7 flips/transposes, shuffle.
# Epoch 878/1000
# 3769/3769 - 22s - loss: 0.1472 - root_mean_squared_error: 0.2542
# generate data, add 7 flips/transposes, shuffle.
# Epoch 879/1000
# 3769/3769 - 21s - loss: 0.1472 - root_mean_squared_error: 0.2537
# generate data, add 7 flips/transposes, shuffle.
# Epoch 880/1000
# 3769/3769 - 22s - loss: 0.1478 - root_mean_squared_error: 0.2539
# generate data, add 7 flips/transposes, shuffle.
# Epoch 881/1000
# 3769/3769 - 22s - loss: 0.1469 - root_mean_squared_error: 0.2533
# generate data, add 7 flips/transposes, shuffle.
# Epoch 882/1000
# 3769/3769 - 22s - loss: 0.1478 - root_mean_squared_error: 0.2545
# generate data, add 7 flips/transposes, shuffle.
# Epoch 883/1000
# 3769/3769 - 21s - loss: 0.1467 - root_mean_squared_error: 0.2527
# generate data, add 7 flips/transposes, shuffle.
# Epoch 884/1000
# 3769/3769 - 22s - loss: 0.1468 - root_mean_squared_error: 0.2526
# generate data, add 7 flips/transposes, shuffle.
# Epoch 885/1000
# 3769/3769 - 22s - loss: 0.1471 - root_mean_squared_error: 0.2536
# generate data, add 7 flips/transposes, shuffle.
# Epoch 886/1000
# 3769/3769 - 22s - loss: 0.1475 - root_mean_squared_error: 0.2539
# generate data, add 7 flips/transposes, shuffle.
# Epoch 887/1000
# 3769/3769 - 21s - loss: 0.1474 - root_mean_squared_error: 0.2540
# generate data, add 7 flips/transposes, shuffle.
# Epoch 888/1000
# 3769/3769 - 21s - loss: 0.1473 - root_mean_squared_error: 0.2536
# generate data, add 7 flips/transposes, shuffle.
# Epoch 889/1000
# 3769/3769 - 22s - loss: 0.1473 - root_mean_squared_error: 0.2541
# generate data, add 7 flips/transposes, shuffle.
# Epoch 890/1000
# 3769/3769 - 22s - loss: 0.1474 - root_mean_squared_error: 0.2541
# generate data, add 7 flips/transposes, shuffle.
# Epoch 891/1000
# 3769/3769 - 21s - loss: 0.1474 - root_mean_squared_error: 0.2536
# generate data, add 7 flips/transposes, shuffle.
# Epoch 892/1000
# 3769/3769 - 21s - loss: 0.1474 - root_mean_squared_error: 0.2535
# generate data, add 7 flips/transposes, shuffle.
# Epoch 893/1000
# 3769/3769 - 22s - loss: 0.1468 - root_mean_squared_error: 0.2530
# generate data, add 7 flips/transposes, shuffle.
# Epoch 894/1000
# 3769/3769 - 21s - loss: 0.1477 - root_mean_squared_error: 0.2543
# generate data, add 7 flips/transposes, shuffle.
# Epoch 895/1000
# 3769/3769 - 21s - loss: 0.1470 - root_mean_squared_error: 0.2537
# generate data, add 7 flips/transposes, shuffle.
# Epoch 896/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1464 - root_mean_squared_error: 0.2520
# generate data, add 7 flips/transposes, shuffle.
# Epoch 897/1000
# 3769/3769 - 22s - loss: 0.1474 - root_mean_squared_error: 0.2546
# generate data, add 7 flips/transposes, shuffle.
# Epoch 898/1000
# 3769/3769 - 21s - loss: 0.1476 - root_mean_squared_error: 0.2552
# generate data, add 7 flips/transposes, shuffle.
# Epoch 899/1000
# 3769/3769 - 21s - loss: 0.1475 - root_mean_squared_error: 0.2545
# generate data, add 7 flips/transposes, shuffle.
# Epoch 900/1000
# 3769/3769 - 21s - loss: 0.1474 - root_mean_squared_error: 0.2540
# generate data, add 7 flips/transposes, shuffle.
# Epoch 901/1000
# 3769/3769 - 22s - loss: 0.1470 - root_mean_squared_error: 0.2534
# generate data, add 7 flips/transposes, shuffle.
# Epoch 902/1000
# 3769/3769 - 21s - loss: 0.1469 - root_mean_squared_error: 0.2536
# generate data, add 7 flips/transposes, shuffle.
# Epoch 903/1000
# 3769/3769 - 21s - loss: 0.1466 - root_mean_squared_error: 0.2528
# generate data, add 7 flips/transposes, shuffle.
# Epoch 904/1000
# 3769/3769 - 22s - loss: 0.1472 - root_mean_squared_error: 0.2546
# generate data, add 7 flips/transposes, shuffle.
# Epoch 905/1000
# 3769/3769 - 21s - loss: 0.1474 - root_mean_squared_error: 0.2535
# generate data, add 7 flips/transposes, shuffle.
# Epoch 906/1000
# 3769/3769 - 21s - loss: 0.1477 - root_mean_squared_error: 0.2541
# generate data, add 7 flips/transposes, shuffle.
# Epoch 907/1000
# 3769/3769 - 21s - loss: 0.1473 - root_mean_squared_error: 0.2543
# generate data, add 7 flips/transposes, shuffle.
# Epoch 908/1000
# 3769/3769 - 21s - loss: 0.1476 - root_mean_squared_error: 0.2535
# generate data, add 7 flips/transposes, shuffle.
# Epoch 909/1000
# 3769/3769 - 21s - loss: 0.1473 - root_mean_squared_error: 0.2540
# generate data, add 7 flips/transposes, shuffle.
# Epoch 910/1000
# 3769/3769 - 22s - loss: 0.1474 - root_mean_squared_error: 0.2539
# generate data, add 7 flips/transposes, shuffle.
# Epoch 911/1000
# 3769/3769 - 21s - loss: 0.1470 - root_mean_squared_error: 0.2537
# generate data, add 7 flips/transposes, shuffle.
# Epoch 912/1000
# 3769/3769 - 22s - loss: 0.1469 - root_mean_squared_error: 0.2537
# generate data, add 7 flips/transposes, shuffle.
# Epoch 913/1000
# 3769/3769 - 21s - loss: 0.1477 - root_mean_squared_error: 0.2539
# generate data, add 7 flips/transposes, shuffle.
# Epoch 914/1000
# 3769/3769 - 21s - loss: 0.1478 - root_mean_squared_error: 0.2537
# generate data, add 7 flips/transposes, shuffle.
# Epoch 915/1000
# 3769/3769 - 21s - loss: 0.1478 - root_mean_squared_error: 0.2541
# generate data, add 7 flips/transposes, shuffle.
# Epoch 916/1000
# 3769/3769 - 22s - loss: 0.1469 - root_mean_squared_error: 0.2535
# generate data, add 7 flips/transposes, shuffle.
# Epoch 917/1000
# 3769/3769 - 21s - loss: 0.1471 - root_mean_squared_error: 0.2537
# generate data, add 7 flips/transposes, shuffle.
# Epoch 918/1000
# 3769/3769 - 22s - loss: 0.1470 - root_mean_squared_error: 0.2541
# generate data, add 7 flips/transposes, shuffle.
# Epoch 919/1000
# 3769/3769 - 21s - loss: 0.1473 - root_mean_squared_error: 0.2540
# generate data, add 7 flips/transposes, shuffle.
# Epoch 920/1000
# 3769/3769 - 22s - loss: 0.1473 - root_mean_squared_error: 0.2539
# generate data, add 7 flips/transposes, shuffle.
# Epoch 921/1000
# 3769/3769 - 21s - loss: 0.1485 - root_mean_squared_error: 0.2555
# generate data, add 7 flips/transposes, shuffle.
# Epoch 922/1000
# 3769/3769 - 21s - loss: 0.1472 - root_mean_squared_error: 0.2533
# generate data, add 7 flips/transposes, shuffle.
# Epoch 923/1000
# 3769/3769 - 22s - loss: 0.1476 - root_mean_squared_error: 0.2538
# generate data, add 7 flips/transposes, shuffle.
# Epoch 924/1000
# 3769/3769 - 22s - loss: 0.1478 - root_mean_squared_error: 0.2543
# generate data, add 7 flips/transposes, shuffle.
# Epoch 925/1000
# 3769/3769 - 21s - loss: 0.1470 - root_mean_squared_error: 0.2532
# generate data, add 7 flips/transposes, shuffle.
# Epoch 926/1000
# 3769/3769 - 22s - loss: 0.1481 - root_mean_squared_error: 0.2560
# generate data, add 7 flips/transposes, shuffle.
# Epoch 927/1000
# 3769/3769 - 22s - loss: 0.1473 - root_mean_squared_error: 0.2534
# generate data, add 7 flips/transposes, shuffle.
# Epoch 928/1000
# 3769/3769 - 22s - loss: 0.1479 - root_mean_squared_error: 0.2548
# generate data, add 7 flips/transposes, shuffle.
# Epoch 929/1000
# 3769/3769 - 21s - loss: 0.1477 - root_mean_squared_error: 0.2535
# generate data, add 7 flips/transposes, shuffle.
# Epoch 930/1000
# 3769/3769 - 21s - loss: 0.1479 - root_mean_squared_error: 0.2538
# generate data, add 7 flips/transposes, shuffle.
# Epoch 931/1000
# 3769/3769 - 22s - loss: 0.1467 - root_mean_squared_error: 0.2527
# generate data, add 7 flips/transposes, shuffle.
# Epoch 932/1000
# 3769/3769 - 22s - loss: 0.1471 - root_mean_squared_error: 0.2545
# generate data, add 7 flips/transposes, shuffle.
# Epoch 933/1000
# 3769/3769 - 22s - loss: 0.1475 - root_mean_squared_error: 0.2541
# generate data, add 7 flips/transposes, shuffle.
# Epoch 934/1000
# 3769/3769 - 22s - loss: 0.1466 - root_mean_squared_error: 0.2515
# generate data, add 7 flips/transposes, shuffle.
# Epoch 935/1000
# 3769/3769 - 21s - loss: 0.1475 - root_mean_squared_error: 0.2539
# generate data, add 7 flips/transposes, shuffle.
# Epoch 936/1000
# 3769/3769 - 21s - loss: 0.1474 - root_mean_squared_error: 0.2536
# generate data, add 7 flips/transposes, shuffle.
# Epoch 937/1000
# 3769/3769 - 21s - loss: 0.1475 - root_mean_squared_error: 0.2540
# generate data, add 7 flips/transposes, shuffle.
# Epoch 938/1000
# 3769/3769 - 22s - loss: 0.1476 - root_mean_squared_error: 0.2545
# generate data, add 7 flips/transposes, shuffle.
# Epoch 939/1000
# 3769/3769 - 21s - loss: 0.1474 - root_mean_squared_error: 0.2534
# generate data, add 7 flips/transposes, shuffle.
# Epoch 940/1000
# 3769/3769 - 22s - loss: 0.1481 - root_mean_squared_error: 0.2547
# generate data, add 7 flips/transposes, shuffle.
# Epoch 941/1000
# 3769/3769 - 22s - loss: 0.1479 - root_mean_squared_error: 0.2548
# generate data, add 7 flips/transposes, shuffle.
# Epoch 942/1000
# 3769/3769 - 22s - loss: 0.1478 - root_mean_squared_error: 0.2547
# generate data, add 7 flips/transposes, shuffle.
# Epoch 943/1000
# 3769/3769 - 22s - loss: 0.1473 - root_mean_squared_error: 0.2534
# generate data, add 7 flips/transposes, shuffle.
# Epoch 944/1000
# 3769/3769 - 22s - loss: 0.1473 - root_mean_squared_error: 0.2532
# generate data, add 7 flips/transposes, shuffle.
# Epoch 945/1000
# 3769/3769 - 22s - loss: 0.1472 - root_mean_squared_error: 0.2533
# generate data, add 7 flips/transposes, shuffle.
# Epoch 946/1000
# 3769/3769 - 22s - loss: 0.1471 - root_mean_squared_error: 0.2536
# generate data, add 7 flips/transposes, shuffle.
# Epoch 947/1000
# 3769/3769 - 22s - loss: 0.1467 - root_mean_squared_error: 0.2532
# generate data, add 7 flips/transposes, shuffle.
# Epoch 948/1000
# 3769/3769 - 22s - loss: 0.1468 - root_mean_squared_error: 0.2530
# generate data, add 7 flips/transposes, shuffle.
# Epoch 949/1000
# 3769/3769 - 22s - loss: 0.1471 - root_mean_squared_error: 0.2534
# generate data, add 7 flips/transposes, shuffle.
# Epoch 950/1000
# 3769/3769 - 22s - loss: 0.1471 - root_mean_squared_error: 0.2536
# generate data, add 7 flips/transposes, shuffle.
# Epoch 951/1000
# 3769/3769 - 22s - loss: 0.1478 - root_mean_squared_error: 0.2540
# generate data, add 7 flips/transposes, shuffle.
# Epoch 952/1000
# 3769/3769 - 22s - loss: 0.1472 - root_mean_squared_error: 0.2539
# generate data, add 7 flips/transposes, shuffle.
# Epoch 953/1000
# 3769/3769 - 22s - loss: 0.1468 - root_mean_squared_error: 0.2527
# generate data, add 7 flips/transposes, shuffle.
# Epoch 954/1000
# 3769/3769 - 22s - loss: 0.1473 - root_mean_squared_error: 0.2540
# generate data, add 7 flips/transposes, shuffle.
# Epoch 955/1000
# 3769/3769 - 22s - loss: 0.1468 - root_mean_squared_error: 0.2529
# generate data, add 7 flips/transposes, shuffle.
# Epoch 956/1000
# 3769/3769 - 22s - loss: 0.1467 - root_mean_squared_error: 0.2529
# generate data, add 7 flips/transposes, shuffle.
# Epoch 957/1000
# 3769/3769 - 22s - loss: 0.1469 - root_mean_squared_error: 0.2523
# generate data, add 7 flips/transposes, shuffle.
# Epoch 958/1000
# 3769/3769 - 22s - loss: 0.1473 - root_mean_squared_error: 0.2531
# generate data, add 7 flips/transposes, shuffle.
# Epoch 959/1000
# 3769/3769 - 22s - loss: 0.1473 - root_mean_squared_error: 0.2533
# generate data, add 7 flips/transposes, shuffle.
# Epoch 960/1000
# 3769/3769 - 22s - loss: 0.1468 - root_mean_squared_error: 0.2528
# generate data, add 7 flips/transposes, shuffle.
# Epoch 961/1000
# 3769/3769 - 22s - loss: 0.1480 - root_mean_squared_error: 0.2554
# generate data, add 7 flips/transposes, shuffle.
# Epoch 962/1000
# 3769/3769 - 22s - loss: 0.1475 - root_mean_squared_error: 0.2538
# generate data, add 7 flips/transposes, shuffle.
# Epoch 963/1000
# 3769/3769 - 22s - loss: 0.1471 - root_mean_squared_error: 0.2540
# generate data, add 7 flips/transposes, shuffle.
# Epoch 964/1000
# 3769/3769 - 22s - loss: 0.1471 - root_mean_squared_error: 0.2536
# generate data, add 7 flips/transposes, shuffle.
# Epoch 965/1000
# 3769/3769 - 22s - loss: 0.1483 - root_mean_squared_error: 0.2553
# generate data, add 7 flips/transposes, shuffle.
# Epoch 966/1000
# 3769/3769 - 22s - loss: 0.1473 - root_mean_squared_error: 0.2542
# generate data, add 7 flips/transposes, shuffle.
# Epoch 967/1000
# 3769/3769 - 22s - loss: 0.1470 - root_mean_squared_error: 0.2539
# generate data, add 7 flips/transposes, shuffle.
# Epoch 968/1000
# 3769/3769 - 22s - loss: 0.1472 - root_mean_squared_error: 0.2537
# generate data, add 7 flips/transposes, shuffle.
# Epoch 969/1000
# 3769/3769 - 22s - loss: 0.1469 - root_mean_squared_error: 0.2529
# generate data, add 7 flips/transposes, shuffle.
# Epoch 970/1000
# 3769/3769 - 22s - loss: 0.1471 - root_mean_squared_error: 0.2538
# generate data, add 7 flips/transposes, shuffle.
# Epoch 971/1000
# 3769/3769 - 22s - loss: 0.1470 - root_mean_squared_error: 0.2533
# generate data, add 7 flips/transposes, shuffle.
# Epoch 972/1000
# 3769/3769 - 22s - loss: 0.1466 - root_mean_squared_error: 0.2537
# generate data, add 7 flips/transposes, shuffle.
# Epoch 973/1000
# 3769/3769 - 22s - loss: 0.1470 - root_mean_squared_error: 0.2528
# generate data, add 7 flips/transposes, shuffle.
# Epoch 974/1000
# 3769/3769 - 22s - loss: 0.1471 - root_mean_squared_error: 0.2539
# generate data, add 7 flips/transposes, shuffle.
# Epoch 975/1000
# 3769/3769 - 22s - loss: 0.1468 - root_mean_squared_error: 0.2525
# generate data, add 7 flips/transposes, shuffle.
# Epoch 976/1000
# 3769/3769 - 22s - loss: 0.1467 - root_mean_squared_error: 0.2523
# generate data, add 7 flips/transposes, shuffle.
# Epoch 977/1000
# 3769/3769 - 22s - loss: 0.1476 - root_mean_squared_error: 0.2543
# generate data, add 7 flips/transposes, shuffle.
# Epoch 978/1000
# 3769/3769 - 22s - loss: 0.1467 - root_mean_squared_error: 0.2528
# generate data, add 7 flips/transposes, shuffle.
# Epoch 979/1000
# INFO:tensorflow:Assets written to: model_NI/assets
# 3769/3769 - 22s - loss: 0.1463 - root_mean_squared_error: 0.2528
# generate data, add 7 flips/transposes, shuffle.
# Epoch 980/1000
# 3769/3769 - 22s - loss: 0.1474 - root_mean_squared_error: 0.2541
# generate data, add 7 flips/transposes, shuffle.
# Epoch 981/1000
# 3769/3769 - 22s - loss: 0.1469 - root_mean_squared_error: 0.2527
# generate data, add 7 flips/transposes, shuffle.
# Epoch 982/1000
# 3769/3769 - 22s - loss: 0.1468 - root_mean_squared_error: 0.2528
# generate data, add 7 flips/transposes, shuffle.
# Epoch 983/1000
# 3769/3769 - 22s - loss: 0.1477 - root_mean_squared_error: 0.2542
# generate data, add 7 flips/transposes, shuffle.
# Epoch 984/1000
# 3769/3769 - 22s - loss: 0.1475 - root_mean_squared_error: 0.2544
# generate data, add 7 flips/transposes, shuffle.
# Epoch 985/1000
# 3769/3769 - 21s - loss: 0.1482 - root_mean_squared_error: 0.2550
# generate data, add 7 flips/transposes, shuffle.
# Epoch 986/1000
# 3769/3769 - 22s - loss: 0.1469 - root_mean_squared_error: 0.2541
# generate data, add 7 flips/transposes, shuffle.
# Epoch 987/1000
# 3769/3769 - 22s - loss: 0.1478 - root_mean_squared_error: 0.2544
# generate data, add 7 flips/transposes, shuffle.
# Epoch 988/1000
# 3769/3769 - 22s - loss: 0.1475 - root_mean_squared_error: 0.2543
# generate data, add 7 flips/transposes, shuffle.
# Epoch 989/1000
# 3769/3769 - 22s - loss: 0.1471 - root_mean_squared_error: 0.2548
# generate data, add 7 flips/transposes, shuffle.
# Epoch 990/1000
# 3769/3769 - 22s - loss: 0.1470 - root_mean_squared_error: 0.2530
# generate data, add 7 flips/transposes, shuffle.
# Epoch 991/1000
# 3769/3769 - 21s - loss: 0.1473 - root_mean_squared_error: 0.2533
# generate data, add 7 flips/transposes, shuffle.
# Epoch 992/1000
# 3769/3769 - 22s - loss: 0.1475 - root_mean_squared_error: 0.2539
# generate data, add 7 flips/transposes, shuffle.
# Epoch 993/1000
# 3769/3769 - 22s - loss: 0.1470 - root_mean_squared_error: 0.2535
# generate data, add 7 flips/transposes, shuffle.
# Epoch 994/1000
# 3769/3769 - 22s - loss: 0.1472 - root_mean_squared_error: 0.2539
# generate data, add 7 flips/transposes, shuffle.
# Epoch 995/1000
# 3769/3769 - 22s - loss: 0.1472 - root_mean_squared_error: 0.2535
# generate data, add 7 flips/transposes, shuffle.
# Epoch 996/1000
# 3769/3769 - 22s - loss: 0.1476 - root_mean_squared_error: 0.2540
# generate data, add 7 flips/transposes, shuffle.
# Epoch 997/1000
# 3769/3769 - 22s - loss: 0.1469 - root_mean_squared_error: 0.2533
# generate data, add 7 flips/transposes, shuffle.
# Epoch 998/1000
# 3769/3769 - 22s - loss: 0.1475 - root_mean_squared_error: 0.2542
# generate data, add 7 flips/transposes, shuffle.
# Epoch 999/1000
# 3769/3769 - 21s - loss: 0.1474 - root_mean_squared_error: 0.2534
# generate data, add 7 flips/transposes, shuffle.
# Epoch 1000/1000
# 3769/3769 - 21s - loss: 0.1470 - root_mean_squared_error: 0.2533
# generate data, add 7 flips/transposes, shuffle.
# CPU times: user 5h 53min 18s, sys: 1h 40min 59s, total: 7h 34min 18s
# Wall time: 6h 6min 42s

# %%
print(history1.history.keys())
fig = plt.figure(figsize=(10,3))
fig.subplots_adjust(hspace=100, wspace=1)
ax1 = fig.add_subplot(1, 2, 1)      
ax1.grid()
# ax1.set_ylim([.15,.2])
ax1.plot(history1.history['loss'])
ax1.set_ylabel('mae')
ax1.set_xlabel('epoch')
ax2 = fig.add_subplot(1, 2, 2)      
# ax2.set_ylim([.25,.4])
ax2.grid()
ax2.plot(history1.history['root_mean_squared_error'])
ax2.set_ylabel('root mean squared error')
ax2.set_xlabel('epoch')
plt.show()
# Out:
# dict_keys(['loss', 'root_mean_squared_error'])

# %% [markdown]
# ## Apply the model to the test data from the simulation study

# %%
# !wget -P npy/ https://www.dropbox.com/s/5kba6a2g777zshr/test_x.npy?dl=1
# !wget -P npy/ https://www.dropbox.com/s/23goi9qyx0qpbqe/test_y.npy?dl=1
test_x = np.load('npy/test_x.npy?dl=1')
test_y = np.load('npy/test_y.npy?dl=1')
# Out:
# --2020-11-11 00:21:26--  https://www.dropbox.com/s/5kba6a2g777zshr/test_x.npy?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.1, 2620:100:6019:1::a27d:401
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/5kba6a2g777zshr/test_x.npy [following]
# --2020-11-11 00:21:26--  https://www.dropbox.com/s/dl/5kba6a2g777zshr/test_x.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc5e3a7e25a9e0e1d9fbcb960619.dl.dropboxusercontent.com/cd/0/get/BC-qxrrChsuHfrEYy-FE_95v-5b_CbIOBJdRm-YPeDuRAQqpwXFUppwhl5x93xvht5Ve4Hbv8K3n2Irm_7Lmw9ZGHVCD7wBRoYcy7AgiF9MUbCOo7KkaKCoHl2ZuT-vamyw/file?dl=1# [following]
# --2020-11-11 00:21:26--  https://uc5e3a7e25a9e0e1d9fbcb960619.dl.dropboxusercontent.com/cd/0/get/BC-qxrrChsuHfrEYy-FE_95v-5b_CbIOBJdRm-YPeDuRAQqpwXFUppwhl5x93xvht5Ve4Hbv8K3n2Irm_7Lmw9ZGHVCD7wBRoYcy7AgiF9MUbCOo7KkaKCoHl2ZuT-vamyw/file?dl=1
# Resolving uc5e3a7e25a9e0e1d9fbcb960619.dl.dropboxusercontent.com (uc5e3a7e25a9e0e1d9fbcb960619.dl.dropboxusercontent.com)... 162.125.7.15, 2620:100:601a:15::a27d:70f
# Connecting to uc5e3a7e25a9e0e1d9fbcb960619.dl.dropboxusercontent.com (uc5e3a7e25a9e0e1d9fbcb960619.dl.dropboxusercontent.com)|162.125.7.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 614400128 (586M) [application/binary]
# Saving to: ‘npy/test_x.npy?dl=1’
#
# test_x.npy?dl=1     100%[===================>] 585.94M  43.2MB/s    in 15s
#
# 2020-11-11 00:21:42 (40.1 MB/s) - ‘npy/test_x.npy?dl=1’ saved [614400128/614400128]
#
# --2020-11-11 00:21:42--  https://www.dropbox.com/s/23goi9qyx0qpbqe/test_y.npy?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.1, 2620:100:6019:1::a27d:401
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/23goi9qyx0qpbqe/test_y.npy [following]
# --2020-11-11 00:21:42--  https://www.dropbox.com/s/dl/23goi9qyx0qpbqe/test_y.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucda3e47819bf7ad69d3e1cf231f.dl.dropboxusercontent.com/cd/0/get/BC85f_M6M8phicCqON3qdLlpYBXk744aFNIWE_wAYWdqHP-3fnwBKeaVEwjwZKdlG-JWhXDkHVSW13VogH_GgjTLvmx55d0FldWEwRNQDofRCjB_8ka2wOuTnVkk3Ia46I4/file?dl=1# [following]
# --2020-11-11 00:21:42--  https://ucda3e47819bf7ad69d3e1cf231f.dl.dropboxusercontent.com/cd/0/get/BC85f_M6M8phicCqON3qdLlpYBXk744aFNIWE_wAYWdqHP-3fnwBKeaVEwjwZKdlG-JWhXDkHVSW13VogH_GgjTLvmx55d0FldWEwRNQDofRCjB_8ka2wOuTnVkk3Ia46I4/file?dl=1
# Resolving ucda3e47819bf7ad69d3e1cf231f.dl.dropboxusercontent.com (ucda3e47819bf7ad69d3e1cf231f.dl.dropboxusercontent.com)... 162.125.80.15, 2620:100:601a:15::a27d:70f
# Connecting to ucda3e47819bf7ad69d3e1cf231f.dl.dropboxusercontent.com (ucda3e47819bf7ad69d3e1cf231f.dl.dropboxusercontent.com)|162.125.80.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 160128 (156K) [application/binary]
# Saving to: ‘npy/test_y.npy?dl=1’
#
# test_y.npy?dl=1     100%[===================>] 156.38K   311KB/s    in 0.5s
#
# 2020-11-11 00:21:44 (311 KB/s) - ‘npy/test_y.npy?dl=1’ saved [160128/160128]

# %%
## scale test_y with same transformation as used in the generator
test_y_scaled = generator.scaler_y.transform(test_y)
print('test_y ---------> max: ', test_y.max(axis=0), ' mean: ', test_y.mean(axis=0), ', std: ', test_y.std(axis=0))
print('test_y_scaled --> max: ', test_y_scaled.max(axis=0), ' mean: ', test_y_scaled.mean(axis=0), ', std: ', test_y_scaled.std(axis=0))
# Out:
# test_y ---------> max:  [ 0.55448721 25.        ]  mean:  [-5.17562131 13.5       ] , std:  [1.81964502 6.80764402]
# test_y_scaled --> max:  [ 2.07693846 -0.00692133]  mean:  [ 0.2549513  -0.80287471] , std:  [0.57858762 0.47117976]

# %%
test_x = tf.convert_to_tensor(test_x, dtype=tf.float32)
im_pred = np.zeros([test_x.shape[0], test_x.shape[3], 2])

# %%
for i in range(test_x.shape[3]):
  print('.', end='')
  pred = model1.predict(x=tf.expand_dims(test_x[:,:,:,i], 3))
  im_pred[:,i,:] = generator.scaler_y.inverse_transform(pred)
# Out:
# ..............................

# %%
print(generator.scaler_y.inverse_transform(pred)[0:4,:])
print(im_pred[0:4,15,:])
# Out:
# [[ 0.01668226  2.7272296 ]
#  [-0.01024092  3.544311  ]
#  [-0.16610086  2.0187144 ]
#  [-0.12469042  2.700046  ]]
# [[ 0.12062942  1.96466792]
#  [ 0.81483471  2.27738714]
#  [ 0.44678795  3.50561285]
#  [-0.59864795  2.01572371]]

# %%
np.save(file='npy/test_pred_model_NI.npy', arr=im_pred)

# %%
def rand_jitter(arr):
    stdev = .02*(max(arr)-min(arr))
    return arr + np.random.randn(len(arr)) * stdev
def abline(ax, slope=1, intercept=0):
    """Plot a line from slope and intercept"""
    x_vals = np.array(ax.get_xlim())
    y_vals = intercept + slope * x_vals
    ax.plot(x_vals, y_vals, '--', c='r')
fig = plt.figure()
fig.subplots_adjust(hspace=100, wspace=1)
fig.set_size_inches(18.5, 10.5)
for i in range(2):
           ax = fig.add_subplot(1, 4, i+1)
           ax.grid()
           ax.scatter(rand_jitter(test_y[:,i]), im_pred[:,0,i], s=1, alpha=.2)
           ax.set_aspect('equal', 'box')
           abline(ax)

# %% [markdown]
# # Save model and predictions to google drive

# %%
! tar -zcvf model_NI.tar.gz model_NI
files.download('model_NI.tar.gz')
files.download('npy/test_pred_model_NI.npy')
pickle.dump(generator.scaler_y, open(file='npy/scaler_y_model_NI.pkl', mode='wb'))
files.download('npy/scaler_y_model_NI.pkl')
# Out:
# model_NI/
# model_NI/saved_model.pb
# model_NI/assets/
# model_NI/variables/
# model_NI/variables/variables.index
# model_NI/variables/variables.data-00000-of-00001

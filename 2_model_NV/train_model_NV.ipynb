# %% [markdown]
# # Train the NV model using Google Colab

# %%
import tensorflow as tf
from google.colab import drive, files
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import StandardScaler
import pickle

# %% [markdown]
# # An image/varigoram generator class
#
# *   generates new images or variograms at the end of each epoch
# *   returns images (`vgram=False`) or vgrams (`vgram=True`)

# %%
class ImageVariogramGenerator(tf.keras.utils.Sequence):
    def __init__(self, path_prefix, path_suffix='', batch_size=256, random_shuffle=True,
                 flip_transpose = True,
                 test=False, replicates=10,
                 vgrams = True,
                 scale_y=True, Scaler=StandardScaler,
                 verbose = True):
        self.Rin_chols = tf.convert_to_tensor(np.load(path_prefix + '_chols.npy' + path_suffix),
                                              dtype="float32")
        self.Rin_alphaMat = tf.convert_to_tensor(np.load(path_prefix + '_alphaMat.npy' + path_suffix),
                                                 dtype="float32")
        self.Rin_thetaGrid= tf.convert_to_tensor(np.load(path_prefix + '_thetaGrid.npy' + path_suffix),
                                                 dtype="float32")
        self.Rin_y = tf.convert_to_tensor(np.load(path_prefix + '_y.npy' + path_suffix),
                                          dtype="float32")
        ## scale y
        self.scale_y = scale_y
        self.Scaler = Scaler
        if self.scale_y:
            self.scaler_y = self.Scaler().fit(self.Rin_y)
            self.Rin_y = self.scaler_y.transform(self.Rin_y)

        self.m = replicates
        self.nObs = self.Rin_chols.shape[0]
        self.N = int(np.sqrt(self.nObs))
        self.nTheta = len(self.Rin_thetaGrid)
        self.nLambda = self.Rin_alphaMat.shape[0]
        self.nChunk = self.m * self.nLambda
        
        self.batch_size = batch_size
        self.random_shuffle = random_shuffle
        if vgrams and flip_transpose:
            self.flip_transpose = False
            tf.print("!! ignore 'flip_transpose = True' because 'vgrams = True'")
            self.vg, self.dist, self.w = None, None, None
        else:
            self.flip_transpose = flip_transpose
        self.test = test
        self.verbose = verbose

        self.vgrams = vgrams
        self.im, self.y = None, None
        
        self.on_epoch_end()

    def flip_transpose_fn(self):
        """ augment data by flipping and rotating the images"""
        if self.verbose:
          tf.print(', add 7 flips/transposes, ', end='')
        r1 = tf.reverse(self.im, axis=[1])
        r2 = tf.reverse(self.im, axis=[2])
        r3 = tf.reverse(self.im, axis=[1,2])
        t0 = tf.transpose(self.im, perm=[0,2,1,3])
        t1 = tf.transpose(r1, perm=[0,2,1,3])
        t2 = tf.transpose(r2, perm=[0,2,1,3])
        t3 = tf.transpose(r3, perm=[0,2,1,3])
        self.im = tf.concat([self.im, r1, r2, r3, t0, t1, t2, t3], axis=0)
        self.y = tf.tile(self.y, [8,1])
        
    def generate_im(self):
        """simulate images from training parameter configurations"""
        if self.verbose:
          tf.print('generate data', end='')
        if self.test:
            normal = random_test(shape=[self.nTheta, self.nObs, self.nChunk, 2])
        else:
            normal = tf.random.normal(shape=[self.nTheta, self.nObs, self.nChunk, 2])
            
        bigG = tf.linalg.matmul(a=tf.transpose(self.Rin_chols, [2,0,1]),
                                b=normal[:,:,:,0]) 
        bigG = tf.reshape(bigG, [self.nTheta, self.nObs, self.nLambda, self.m])
        bigG = tf.transpose(bigG, [1,3,2,0])
        # bigG.shape: nObs, m, nLambda, nTheta
        
        # Rin_alphaMat.shape: nLambda, nTheta
        alphaArray = tf.reshape(self.Rin_alphaMat, [1, 1, self.nLambda, self.nTheta])
        alphaArray = tf.tile(alphaArray, [self.nObs, self.m, 1, 1])
        
        self.im = tf.sqrt(1-alphaArray) * bigG + \
            tf.sqrt(alphaArray) * tf.reshape(normal[:,:,:,1], alphaArray.shape)
        self.im = tf.reshape(self.im, [self.nObs, self.m*self.nLambda*self.nTheta])
        self.im = tf.reshape(tf.transpose(self.im), [self.m*self.nLambda*self.nTheta, self.N, self.N])
        self.im = tf.expand_dims(self.im, 3)
        
        # Rin_y: [lambda, theta]
        self.y = tf.reshape(self.Rin_y, [self.nTheta, self.nLambda, 2, 1])
        self.y = tf.transpose(self.y, [2, 3, 1, 0])
        self.y = tf.tile(self.y, [1, self.m, 1, 1])
        self.y = tf.transpose(tf.reshape(self.y, [2, self.m*self.nLambda*self.nTheta]))

    def squared_diff(self, i, im):
        """ compute the sqared difference when shifting image. Helper function for vgram()"""
        # self.x: input data with shape NHWC
        # i: int index to go out
        dist = np.sqrt(i**2 + np.arange(0,i+1)**2)
        if i == 1:
            ix = [[i, 0], [i, -i]]
            iy = [[0, i], [i,  i]]
        else:
            ix = [[i, k] for k in range(1,i)]
            ix.insert(0, [i, 0])
            ix.append([i, -i])
            iy = [[k, i] for k in range(1,i)]
            iy.insert(0, [0, i])
            iy.append([i, i])
        diff = []
        w = np.zeros(len(dist))
        for j in range(len(dist)):
            w[j] = (im.shape[1]-ix[j][0]) * (im.shape[2]-iy[j][0]) * 2
            if j == 0:
                tmp = [tf.expand_dims(
                    tf.reduce_sum(tf.math.squared_difference(im[:, ix[j][k]:, iy[j][k]:, :],
                                                             im[:, 0:(im.shape[1]-ix[j][k]), 0:(im.shape[2]-iy[j][k]), :]),
                                  axis=[1,2]), axis=2)
                       for k in range(2)]
                tmp = tf.expand_dims(tf.reduce_sum(tf.concat(tmp, axis=2), axis=2), axis=2)
            elif j == len(dist)-1:
                tmp1 = tf.expand_dims(
                    tf.reduce_sum(tf.math.squared_difference(im[:, ix[j][0]:, iy[j][0]:, :],
                                                             im[:, 0:(im.shape[1]-ix[j][0]), 0:(im.shape[2]-iy[j][0]), :]),
                                  axis=[1,2]), axis=2)
                tmp2 = tf.expand_dims(
                    tf.reduce_sum(tf.math.squared_difference(im[:, 0:(im.shape[1]-ix[j][0]), iy[j][0]:, :],
                                                             im[:, ix[j][0]:, 0:(im.shape[2]-iy[j][0]), :]),
                                  axis=[1,2]), axis=2)
                tmp = tf.expand_dims(tf.reduce_sum(tf.concat([tmp1, tmp2], axis=2), axis=2), axis=2)
            else:
                w[j] *= 2
                tmp1 = [tf.expand_dims(
                    tf.reduce_sum(tf.math.squared_difference(im[:, ix[j][k]:, iy[j][k]:, :],
                                                             im[:, 0:(im.shape[1]-ix[j][k]), 0:(im.shape[2]-iy[j][k]), :]),
                                  axis=[1,2]), axis=2)
                        for k in range(2)]
                tmp1 = tf.expand_dims(tf.reduce_sum(tf.concat(tmp1, axis=2), axis=2), axis=2)
                tmp2 = [tf.expand_dims( # x shifted in other direction ..
                    tf.reduce_sum(tf.math.squared_difference(im[:, 0:(im.shape[1]-ix[j][k]), iy[j][k]:, :],
                                                             im[:, ix[j][k]:, 0:(im.shape[2]-iy[j][k]), :]),
                                  axis=[1,2]), axis=2)
                        for k in range(2)]
                tmp2 = tf.expand_dims(tf.reduce_sum(tf.concat(tmp2, axis=2), axis=2), axis=2)
                tmp = tf.expand_dims(tf.reduce_sum(tf.concat([tmp1, tmp2], axis=2), axis=2), axis=2)
            diff.append(tmp / w[j])
        diff = tf.concat(diff, axis=2)
        return diff, dist, w

    def vgram(self, im=None, verbose=None):
        """compute variograms from images"""
        if im is None:
            return_flag = False
            im = self.im
        else:
            return_flag = True
        if verbose is None:
            verbose = self.verbose
        if verbose:
            if not return_flag:
                tf.print(', vgrams', end='')
            else:
                tf.print('vgrams.')
        diff, dist, w = self.squared_diff(i=1, im=im)
        for i in range(2, im.shape[1]): # probably tf.map_fn would be faster
            tmp_diff, tmp_dist, tmp_w = self.squared_diff(i=i, im=im)
            diff = tf.concat([diff, tmp_diff], axis=2)
            dist = np.concatenate([dist, tmp_dist])
            w    = np.concatenate([w, tmp_w])
        # sort according to dist
        ind  = tf.argsort(dist)
        diff = tf.gather(diff, ind, axis=2)
        dist = tf.gather(dist, ind)
        w    = tf.gather(w,    ind)
        # combine results with same dist
        diff = tf.cast(diff, dtype=tf.float32)
        w = tf.cast(w, dtype=tf.float32)
        uni = tf.unique(dist)[1]
        dist = tf.math.segment_sum(dist, uni)
        tmp1 = tf.transpose(diff * tf.tile(tf.reshape(w, [1,1,len(w)]),
                                           [diff.shape[0],diff.shape[1],1]), [2,0,1])
        diff = tf.transpose(tf.math.segment_sum(tmp1, uni), [1,2,0])
        w = tf.math.segment_sum(w, uni)
        diff /= tf.tile(tf.reshape(w, [1,1,len(w)]), [diff.shape[0],diff.shape[1], 1])
                        
        vg = tf.transpose(tf.expand_dims(diff, 3), [0,2,3,1]) / 2
        if return_flag:
            return vg, dist, w
        else:
            self.vg   = vg # NWH(=1)C
            self.dist = dist
            self.w    = w
            
    def on_epoch_end(self):
      """generate new data at the end of each epoch"""
        self.generate_im()
        if self.vgrams:
            self.vgram()
            #self.im = None # free memory
        elif self.flip_transpose:
            self.flip_transpose_fn()
        if self.random_shuffle:
            if self.verbose:
                tf.print(', shuffle', end='')
            indices = tf.range(start=0, limit=tf.shape(self.y)[0], dtype=tf.int32)
            indices = tf.random.shuffle(indices)
            self.y = tf.gather(self.y, indices)
            self.im = tf.gather(self.im, indices)
            if self.vgrams:
                self.vg = tf.gather(self.vg, indices)
        if self.verbose:
              tf.print('.')
             

    def __len__(self):
        leng, rem = divmod(self.y.shape[0], self.batch_size)
        return (leng + (1 if rem > 0 else 0))

    def __getitem__(self,i):
        start = i*self.batch_size
        end = start + self.batch_size
        if self.vgrams:
            x = self.vg[start:end,:,:,:]
        else:
            x = self.im[start:end,:,:,:]
        y = self.y[start:end,:]
        return x, y

# %% [markdown]
# # Load data input for generator.
#
# *   can be generated with `makeTrainingData.R`

# %%
# !mkdir -p npy
# !wget -P npy/ https://www.dropbox.com/s/5d4ze60wg4b81ed/training_201_200_alphaMat.npy?dl=1
# !wget -P npy/ https://www.dropbox.com/s/3wp3du0u45sbxcd/training_201_200_chols.npy?dl=1
# !wget -P npy/ https://www.dropbox.com/s/0ya8ukx7vuy9fr4/training_201_200_thetaGrid.npy?dl=1
# !wget -P npy/ https://www.dropbox.com/s/7m31iqek7mhnqno/training_201_200_y.npy?dl=1
# Out:
# --2020-11-11 21:39:53--  https://www.dropbox.com/s/5d4ze60wg4b81ed/training_201_200_alphaMat.npy?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/5d4ze60wg4b81ed/training_201_200_alphaMat.npy [following]
# --2020-11-11 21:39:54--  https://www.dropbox.com/s/dl/5d4ze60wg4b81ed/training_201_200_alphaMat.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc0eb25dd3b417241ecd6449e71.dl.dropboxusercontent.com/cd/0/get/BDD2EBJGOqSTfQ8mJP2hKqTCdeo9XWhK2ai8jYP__Q3kP3G5NkKlcaRej6WD4N8oV0iua7J_hi2Nhe7r40qTbqUWPDc9Rzu6Vu7lzdN9kiEREYbg2Elknb3gM5Bw1ZmYCYE/file?dl=1# [following]
# --2020-11-11 21:39:54--  https://ucc0eb25dd3b417241ecd6449e71.dl.dropboxusercontent.com/cd/0/get/BDD2EBJGOqSTfQ8mJP2hKqTCdeo9XWhK2ai8jYP__Q3kP3G5NkKlcaRej6WD4N8oV0iua7J_hi2Nhe7r40qTbqUWPDc9Rzu6Vu7lzdN9kiEREYbg2Elknb3gM5Bw1ZmYCYE/file?dl=1
# Resolving ucc0eb25dd3b417241ecd6449e71.dl.dropboxusercontent.com (ucc0eb25dd3b417241ecd6449e71.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to ucc0eb25dd3b417241ecd6449e71.dl.dropboxusercontent.com (ucc0eb25dd3b417241ecd6449e71.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 321728 (314K) [application/binary]
# Saving to: ‘npy/training_201_200_alphaMat.npy?dl=1.1’
#
# training_201_200_al 100%[===================>] 314.19K  --.-KB/s    in 0.03s
#
# 2020-11-11 21:39:54 (9.32 MB/s) - ‘npy/training_201_200_alphaMat.npy?dl=1.1’ saved [321728/321728]
#
# --2020-11-11 21:39:54--  https://www.dropbox.com/s/3wp3du0u45sbxcd/training_201_200_chols.npy?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/3wp3du0u45sbxcd/training_201_200_chols.npy [following]
# --2020-11-11 21:39:54--  https://www.dropbox.com/s/dl/3wp3du0u45sbxcd/training_201_200_chols.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce83b580004841c343c8dd5930a.dl.dropboxusercontent.com/cd/0/get/BDA_YsX4LWrbvbLkaaXWdfAItrM7ilL_s5ms8YM532_WVPmBRmZ4Mgpw4GcIChHq1UFlole-ox3F7WaEz5Xr6lY-7LArUNP-2Plw6YSCqeqZl1_u5nxttOgcOSttRF45B1Y/file?dl=1# [following]
# --2020-11-11 21:39:55--  https://uce83b580004841c343c8dd5930a.dl.dropboxusercontent.com/cd/0/get/BDA_YsX4LWrbvbLkaaXWdfAItrM7ilL_s5ms8YM532_WVPmBRmZ4Mgpw4GcIChHq1UFlole-ox3F7WaEz5Xr6lY-7LArUNP-2Plw6YSCqeqZl1_u5nxttOgcOSttRF45B1Y/file?dl=1
# Resolving uce83b580004841c343c8dd5930a.dl.dropboxusercontent.com (uce83b580004841c343c8dd5930a.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uce83b580004841c343c8dd5930a.dl.dropboxusercontent.com (uce83b580004841c343c8dd5930a.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104857728 (100M) [application/binary]
# Saving to: ‘npy/training_201_200_chols.npy?dl=1.1’
#
# training_201_200_ch 100%[===================>] 100.00M  78.5MB/s    in 1.3s
#
# 2020-11-11 21:39:57 (78.5 MB/s) - ‘npy/training_201_200_chols.npy?dl=1.1’ saved [104857728/104857728]
#
# --2020-11-11 21:39:57--  https://www.dropbox.com/s/0ya8ukx7vuy9fr4/training_201_200_thetaGrid.npy?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/0ya8ukx7vuy9fr4/training_201_200_thetaGrid.npy [following]
# --2020-11-11 21:39:57--  https://www.dropbox.com/s/dl/0ya8ukx7vuy9fr4/training_201_200_thetaGrid.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd1078bc34ce9e998c79539ea92.dl.dropboxusercontent.com/cd/0/get/BDBmfiMPPT687Bekz2yTMdzEmfUKE6S2E1ROTvf8nGbHz-ZnnaUAtl9UzmEAuNKaS-Y7rvOxt5NmtvG6jSNXWCV6cY_b4iuk6h-oYLXUOYkigKm5AguzvnU0y87-W5YPA4o/file?dl=1# [following]
# --2020-11-11 21:39:57--  https://ucd1078bc34ce9e998c79539ea92.dl.dropboxusercontent.com/cd/0/get/BDBmfiMPPT687Bekz2yTMdzEmfUKE6S2E1ROTvf8nGbHz-ZnnaUAtl9UzmEAuNKaS-Y7rvOxt5NmtvG6jSNXWCV6cY_b4iuk6h-oYLXUOYkigKm5AguzvnU0y87-W5YPA4o/file?dl=1
# Resolving ucd1078bc34ce9e998c79539ea92.dl.dropboxusercontent.com (ucd1078bc34ce9e998c79539ea92.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to ucd1078bc34ce9e998c79539ea92.dl.dropboxusercontent.com (ucd1078bc34ce9e998c79539ea92.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1728 (1.7K) [application/binary]
# Saving to: ‘npy/training_201_200_thetaGrid.npy?dl=1.1’
#
# training_201_200_th 100%[===================>]   1.69K  --.-KB/s    in 0s
#
# 2020-11-11 21:40:00 (321 MB/s) - ‘npy/training_201_200_thetaGrid.npy?dl=1.1’ saved [1728/1728]
#
# --2020-11-11 21:40:00--  https://www.dropbox.com/s/7m31iqek7mhnqno/training_201_200_y.npy?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/7m31iqek7mhnqno/training_201_200_y.npy [following]
# --2020-11-11 21:40:00--  https://www.dropbox.com/s/dl/7m31iqek7mhnqno/training_201_200_y.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc987db67a4115e293299e456684.dl.dropboxusercontent.com/cd/0/get/BDBGghBCSnnKDx-dN8ZwyidbCqKAnQEtmXC8h9UqMdyKOyBB6-n6mTDqRrBde6f3aaOpb-qwHEiWwimQRCmqXQaGx2dvx9Q53iWfjwthc3Dbf4bLmnnV7g2j8SDURO5rxhA/file?dl=1# [following]
# --2020-11-11 21:40:00--  https://uc987db67a4115e293299e456684.dl.dropboxusercontent.com/cd/0/get/BDBGghBCSnnKDx-dN8ZwyidbCqKAnQEtmXC8h9UqMdyKOyBB6-n6mTDqRrBde6f3aaOpb-qwHEiWwimQRCmqXQaGx2dvx9Q53iWfjwthc3Dbf4bLmnnV7g2j8SDURO5rxhA/file?dl=1
# Resolving uc987db67a4115e293299e456684.dl.dropboxusercontent.com (uc987db67a4115e293299e456684.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc987db67a4115e293299e456684.dl.dropboxusercontent.com (uc987db67a4115e293299e456684.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 643328 (628K) [application/binary]
# Saving to: ‘npy/training_201_200_y.npy?dl=1.1’
#
# training_201_200_y. 100%[===================>] 628.25K  --.-KB/s    in 0.08s
#
# 2020-11-11 21:40:00 (8.15 MB/s) - ‘npy/training_201_200_y.npy?dl=1.1’ saved [643328/643328]

# %% [markdown]
# Make instance of generator...

# %%
generator = ImageVariogramGenerator(path_prefix = 'npy/training_201_200', path_suffix='?dl=1', replicates=3, vgrams=True, flip_transpose = False, random_shuffle=True)
## each epoch trains with this amount of images:
print('vg.shape: ', generator.vg.shape, ', y.shape', generator.y.shape)
# Out:
# generate data, vgrams, shuffle.
# vg.shape:  (120600, 119, 1, 1) , y.shape (120600, 2)

# %%
n_plot= 1000
plt.plot(np.transpose(generator.vg.numpy()[0:n_plot,:,0,0]), alpha=0.5);
plt.title(str(n_plot) + ' random variograms');

# %% [markdown]
# # Define and train model

# %%
model1 = tf.keras.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(3000, activation='relu'),
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dense(2),
])
model1.compile(optimizer= tf.keras.optimizers.Adam(), 
               loss=tf.keras.losses.MeanAbsoluteError(),
               metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath='model_NV',
    save_weights_only=False, monitor='loss', mode='min', save_best_only=True)

# %%
# %%time
history1 = model1.fit(x=generator, epochs=1000, batch_size = 200, callbacks=[checkpoint_callback], verbose=2)
# Out:
# Epoch 1/1000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.3968 - root_mean_squared_error: 0.5430
# generate data, vgrams, shuffle.
# Epoch 2/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2970 - root_mean_squared_error: 0.4179
# generate data, vgrams, shuffle.
# Epoch 3/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2730 - root_mean_squared_error: 0.3937
# generate data, vgrams, shuffle.
# Epoch 4/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2582 - root_mean_squared_error: 0.3781
# generate data, vgrams, shuffle.
# Epoch 5/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2492 - root_mean_squared_error: 0.3696
# generate data, vgrams, shuffle.
# Epoch 6/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2407 - root_mean_squared_error: 0.3592
# generate data, vgrams, shuffle.
# Epoch 7/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2347 - root_mean_squared_error: 0.3535
# generate data, vgrams, shuffle.
# Epoch 8/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2328 - root_mean_squared_error: 0.3513
# generate data, vgrams, shuffle.
# Epoch 9/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2282 - root_mean_squared_error: 0.3465
# generate data, vgrams, shuffle.
# Epoch 10/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2281 - root_mean_squared_error: 0.3465
# generate data, vgrams, shuffle.
# Epoch 11/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2241 - root_mean_squared_error: 0.3423
# generate data, vgrams, shuffle.
# Epoch 12/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2231 - root_mean_squared_error: 0.3409
# generate data, vgrams, shuffle.
# Epoch 13/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2192 - root_mean_squared_error: 0.3365
# generate data, vgrams, shuffle.
# Epoch 14/1000
# 472/472 - 2s - loss: 0.2198 - root_mean_squared_error: 0.3376
# generate data, vgrams, shuffle.
# Epoch 15/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2148 - root_mean_squared_error: 0.3319
# generate data, vgrams, shuffle.
# Epoch 16/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2146 - root_mean_squared_error: 0.3320
# generate data, vgrams, shuffle.
# Epoch 17/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2125 - root_mean_squared_error: 0.3293
# generate data, vgrams, shuffle.
# Epoch 18/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2119 - root_mean_squared_error: 0.3285
# generate data, vgrams, shuffle.
# Epoch 19/1000
# 472/472 - 2s - loss: 0.2120 - root_mean_squared_error: 0.3304
# generate data, vgrams, shuffle.
# Epoch 20/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2101 - root_mean_squared_error: 0.3264
# generate data, vgrams, shuffle.
# Epoch 21/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2082 - root_mean_squared_error: 0.3249
# generate data, vgrams, shuffle.
# Epoch 22/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2067 - root_mean_squared_error: 0.3232
# generate data, vgrams, shuffle.
# Epoch 23/1000
# 472/472 - 2s - loss: 0.2071 - root_mean_squared_error: 0.3238
# generate data, vgrams, shuffle.
# Epoch 24/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2050 - root_mean_squared_error: 0.3215
# generate data, vgrams, shuffle.
# Epoch 25/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2049 - root_mean_squared_error: 0.3207
# generate data, vgrams, shuffle.
# Epoch 26/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2048 - root_mean_squared_error: 0.3213
# generate data, vgrams, shuffle.
# Epoch 27/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2037 - root_mean_squared_error: 0.3197
# generate data, vgrams, shuffle.
# Epoch 28/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2026 - root_mean_squared_error: 0.3189
# generate data, vgrams, shuffle.
# Epoch 29/1000
# 472/472 - 2s - loss: 0.2034 - root_mean_squared_error: 0.3197
# generate data, vgrams, shuffle.
# Epoch 30/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2011 - root_mean_squared_error: 0.3173
# generate data, vgrams, shuffle.
# Epoch 31/1000
# 472/472 - 2s - loss: 0.2015 - root_mean_squared_error: 0.3178
# generate data, vgrams, shuffle.
# Epoch 32/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2005 - root_mean_squared_error: 0.3160
# generate data, vgrams, shuffle.
# Epoch 33/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.2000 - root_mean_squared_error: 0.3161
# generate data, vgrams, shuffle.
# Epoch 34/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1983 - root_mean_squared_error: 0.3133
# generate data, vgrams, shuffle.
# Epoch 35/1000
# 472/472 - 2s - loss: 0.2000 - root_mean_squared_error: 0.3150
# generate data, vgrams, shuffle.
# Epoch 36/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1978 - root_mean_squared_error: 0.3129
# generate data, vgrams, shuffle.
# Epoch 37/1000
# 472/472 - 2s - loss: 0.1979 - root_mean_squared_error: 0.3143
# generate data, vgrams, shuffle.
# Epoch 38/1000
# 472/472 - 2s - loss: 0.1983 - root_mean_squared_error: 0.3137
# generate data, vgrams, shuffle.
# Epoch 39/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1967 - root_mean_squared_error: 0.3117
# generate data, vgrams, shuffle.
# Epoch 40/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1963 - root_mean_squared_error: 0.3122
# generate data, vgrams, shuffle.
# Epoch 41/1000
# 472/472 - 2s - loss: 0.1968 - root_mean_squared_error: 0.3123
# generate data, vgrams, shuffle.
# Epoch 42/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1955 - root_mean_squared_error: 0.3109
# generate data, vgrams, shuffle.
# Epoch 43/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1952 - root_mean_squared_error: 0.3108
# generate data, vgrams, shuffle.
# Epoch 44/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1922 - root_mean_squared_error: 0.3069
# generate data, vgrams, shuffle.
# Epoch 45/1000
# 472/472 - 2s - loss: 0.1958 - root_mean_squared_error: 0.3113
# generate data, vgrams, shuffle.
# Epoch 46/1000
# 472/472 - 2s - loss: 0.1937 - root_mean_squared_error: 0.3086
# generate data, vgrams, shuffle.
# Epoch 47/1000
# 472/472 - 2s - loss: 0.1942 - root_mean_squared_error: 0.3087
# generate data, vgrams, shuffle.
# Epoch 48/1000
# 472/472 - 2s - loss: 0.1938 - root_mean_squared_error: 0.3087
# generate data, vgrams, shuffle.
# Epoch 49/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1922 - root_mean_squared_error: 0.3073
# generate data, vgrams, shuffle.
# Epoch 50/1000
# 472/472 - 2s - loss: 0.1936 - root_mean_squared_error: 0.3092
# generate data, vgrams, shuffle.
# Epoch 51/1000
# 472/472 - 2s - loss: 0.1931 - root_mean_squared_error: 0.3087
# generate data, vgrams, shuffle.
# Epoch 52/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1910 - root_mean_squared_error: 0.3062
# generate data, vgrams, shuffle.
# Epoch 53/1000
# 472/472 - 2s - loss: 0.1928 - root_mean_squared_error: 0.3076
# generate data, vgrams, shuffle.
# Epoch 54/1000
# 472/472 - 2s - loss: 0.1924 - root_mean_squared_error: 0.3072
# generate data, vgrams, shuffle.
# Epoch 55/1000
# 472/472 - 2s - loss: 0.1916 - root_mean_squared_error: 0.3071
# generate data, vgrams, shuffle.
# Epoch 56/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1900 - root_mean_squared_error: 0.3044
# generate data, vgrams, shuffle.
# Epoch 57/1000
# 472/472 - 2s - loss: 0.1922 - root_mean_squared_error: 0.3071
# generate data, vgrams, shuffle.
# Epoch 58/1000
# 472/472 - 2s - loss: 0.1904 - root_mean_squared_error: 0.3053
# generate data, vgrams, shuffle.
# Epoch 59/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1887 - root_mean_squared_error: 0.3032
# generate data, vgrams, shuffle.
# Epoch 60/1000
# 472/472 - 2s - loss: 0.1921 - root_mean_squared_error: 0.3068
# generate data, vgrams, shuffle.
# Epoch 61/1000
# 472/472 - 2s - loss: 0.1906 - root_mean_squared_error: 0.3057
# generate data, vgrams, shuffle.
# Epoch 62/1000
# 472/472 - 2s - loss: 0.1901 - root_mean_squared_error: 0.3044
# generate data, vgrams, shuffle.
# Epoch 63/1000
# 472/472 - 2s - loss: 0.1905 - root_mean_squared_error: 0.3057
# generate data, vgrams, shuffle.
# Epoch 64/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1879 - root_mean_squared_error: 0.3018
# generate data, vgrams, shuffle.
# Epoch 65/1000
# 472/472 - 2s - loss: 0.1905 - root_mean_squared_error: 0.3053
# generate data, vgrams, shuffle.
# Epoch 66/1000
# 472/472 - 2s - loss: 0.1882 - root_mean_squared_error: 0.3026
# generate data, vgrams, shuffle.
# Epoch 67/1000
# 472/472 - 2s - loss: 0.1891 - root_mean_squared_error: 0.3038
# generate data, vgrams, shuffle.
# Epoch 68/1000
# 472/472 - 2s - loss: 0.1887 - root_mean_squared_error: 0.3043
# generate data, vgrams, shuffle.
# Epoch 69/1000
# 472/472 - 2s - loss: 0.1893 - root_mean_squared_error: 0.3044
# generate data, vgrams, shuffle.
# Epoch 70/1000
# 472/472 - 2s - loss: 0.1880 - root_mean_squared_error: 0.3031
# generate data, vgrams, shuffle.
# Epoch 71/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1878 - root_mean_squared_error: 0.3024
# generate data, vgrams, shuffle.
# Epoch 72/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1866 - root_mean_squared_error: 0.3007
# generate data, vgrams, shuffle.
# Epoch 73/1000
# 472/472 - 2s - loss: 0.1897 - root_mean_squared_error: 0.3046
# generate data, vgrams, shuffle.
# Epoch 74/1000
# 472/472 - 2s - loss: 0.1871 - root_mean_squared_error: 0.3006
# generate data, vgrams, shuffle.
# Epoch 75/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1865 - root_mean_squared_error: 0.3013
# generate data, vgrams, shuffle.
# Epoch 76/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1861 - root_mean_squared_error: 0.3001
# generate data, vgrams, shuffle.
# Epoch 77/1000
# 472/472 - 2s - loss: 0.1870 - root_mean_squared_error: 0.3017
# generate data, vgrams, shuffle.
# Epoch 78/1000
# 472/472 - 2s - loss: 0.1870 - root_mean_squared_error: 0.3015
# generate data, vgrams, shuffle.
# Epoch 79/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1860 - root_mean_squared_error: 0.3004
# generate data, vgrams, shuffle.
# Epoch 80/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1854 - root_mean_squared_error: 0.2993
# generate data, vgrams, shuffle.
# Epoch 81/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1845 - root_mean_squared_error: 0.2987
# generate data, vgrams, shuffle.
# Epoch 82/1000
# 472/472 - 2s - loss: 0.1858 - root_mean_squared_error: 0.2997
# generate data, vgrams, shuffle.
# Epoch 83/1000
# 472/472 - 2s - loss: 0.1850 - root_mean_squared_error: 0.2988
# generate data, vgrams, shuffle.
# Epoch 84/1000
# 472/472 - 2s - loss: 0.1854 - root_mean_squared_error: 0.2993
# generate data, vgrams, shuffle.
# Epoch 85/1000
# 472/472 - 2s - loss: 0.1855 - root_mean_squared_error: 0.2998
# generate data, vgrams, shuffle.
# Epoch 86/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1840 - root_mean_squared_error: 0.2983
# generate data, vgrams, shuffle.
# Epoch 87/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1838 - root_mean_squared_error: 0.2981
# generate data, vgrams, shuffle.
# Epoch 88/1000
# 472/472 - 2s - loss: 0.1851 - root_mean_squared_error: 0.2992
# generate data, vgrams, shuffle.
# Epoch 89/1000
# 472/472 - 2s - loss: 0.1848 - root_mean_squared_error: 0.2987
# generate data, vgrams, shuffle.
# Epoch 90/1000
# 472/472 - 2s - loss: 0.1849 - root_mean_squared_error: 0.2982
# generate data, vgrams, shuffle.
# Epoch 91/1000
# 472/472 - 2s - loss: 0.1851 - root_mean_squared_error: 0.2988
# generate data, vgrams, shuffle.
# Epoch 92/1000
# 472/472 - 2s - loss: 0.1855 - root_mean_squared_error: 0.2990
# generate data, vgrams, shuffle.
# Epoch 93/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1835 - root_mean_squared_error: 0.2966
# generate data, vgrams, shuffle.
# Epoch 94/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1829 - root_mean_squared_error: 0.2964
# generate data, vgrams, shuffle.
# Epoch 95/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1824 - root_mean_squared_error: 0.2965
# generate data, vgrams, shuffle.
# Epoch 96/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1816 - root_mean_squared_error: 0.2951
# generate data, vgrams, shuffle.
# Epoch 97/1000
# 472/472 - 2s - loss: 0.1830 - root_mean_squared_error: 0.2968
# generate data, vgrams, shuffle.
# Epoch 98/1000
# 472/472 - 2s - loss: 0.1828 - root_mean_squared_error: 0.2962
# generate data, vgrams, shuffle.
# Epoch 99/1000
# 472/472 - 2s - loss: 0.1839 - root_mean_squared_error: 0.2985
# generate data, vgrams, shuffle.
# Epoch 100/1000
# 472/472 - 2s - loss: 0.1831 - root_mean_squared_error: 0.2962
# generate data, vgrams, shuffle.
# Epoch 101/1000
# 472/472 - 2s - loss: 0.1820 - root_mean_squared_error: 0.2959
# generate data, vgrams, shuffle.
# Epoch 102/1000
# 472/472 - 2s - loss: 0.1846 - root_mean_squared_error: 0.2982
# generate data, vgrams, shuffle.
# Epoch 103/1000
# 472/472 - 2s - loss: 0.1821 - root_mean_squared_error: 0.2959
# generate data, vgrams, shuffle.
# Epoch 104/1000
# 472/472 - 2s - loss: 0.1834 - root_mean_squared_error: 0.2974
# generate data, vgrams, shuffle.
# Epoch 105/1000
# 472/472 - 2s - loss: 0.1836 - root_mean_squared_error: 0.2976
# generate data, vgrams, shuffle.
# Epoch 106/1000
# 472/472 - 2s - loss: 0.1822 - root_mean_squared_error: 0.2957
# generate data, vgrams, shuffle.
# Epoch 107/1000
# 472/472 - 2s - loss: 0.1818 - root_mean_squared_error: 0.2954
# generate data, vgrams, shuffle.
# Epoch 108/1000
# 472/472 - 2s - loss: 0.1828 - root_mean_squared_error: 0.2964
# generate data, vgrams, shuffle.
# Epoch 109/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1804 - root_mean_squared_error: 0.2937
# generate data, vgrams, shuffle.
# Epoch 110/1000
# 472/472 - 2s - loss: 0.1819 - root_mean_squared_error: 0.2959
# generate data, vgrams, shuffle.
# Epoch 111/1000
# 472/472 - 2s - loss: 0.1834 - root_mean_squared_error: 0.2973
# generate data, vgrams, shuffle.
# Epoch 112/1000
# 472/472 - 2s - loss: 0.1822 - root_mean_squared_error: 0.2957
# generate data, vgrams, shuffle.
# Epoch 113/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1797 - root_mean_squared_error: 0.2930
# generate data, vgrams, shuffle.
# Epoch 114/1000
# 472/472 - 2s - loss: 0.1815 - root_mean_squared_error: 0.2955
# generate data, vgrams, shuffle.
# Epoch 115/1000
# 472/472 - 2s - loss: 0.1816 - root_mean_squared_error: 0.2947
# generate data, vgrams, shuffle.
# Epoch 116/1000
# 472/472 - 2s - loss: 0.1804 - root_mean_squared_error: 0.2935
# generate data, vgrams, shuffle.
# Epoch 117/1000
# 472/472 - 2s - loss: 0.1819 - root_mean_squared_error: 0.2954
# generate data, vgrams, shuffle.
# Epoch 118/1000
# 472/472 - 2s - loss: 0.1841 - root_mean_squared_error: 0.2987
# generate data, vgrams, shuffle.
# Epoch 119/1000
# 472/472 - 2s - loss: 0.1821 - root_mean_squared_error: 0.2961
# generate data, vgrams, shuffle.
# Epoch 120/1000
# 472/472 - 2s - loss: 0.1812 - root_mean_squared_error: 0.2944
# generate data, vgrams, shuffle.
# Epoch 121/1000
# 472/472 - 2s - loss: 0.1815 - root_mean_squared_error: 0.2948
# generate data, vgrams, shuffle.
# Epoch 122/1000
# 472/472 - 2s - loss: 0.1799 - root_mean_squared_error: 0.2931
# generate data, vgrams, shuffle.
# Epoch 123/1000
# 472/472 - 2s - loss: 0.1813 - root_mean_squared_error: 0.2947
# generate data, vgrams, shuffle.
# Epoch 124/1000
# 472/472 - 2s - loss: 0.1810 - root_mean_squared_error: 0.2944
# generate data, vgrams, shuffle.
# Epoch 125/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1795 - root_mean_squared_error: 0.2927
# generate data, vgrams, shuffle.
# Epoch 126/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1791 - root_mean_squared_error: 0.2923
# generate data, vgrams, shuffle.
# Epoch 127/1000
# 472/472 - 2s - loss: 0.1800 - root_mean_squared_error: 0.2926
# generate data, vgrams, shuffle.
# Epoch 128/1000
# 472/472 - 2s - loss: 0.1798 - root_mean_squared_error: 0.2937
# generate data, vgrams, shuffle.
# Epoch 129/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1790 - root_mean_squared_error: 0.2916
# generate data, vgrams, shuffle.
# Epoch 130/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1778 - root_mean_squared_error: 0.2906
# generate data, vgrams, shuffle.
# Epoch 131/1000
# 472/472 - 2s - loss: 0.1801 - root_mean_squared_error: 0.2936
# generate data, vgrams, shuffle.
# Epoch 132/1000
# 472/472 - 2s - loss: 0.1784 - root_mean_squared_error: 0.2907
# generate data, vgrams, shuffle.
# Epoch 133/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1774 - root_mean_squared_error: 0.2897
# generate data, vgrams, shuffle.
# Epoch 134/1000
# 472/472 - 2s - loss: 0.1791 - root_mean_squared_error: 0.2922
# generate data, vgrams, shuffle.
# Epoch 135/1000
# 472/472 - 2s - loss: 0.1796 - root_mean_squared_error: 0.2932
# generate data, vgrams, shuffle.
# Epoch 136/1000
# 472/472 - 2s - loss: 0.1786 - root_mean_squared_error: 0.2918
# generate data, vgrams, shuffle.
# Epoch 137/1000
# 472/472 - 2s - loss: 0.1789 - root_mean_squared_error: 0.2925
# generate data, vgrams, shuffle.
# Epoch 138/1000
# 472/472 - 2s - loss: 0.1812 - root_mean_squared_error: 0.2947
# generate data, vgrams, shuffle.
# Epoch 139/1000
# 472/472 - 2s - loss: 0.1796 - root_mean_squared_error: 0.2930
# generate data, vgrams, shuffle.
# Epoch 140/1000
# 472/472 - 2s - loss: 0.1790 - root_mean_squared_error: 0.2921
# generate data, vgrams, shuffle.
# Epoch 141/1000
# 472/472 - 2s - loss: 0.1791 - root_mean_squared_error: 0.2932
# generate data, vgrams, shuffle.
# Epoch 142/1000
# 472/472 - 2s - loss: 0.1783 - root_mean_squared_error: 0.2911
# generate data, vgrams, shuffle.
# Epoch 143/1000
# 472/472 - 2s - loss: 0.1788 - root_mean_squared_error: 0.2921
# generate data, vgrams, shuffle.
# Epoch 144/1000
# 472/472 - 2s - loss: 0.1811 - root_mean_squared_error: 0.2948
# generate data, vgrams, shuffle.
# Epoch 145/1000
# 472/472 - 2s - loss: 0.1781 - root_mean_squared_error: 0.2918
# generate data, vgrams, shuffle.
# Epoch 146/1000
# 472/472 - 2s - loss: 0.1785 - root_mean_squared_error: 0.2918
# generate data, vgrams, shuffle.
# Epoch 147/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1772 - root_mean_squared_error: 0.2904
# generate data, vgrams, shuffle.
# Epoch 148/1000
# 472/472 - 2s - loss: 0.1798 - root_mean_squared_error: 0.2932
# generate data, vgrams, shuffle.
# Epoch 149/1000
# 472/472 - 2s - loss: 0.1783 - root_mean_squared_error: 0.2915
# generate data, vgrams, shuffle.
# Epoch 150/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1771 - root_mean_squared_error: 0.2902
# generate data, vgrams, shuffle.
# Epoch 151/1000
# 472/472 - 2s - loss: 0.1783 - root_mean_squared_error: 0.2912
# generate data, vgrams, shuffle.
# Epoch 152/1000
# 472/472 - 2s - loss: 0.1777 - root_mean_squared_error: 0.2904
# generate data, vgrams, shuffle.
# Epoch 153/1000
# 472/472 - 2s - loss: 0.1775 - root_mean_squared_error: 0.2907
# generate data, vgrams, shuffle.
# Epoch 154/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1770 - root_mean_squared_error: 0.2902
# generate data, vgrams, shuffle.
# Epoch 155/1000
# 472/472 - 2s - loss: 0.1772 - root_mean_squared_error: 0.2904
# generate data, vgrams, shuffle.
# Epoch 156/1000
# 472/472 - 2s - loss: 0.1785 - root_mean_squared_error: 0.2922
# generate data, vgrams, shuffle.
# Epoch 157/1000
# 472/472 - 2s - loss: 0.1777 - root_mean_squared_error: 0.2907
# generate data, vgrams, shuffle.
# Epoch 158/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1761 - root_mean_squared_error: 0.2888
# generate data, vgrams, shuffle.
# Epoch 159/1000
# 472/472 - 2s - loss: 0.1765 - root_mean_squared_error: 0.2889
# generate data, vgrams, shuffle.
# Epoch 160/1000
# 472/472 - 2s - loss: 0.1786 - root_mean_squared_error: 0.2912
# generate data, vgrams, shuffle.
# Epoch 161/1000
# 472/472 - 2s - loss: 0.1780 - root_mean_squared_error: 0.2915
# generate data, vgrams, shuffle.
# Epoch 162/1000
# 472/472 - 2s - loss: 0.1777 - root_mean_squared_error: 0.2905
# generate data, vgrams, shuffle.
# Epoch 163/1000
# 472/472 - 2s - loss: 0.1785 - root_mean_squared_error: 0.2916
# generate data, vgrams, shuffle.
# Epoch 164/1000
# 472/472 - 2s - loss: 0.1773 - root_mean_squared_error: 0.2905
# generate data, vgrams, shuffle.
# Epoch 165/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1759 - root_mean_squared_error: 0.2892
# generate data, vgrams, shuffle.
# Epoch 166/1000
# 472/472 - 2s - loss: 0.1771 - root_mean_squared_error: 0.2902
# generate data, vgrams, shuffle.
# Epoch 167/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1759 - root_mean_squared_error: 0.2887
# generate data, vgrams, shuffle.
# Epoch 168/1000
# 472/472 - 2s - loss: 0.1761 - root_mean_squared_error: 0.2886
# generate data, vgrams, shuffle.
# Epoch 169/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1754 - root_mean_squared_error: 0.2877
# generate data, vgrams, shuffle.
# Epoch 170/1000
# 472/472 - 2s - loss: 0.1763 - root_mean_squared_error: 0.2893
# generate data, vgrams, shuffle.
# Epoch 171/1000
# 472/472 - 2s - loss: 0.1782 - root_mean_squared_error: 0.2922
# generate data, vgrams, shuffle.
# Epoch 172/1000
# 472/472 - 2s - loss: 0.1756 - root_mean_squared_error: 0.2890
# generate data, vgrams, shuffle.
# Epoch 173/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1752 - root_mean_squared_error: 0.2881
# generate data, vgrams, shuffle.
# Epoch 174/1000
# 472/472 - 2s - loss: 0.1757 - root_mean_squared_error: 0.2879
# generate data, vgrams, shuffle.
# Epoch 175/1000
# 472/472 - 2s - loss: 0.1772 - root_mean_squared_error: 0.2906
# generate data, vgrams, shuffle.
# Epoch 176/1000
# 472/472 - 2s - loss: 0.1762 - root_mean_squared_error: 0.2891
# generate data, vgrams, shuffle.
# Epoch 177/1000
# 472/472 - 2s - loss: 0.1763 - root_mean_squared_error: 0.2885
# generate data, vgrams, shuffle.
# Epoch 178/1000
# 472/472 - 2s - loss: 0.1769 - root_mean_squared_error: 0.2900
# generate data, vgrams, shuffle.
# Epoch 179/1000
# 472/472 - 2s - loss: 0.1756 - root_mean_squared_error: 0.2880
# generate data, vgrams, shuffle.
# Epoch 180/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1749 - root_mean_squared_error: 0.2882
# generate data, vgrams, shuffle.
# Epoch 181/1000
# 472/472 - 2s - loss: 0.1761 - root_mean_squared_error: 0.2892
# generate data, vgrams, shuffle.
# Epoch 182/1000
# 472/472 - 2s - loss: 0.1765 - root_mean_squared_error: 0.2902
# generate data, vgrams, shuffle.
# Epoch 183/1000
# 472/472 - 2s - loss: 0.1773 - root_mean_squared_error: 0.2910
# generate data, vgrams, shuffle.
# Epoch 184/1000
# 472/472 - 2s - loss: 0.1763 - root_mean_squared_error: 0.2889
# generate data, vgrams, shuffle.
# Epoch 185/1000
# 472/472 - 2s - loss: 0.1762 - root_mean_squared_error: 0.2888
# generate data, vgrams, shuffle.
# Epoch 186/1000
# 472/472 - 2s - loss: 0.1763 - root_mean_squared_error: 0.2890
# generate data, vgrams, shuffle.
# Epoch 187/1000
# 472/472 - 2s - loss: 0.1750 - root_mean_squared_error: 0.2876
# generate data, vgrams, shuffle.
# Epoch 188/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1741 - root_mean_squared_error: 0.2859
# generate data, vgrams, shuffle.
# Epoch 189/1000
# 472/472 - 2s - loss: 0.1759 - root_mean_squared_error: 0.2880
# generate data, vgrams, shuffle.
# Epoch 190/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1735 - root_mean_squared_error: 0.2863
# generate data, vgrams, shuffle.
# Epoch 191/1000
# 472/472 - 2s - loss: 0.1743 - root_mean_squared_error: 0.2872
# generate data, vgrams, shuffle.
# Epoch 192/1000
# 472/472 - 2s - loss: 0.1769 - root_mean_squared_error: 0.2898
# generate data, vgrams, shuffle.
# Epoch 193/1000
# 472/472 - 2s - loss: 0.1750 - root_mean_squared_error: 0.2885
# generate data, vgrams, shuffle.
# Epoch 194/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1729 - root_mean_squared_error: 0.2852
# generate data, vgrams, shuffle.
# Epoch 195/1000
# 472/472 - 2s - loss: 0.1756 - root_mean_squared_error: 0.2879
# generate data, vgrams, shuffle.
# Epoch 196/1000
# 472/472 - 2s - loss: 0.1760 - root_mean_squared_error: 0.2894
# generate data, vgrams, shuffle.
# Epoch 197/1000
# 472/472 - 2s - loss: 0.1752 - root_mean_squared_error: 0.2878
# generate data, vgrams, shuffle.
# Epoch 198/1000
# 472/472 - 2s - loss: 0.1752 - root_mean_squared_error: 0.2879
# generate data, vgrams, shuffle.
# Epoch 199/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1727 - root_mean_squared_error: 0.2852
# generate data, vgrams, shuffle.
# Epoch 200/1000
# 472/472 - 2s - loss: 0.1762 - root_mean_squared_error: 0.2897
# generate data, vgrams, shuffle.
# Epoch 201/1000
# 472/472 - 2s - loss: 0.1749 - root_mean_squared_error: 0.2875
# generate data, vgrams, shuffle.
# Epoch 202/1000
# 472/472 - 2s - loss: 0.1735 - root_mean_squared_error: 0.2850
# generate data, vgrams, shuffle.
# Epoch 203/1000
# 472/472 - 2s - loss: 0.1762 - root_mean_squared_error: 0.2893
# generate data, vgrams, shuffle.
# Epoch 204/1000
# 472/472 - 2s - loss: 0.1749 - root_mean_squared_error: 0.2873
# generate data, vgrams, shuffle.
# Epoch 205/1000
# 472/472 - 2s - loss: 0.1757 - root_mean_squared_error: 0.2885
# generate data, vgrams, shuffle.
# Epoch 206/1000
# 472/472 - 2s - loss: 0.1734 - root_mean_squared_error: 0.2854
# generate data, vgrams, shuffle.
# Epoch 207/1000
# 472/472 - 2s - loss: 0.1767 - root_mean_squared_error: 0.2893
# generate data, vgrams, shuffle.
# Epoch 208/1000
# 472/472 - 2s - loss: 0.1756 - root_mean_squared_error: 0.2884
# generate data, vgrams, shuffle.
# Epoch 209/1000
# 472/472 - 2s - loss: 0.1765 - root_mean_squared_error: 0.2898
# generate data, vgrams, shuffle.
# Epoch 210/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1727 - root_mean_squared_error: 0.2854
# generate data, vgrams, shuffle.
# Epoch 211/1000
# 472/472 - 2s - loss: 0.1746 - root_mean_squared_error: 0.2869
# generate data, vgrams, shuffle.
# Epoch 212/1000
# 472/472 - 2s - loss: 0.1742 - root_mean_squared_error: 0.2874
# generate data, vgrams, shuffle.
# Epoch 213/1000
# 472/472 - 2s - loss: 0.1756 - root_mean_squared_error: 0.2889
# generate data, vgrams, shuffle.
# Epoch 214/1000
# 472/472 - 2s - loss: 0.1732 - root_mean_squared_error: 0.2856
# generate data, vgrams, shuffle.
# Epoch 215/1000
# 472/472 - 2s - loss: 0.1736 - root_mean_squared_error: 0.2851
# generate data, vgrams, shuffle.
# Epoch 216/1000
# 472/472 - 2s - loss: 0.1746 - root_mean_squared_error: 0.2874
# generate data, vgrams, shuffle.
# Epoch 217/1000
# 472/472 - 2s - loss: 0.1734 - root_mean_squared_error: 0.2857
# generate data, vgrams, shuffle.
# Epoch 218/1000
# 472/472 - 2s - loss: 0.1751 - root_mean_squared_error: 0.2881
# generate data, vgrams, shuffle.
# Epoch 219/1000
# 472/472 - 2s - loss: 0.1738 - root_mean_squared_error: 0.2865
# generate data, vgrams, shuffle.
# Epoch 220/1000
# 472/472 - 2s - loss: 0.1728 - root_mean_squared_error: 0.2849
# generate data, vgrams, shuffle.
# Epoch 221/1000
# 472/472 - 2s - loss: 0.1760 - root_mean_squared_error: 0.2902
# generate data, vgrams, shuffle.
# Epoch 222/1000
# 472/472 - 2s - loss: 0.1743 - root_mean_squared_error: 0.2874
# generate data, vgrams, shuffle.
# Epoch 223/1000
# 472/472 - 2s - loss: 0.1749 - root_mean_squared_error: 0.2877
# generate data, vgrams, shuffle.
# Epoch 224/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1723 - root_mean_squared_error: 0.2850
# generate data, vgrams, shuffle.
# Epoch 225/1000
# 472/472 - 2s - loss: 0.1730 - root_mean_squared_error: 0.2852
# generate data, vgrams, shuffle.
# Epoch 226/1000
# 472/472 - 2s - loss: 0.1733 - root_mean_squared_error: 0.2858
# generate data, vgrams, shuffle.
# Epoch 227/1000
# 472/472 - 2s - loss: 0.1735 - root_mean_squared_error: 0.2863
# generate data, vgrams, shuffle.
# Epoch 228/1000
# 472/472 - 2s - loss: 0.1730 - root_mean_squared_error: 0.2856
# generate data, vgrams, shuffle.
# Epoch 229/1000
# 472/472 - 2s - loss: 0.1746 - root_mean_squared_error: 0.2872
# generate data, vgrams, shuffle.
# Epoch 230/1000
# 472/472 - 2s - loss: 0.1738 - root_mean_squared_error: 0.2856
# generate data, vgrams, shuffle.
# Epoch 231/1000
# 472/472 - 2s - loss: 0.1726 - root_mean_squared_error: 0.2847
# generate data, vgrams, shuffle.
# Epoch 232/1000
# 472/472 - 2s - loss: 0.1730 - root_mean_squared_error: 0.2856
# generate data, vgrams, shuffle.
# Epoch 233/1000
# 472/472 - 2s - loss: 0.1733 - root_mean_squared_error: 0.2855
# generate data, vgrams, shuffle.
# Epoch 234/1000
# 472/472 - 2s - loss: 0.1735 - root_mean_squared_error: 0.2855
# generate data, vgrams, shuffle.
# Epoch 235/1000
# 472/472 - 2s - loss: 0.1743 - root_mean_squared_error: 0.2867
# generate data, vgrams, shuffle.
# Epoch 236/1000
# 472/472 - 2s - loss: 0.1727 - root_mean_squared_error: 0.2848
# generate data, vgrams, shuffle.
# Epoch 237/1000
# 472/472 - 2s - loss: 0.1728 - root_mean_squared_error: 0.2857
# generate data, vgrams, shuffle.
# Epoch 238/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1721 - root_mean_squared_error: 0.2850
# generate data, vgrams, shuffle.
# Epoch 239/1000
# 472/472 - 2s - loss: 0.1730 - root_mean_squared_error: 0.2852
# generate data, vgrams, shuffle.
# Epoch 240/1000
# 472/472 - 2s - loss: 0.1732 - root_mean_squared_error: 0.2857
# generate data, vgrams, shuffle.
# Epoch 241/1000
# 472/472 - 2s - loss: 0.1730 - root_mean_squared_error: 0.2855
# generate data, vgrams, shuffle.
# Epoch 242/1000
# 472/472 - 2s - loss: 0.1730 - root_mean_squared_error: 0.2854
# generate data, vgrams, shuffle.
# Epoch 243/1000
# 472/472 - 2s - loss: 0.1747 - root_mean_squared_error: 0.2880
# generate data, vgrams, shuffle.
# Epoch 244/1000
# 472/472 - 2s - loss: 0.1732 - root_mean_squared_error: 0.2861
# generate data, vgrams, shuffle.
# Epoch 245/1000
# 472/472 - 2s - loss: 0.1731 - root_mean_squared_error: 0.2860
# generate data, vgrams, shuffle.
# Epoch 246/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1715 - root_mean_squared_error: 0.2832
# generate data, vgrams, shuffle.
# Epoch 247/1000
# 472/472 - 2s - loss: 0.1724 - root_mean_squared_error: 0.2844
# generate data, vgrams, shuffle.
# Epoch 248/1000
# 472/472 - 2s - loss: 0.1722 - root_mean_squared_error: 0.2849
# generate data, vgrams, shuffle.
# Epoch 249/1000
# 472/472 - 2s - loss: 0.1731 - root_mean_squared_error: 0.2859
# generate data, vgrams, shuffle.
# Epoch 250/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1712 - root_mean_squared_error: 0.2831
# generate data, vgrams, shuffle.
# Epoch 251/1000
# 472/472 - 2s - loss: 0.1716 - root_mean_squared_error: 0.2832
# generate data, vgrams, shuffle.
# Epoch 252/1000
# 472/472 - 2s - loss: 0.1731 - root_mean_squared_error: 0.2860
# generate data, vgrams, shuffle.
# Epoch 253/1000
# 472/472 - 2s - loss: 0.1723 - root_mean_squared_error: 0.2848
# generate data, vgrams, shuffle.
# Epoch 254/1000
# 472/472 - 2s - loss: 0.1718 - root_mean_squared_error: 0.2845
# generate data, vgrams, shuffle.
# Epoch 255/1000
# 472/472 - 2s - loss: 0.1717 - root_mean_squared_error: 0.2840
# generate data, vgrams, shuffle.
# Epoch 256/1000
# 472/472 - 2s - loss: 0.1720 - root_mean_squared_error: 0.2843
# generate data, vgrams, shuffle.
# Epoch 257/1000
# 472/472 - 2s - loss: 0.1712 - root_mean_squared_error: 0.2836
# generate data, vgrams, shuffle.
# Epoch 258/1000
# 472/472 - 2s - loss: 0.1724 - root_mean_squared_error: 0.2845
# generate data, vgrams, shuffle.
# Epoch 259/1000
# 472/472 - 2s - loss: 0.1724 - root_mean_squared_error: 0.2849
# generate data, vgrams, shuffle.
# Epoch 260/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1710 - root_mean_squared_error: 0.2837
# generate data, vgrams, shuffle.
# Epoch 261/1000
# 472/472 - 2s - loss: 0.1730 - root_mean_squared_error: 0.2854
# generate data, vgrams, shuffle.
# Epoch 262/1000
# 472/472 - 2s - loss: 0.1729 - root_mean_squared_error: 0.2856
# generate data, vgrams, shuffle.
# Epoch 263/1000
# 472/472 - 2s - loss: 0.1728 - root_mean_squared_error: 0.2855
# generate data, vgrams, shuffle.
# Epoch 264/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1709 - root_mean_squared_error: 0.2830
# generate data, vgrams, shuffle.
# Epoch 265/1000
# 472/472 - 2s - loss: 0.1718 - root_mean_squared_error: 0.2846
# generate data, vgrams, shuffle.
# Epoch 266/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1708 - root_mean_squared_error: 0.2831
# generate data, vgrams, shuffle.
# Epoch 267/1000
# 472/472 - 2s - loss: 0.1720 - root_mean_squared_error: 0.2847
# generate data, vgrams, shuffle.
# Epoch 268/1000
# 472/472 - 2s - loss: 0.1726 - root_mean_squared_error: 0.2848
# generate data, vgrams, shuffle.
# Epoch 269/1000
# 472/472 - 2s - loss: 0.1710 - root_mean_squared_error: 0.2838
# generate data, vgrams, shuffle.
# Epoch 270/1000
# 472/472 - 2s - loss: 0.1726 - root_mean_squared_error: 0.2850
# generate data, vgrams, shuffle.
# Epoch 271/1000
# 472/472 - 2s - loss: 0.1718 - root_mean_squared_error: 0.2846
# generate data, vgrams, shuffle.
# Epoch 272/1000
# 472/472 - 2s - loss: 0.1724 - root_mean_squared_error: 0.2854
# generate data, vgrams, shuffle.
# Epoch 273/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1706 - root_mean_squared_error: 0.2822
# generate data, vgrams, shuffle.
# Epoch 274/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1704 - root_mean_squared_error: 0.2819
# generate data, vgrams, shuffle.
# Epoch 275/1000
# 472/472 - 2s - loss: 0.1723 - root_mean_squared_error: 0.2842
# generate data, vgrams, shuffle.
# Epoch 276/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1695 - root_mean_squared_error: 0.2821
# generate data, vgrams, shuffle.
# Epoch 277/1000
# 472/472 - 2s - loss: 0.1728 - root_mean_squared_error: 0.2854
# generate data, vgrams, shuffle.
# Epoch 278/1000
# 472/472 - 2s - loss: 0.1713 - root_mean_squared_error: 0.2833
# generate data, vgrams, shuffle.
# Epoch 279/1000
# 472/472 - 2s - loss: 0.1709 - root_mean_squared_error: 0.2832
# generate data, vgrams, shuffle.
# Epoch 280/1000
# 472/472 - 2s - loss: 0.1726 - root_mean_squared_error: 0.2850
# generate data, vgrams, shuffle.
# Epoch 281/1000
# 472/472 - 2s - loss: 0.1699 - root_mean_squared_error: 0.2826
# generate data, vgrams, shuffle.
# Epoch 282/1000
# 472/472 - 2s - loss: 0.1701 - root_mean_squared_error: 0.2823
# generate data, vgrams, shuffle.
# Epoch 283/1000
# 472/472 - 2s - loss: 0.1714 - root_mean_squared_error: 0.2835
# generate data, vgrams, shuffle.
# Epoch 284/1000
# 472/472 - 2s - loss: 0.1707 - root_mean_squared_error: 0.2832
# generate data, vgrams, shuffle.
# Epoch 285/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1694 - root_mean_squared_error: 0.2813
# generate data, vgrams, shuffle.
# Epoch 286/1000
# 472/472 - 2s - loss: 0.1715 - root_mean_squared_error: 0.2842
# generate data, vgrams, shuffle.
# Epoch 287/1000
# 472/472 - 2s - loss: 0.1702 - root_mean_squared_error: 0.2818
# generate data, vgrams, shuffle.
# Epoch 288/1000
# 472/472 - 2s - loss: 0.1710 - root_mean_squared_error: 0.2842
# generate data, vgrams, shuffle.
# Epoch 289/1000
# 472/472 - 2s - loss: 0.1707 - root_mean_squared_error: 0.2829
# generate data, vgrams, shuffle.
# Epoch 290/1000
# 472/472 - 2s - loss: 0.1703 - root_mean_squared_error: 0.2834
# generate data, vgrams, shuffle.
# Epoch 291/1000
# 472/472 - 2s - loss: 0.1709 - root_mean_squared_error: 0.2838
# generate data, vgrams, shuffle.
# Epoch 292/1000
# 472/472 - 2s - loss: 0.1719 - root_mean_squared_error: 0.2838
# generate data, vgrams, shuffle.
# Epoch 293/1000
# 472/472 - 2s - loss: 0.1708 - root_mean_squared_error: 0.2833
# generate data, vgrams, shuffle.
# Epoch 294/1000
# 472/472 - 2s - loss: 0.1705 - root_mean_squared_error: 0.2832
# generate data, vgrams, shuffle.
# Epoch 295/1000
# 472/472 - 2s - loss: 0.1713 - root_mean_squared_error: 0.2832
# generate data, vgrams, shuffle.
# Epoch 296/1000
# 472/472 - 2s - loss: 0.1722 - root_mean_squared_error: 0.2845
# generate data, vgrams, shuffle.
# Epoch 297/1000
# 472/472 - 2s - loss: 0.1709 - root_mean_squared_error: 0.2834
# generate data, vgrams, shuffle.
# Epoch 298/1000
# 472/472 - 2s - loss: 0.1712 - root_mean_squared_error: 0.2840
# generate data, vgrams, shuffle.
# Epoch 299/1000
# 472/472 - 2s - loss: 0.1698 - root_mean_squared_error: 0.2819
# generate data, vgrams, shuffle.
# Epoch 300/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1693 - root_mean_squared_error: 0.2814
# generate data, vgrams, shuffle.
# Epoch 301/1000
# 472/472 - 2s - loss: 0.1698 - root_mean_squared_error: 0.2827
# generate data, vgrams, shuffle.
# Epoch 302/1000
# 472/472 - 2s - loss: 0.1726 - root_mean_squared_error: 0.2846
# generate data, vgrams, shuffle.
# Epoch 303/1000
# 472/472 - 2s - loss: 0.1716 - root_mean_squared_error: 0.2838
# generate data, vgrams, shuffle.
# Epoch 304/1000
# 472/472 - 2s - loss: 0.1704 - root_mean_squared_error: 0.2829
# generate data, vgrams, shuffle.
# Epoch 305/1000
# 472/472 - 2s - loss: 0.1697 - root_mean_squared_error: 0.2822
# generate data, vgrams, shuffle.
# Epoch 306/1000
# 472/472 - 2s - loss: 0.1706 - root_mean_squared_error: 0.2824
# generate data, vgrams, shuffle.
# Epoch 307/1000
# 472/472 - 2s - loss: 0.1709 - root_mean_squared_error: 0.2838
# generate data, vgrams, shuffle.
# Epoch 308/1000
# 472/472 - 2s - loss: 0.1708 - root_mean_squared_error: 0.2836
# generate data, vgrams, shuffle.
# Epoch 309/1000
# 472/472 - 2s - loss: 0.1710 - root_mean_squared_error: 0.2838
# generate data, vgrams, shuffle.
# Epoch 310/1000
# 472/472 - 2s - loss: 0.1712 - root_mean_squared_error: 0.2830
# generate data, vgrams, shuffle.
# Epoch 311/1000
# 472/472 - 2s - loss: 0.1709 - root_mean_squared_error: 0.2827
# generate data, vgrams, shuffle.
# Epoch 312/1000
# 472/472 - 2s - loss: 0.1697 - root_mean_squared_error: 0.2823
# generate data, vgrams, shuffle.
# Epoch 313/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1692 - root_mean_squared_error: 0.2814
# generate data, vgrams, shuffle.
# Epoch 314/1000
# 472/472 - 2s - loss: 0.1700 - root_mean_squared_error: 0.2816
# generate data, vgrams, shuffle.
# Epoch 315/1000
# 472/472 - 2s - loss: 0.1709 - root_mean_squared_error: 0.2842
# generate data, vgrams, shuffle.
# Epoch 316/1000
# 472/472 - 2s - loss: 0.1705 - root_mean_squared_error: 0.2836
# generate data, vgrams, shuffle.
# Epoch 317/1000
# 472/472 - 2s - loss: 0.1696 - root_mean_squared_error: 0.2815
# generate data, vgrams, shuffle.
# Epoch 318/1000
# 472/472 - 2s - loss: 0.1705 - root_mean_squared_error: 0.2825
# generate data, vgrams, shuffle.
# Epoch 319/1000
# 472/472 - 2s - loss: 0.1693 - root_mean_squared_error: 0.2819
# generate data, vgrams, shuffle.
# Epoch 320/1000
# 472/472 - 2s - loss: 0.1697 - root_mean_squared_error: 0.2822
# generate data, vgrams, shuffle.
# Epoch 321/1000
# 472/472 - 2s - loss: 0.1705 - root_mean_squared_error: 0.2825
# generate data, vgrams, shuffle.
# Epoch 322/1000
# 472/472 - 2s - loss: 0.1713 - root_mean_squared_error: 0.2840
# generate data, vgrams, shuffle.
# Epoch 323/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1688 - root_mean_squared_error: 0.2811
# generate data, vgrams, shuffle.
# Epoch 324/1000
# 472/472 - 2s - loss: 0.1705 - root_mean_squared_error: 0.2824
# generate data, vgrams, shuffle.
# Epoch 325/1000
# 472/472 - 2s - loss: 0.1703 - root_mean_squared_error: 0.2826
# generate data, vgrams, shuffle.
# Epoch 326/1000
# 472/472 - 2s - loss: 0.1700 - root_mean_squared_error: 0.2822
# generate data, vgrams, shuffle.
# Epoch 327/1000
# 472/472 - 2s - loss: 0.1692 - root_mean_squared_error: 0.2809
# generate data, vgrams, shuffle.
# Epoch 328/1000
# 472/472 - 2s - loss: 0.1693 - root_mean_squared_error: 0.2813
# generate data, vgrams, shuffle.
# Epoch 329/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1682 - root_mean_squared_error: 0.2795
# generate data, vgrams, shuffle.
# Epoch 330/1000
# 472/472 - 2s - loss: 0.1689 - root_mean_squared_error: 0.2807
# generate data, vgrams, shuffle.
# Epoch 331/1000
# 472/472 - 2s - loss: 0.1704 - root_mean_squared_error: 0.2821
# generate data, vgrams, shuffle.
# Epoch 332/1000
# 472/472 - 2s - loss: 0.1695 - root_mean_squared_error: 0.2815
# generate data, vgrams, shuffle.
# Epoch 333/1000
# 472/472 - 2s - loss: 0.1695 - root_mean_squared_error: 0.2814
# generate data, vgrams, shuffle.
# Epoch 334/1000
# 472/472 - 2s - loss: 0.1716 - root_mean_squared_error: 0.2838
# generate data, vgrams, shuffle.
# Epoch 335/1000
# 472/472 - 2s - loss: 0.1702 - root_mean_squared_error: 0.2828
# generate data, vgrams, shuffle.
# Epoch 336/1000
# 472/472 - 2s - loss: 0.1692 - root_mean_squared_error: 0.2812
# generate data, vgrams, shuffle.
# Epoch 337/1000
# 472/472 - 2s - loss: 0.1682 - root_mean_squared_error: 0.2799
# generate data, vgrams, shuffle.
# Epoch 338/1000
# 472/472 - 2s - loss: 0.1691 - root_mean_squared_error: 0.2803
# generate data, vgrams, shuffle.
# Epoch 339/1000
# 472/472 - 2s - loss: 0.1702 - root_mean_squared_error: 0.2819
# generate data, vgrams, shuffle.
# Epoch 340/1000
# 472/472 - 2s - loss: 0.1703 - root_mean_squared_error: 0.2829
# generate data, vgrams, shuffle.
# Epoch 341/1000
# 472/472 - 2s - loss: 0.1702 - root_mean_squared_error: 0.2824
# generate data, vgrams, shuffle.
# Epoch 342/1000
# 472/472 - 2s - loss: 0.1687 - root_mean_squared_error: 0.2805
# generate data, vgrams, shuffle.
# Epoch 343/1000
# 472/472 - 2s - loss: 0.1693 - root_mean_squared_error: 0.2816
# generate data, vgrams, shuffle.
# Epoch 344/1000
# 472/472 - 2s - loss: 0.1724 - root_mean_squared_error: 0.2849
# generate data, vgrams, shuffle.
# Epoch 345/1000
# 472/472 - 2s - loss: 0.1682 - root_mean_squared_error: 0.2799
# generate data, vgrams, shuffle.
# Epoch 346/1000
# 472/472 - 2s - loss: 0.1683 - root_mean_squared_error: 0.2803
# generate data, vgrams, shuffle.
# Epoch 347/1000
# 472/472 - 2s - loss: 0.1685 - root_mean_squared_error: 0.2807
# generate data, vgrams, shuffle.
# Epoch 348/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1679 - root_mean_squared_error: 0.2798
# generate data, vgrams, shuffle.
# Epoch 349/1000
# 472/472 - 2s - loss: 0.1706 - root_mean_squared_error: 0.2828
# generate data, vgrams, shuffle.
# Epoch 350/1000
# 472/472 - 2s - loss: 0.1695 - root_mean_squared_error: 0.2810
# generate data, vgrams, shuffle.
# Epoch 351/1000
# 472/472 - 2s - loss: 0.1694 - root_mean_squared_error: 0.2818
# generate data, vgrams, shuffle.
# Epoch 352/1000
# 472/472 - 2s - loss: 0.1686 - root_mean_squared_error: 0.2809
# generate data, vgrams, shuffle.
# Epoch 353/1000
# 472/472 - 2s - loss: 0.1706 - root_mean_squared_error: 0.2826
# generate data, vgrams, shuffle.
# Epoch 354/1000
# 472/472 - 2s - loss: 0.1685 - root_mean_squared_error: 0.2814
# generate data, vgrams, shuffle.
# Epoch 355/1000
# 472/472 - 2s - loss: 0.1700 - root_mean_squared_error: 0.2826
# generate data, vgrams, shuffle.
# Epoch 356/1000
# 472/472 - 2s - loss: 0.1710 - root_mean_squared_error: 0.2839
# generate data, vgrams, shuffle.
# Epoch 357/1000
# 472/472 - 2s - loss: 0.1691 - root_mean_squared_error: 0.2806
# generate data, vgrams, shuffle.
# Epoch 358/1000
# 472/472 - 2s - loss: 0.1690 - root_mean_squared_error: 0.2801
# generate data, vgrams, shuffle.
# Epoch 359/1000
# 472/472 - 2s - loss: 0.1693 - root_mean_squared_error: 0.2813
# generate data, vgrams, shuffle.
# Epoch 360/1000
# 472/472 - 2s - loss: 0.1688 - root_mean_squared_error: 0.2810
# generate data, vgrams, shuffle.
# Epoch 361/1000
# 472/472 - 2s - loss: 0.1690 - root_mean_squared_error: 0.2806
# generate data, vgrams, shuffle.
# Epoch 362/1000
# 472/472 - 2s - loss: 0.1682 - root_mean_squared_error: 0.2803
# generate data, vgrams, shuffle.
# Epoch 363/1000
# 472/472 - 2s - loss: 0.1699 - root_mean_squared_error: 0.2827
# generate data, vgrams, shuffle.
# Epoch 364/1000
# 472/472 - 2s - loss: 0.1683 - root_mean_squared_error: 0.2799
# generate data, vgrams, shuffle.
# Epoch 365/1000
# 472/472 - 2s - loss: 0.1687 - root_mean_squared_error: 0.2804
# generate data, vgrams, shuffle.
# Epoch 366/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1666 - root_mean_squared_error: 0.2782
# generate data, vgrams, shuffle.
# Epoch 367/1000
# 472/472 - 2s - loss: 0.1683 - root_mean_squared_error: 0.2807
# generate data, vgrams, shuffle.
# Epoch 368/1000
# 472/472 - 2s - loss: 0.1680 - root_mean_squared_error: 0.2803
# generate data, vgrams, shuffle.
# Epoch 369/1000
# 472/472 - 2s - loss: 0.1691 - root_mean_squared_error: 0.2813
# generate data, vgrams, shuffle.
# Epoch 370/1000
# 472/472 - 2s - loss: 0.1705 - root_mean_squared_error: 0.2816
# generate data, vgrams, shuffle.
# Epoch 371/1000
# 472/472 - 2s - loss: 0.1674 - root_mean_squared_error: 0.2796
# generate data, vgrams, shuffle.
# Epoch 372/1000
# 472/472 - 2s - loss: 0.1692 - root_mean_squared_error: 0.2811
# generate data, vgrams, shuffle.
# Epoch 373/1000
# 472/472 - 2s - loss: 0.1684 - root_mean_squared_error: 0.2812
# generate data, vgrams, shuffle.
# Epoch 374/1000
# 472/472 - 2s - loss: 0.1679 - root_mean_squared_error: 0.2801
# generate data, vgrams, shuffle.
# Epoch 375/1000
# 472/472 - 2s - loss: 0.1671 - root_mean_squared_error: 0.2784
# generate data, vgrams, shuffle.
# Epoch 376/1000
# 472/472 - 2s - loss: 0.1715 - root_mean_squared_error: 0.2845
# generate data, vgrams, shuffle.
# Epoch 377/1000
# 472/472 - 2s - loss: 0.1680 - root_mean_squared_error: 0.2796
# generate data, vgrams, shuffle.
# Epoch 378/1000
# 472/472 - 2s - loss: 0.1676 - root_mean_squared_error: 0.2792
# generate data, vgrams, shuffle.
# Epoch 379/1000
# 472/472 - 2s - loss: 0.1685 - root_mean_squared_error: 0.2793
# generate data, vgrams, shuffle.
# Epoch 380/1000
# 472/472 - 2s - loss: 0.1681 - root_mean_squared_error: 0.2804
# generate data, vgrams, shuffle.
# Epoch 381/1000
# 472/472 - 2s - loss: 0.1670 - root_mean_squared_error: 0.2787
# generate data, vgrams, shuffle.
# Epoch 382/1000
# 472/472 - 2s - loss: 0.1671 - root_mean_squared_error: 0.2789
# generate data, vgrams, shuffle.
# Epoch 383/1000
# 472/472 - 2s - loss: 0.1682 - root_mean_squared_error: 0.2799
# generate data, vgrams, shuffle.
# Epoch 384/1000
# 472/472 - 2s - loss: 0.1681 - root_mean_squared_error: 0.2803
# generate data, vgrams, shuffle.
# Epoch 385/1000
# 472/472 - 2s - loss: 0.1681 - root_mean_squared_error: 0.2792
# generate data, vgrams, shuffle.
# Epoch 386/1000
# 472/472 - 2s - loss: 0.1694 - root_mean_squared_error: 0.2819
# generate data, vgrams, shuffle.
# Epoch 387/1000
# 472/472 - 2s - loss: 0.1667 - root_mean_squared_error: 0.2780
# generate data, vgrams, shuffle.
# Epoch 388/1000
# 472/472 - 2s - loss: 0.1682 - root_mean_squared_error: 0.2803
# generate data, vgrams, shuffle.
# Epoch 389/1000
# 472/472 - 2s - loss: 0.1677 - root_mean_squared_error: 0.2791
# generate data, vgrams, shuffle.
# Epoch 390/1000
# 472/472 - 2s - loss: 0.1670 - root_mean_squared_error: 0.2781
# generate data, vgrams, shuffle.
# Epoch 391/1000
# 472/472 - 2s - loss: 0.1679 - root_mean_squared_error: 0.2805
# generate data, vgrams, shuffle.
# Epoch 392/1000
# 472/472 - 2s - loss: 0.1670 - root_mean_squared_error: 0.2790
# generate data, vgrams, shuffle.
# Epoch 393/1000
# ...
# generate data, vgrams, shuffle.
# Epoch 859/1000
# 472/472 - 2s - loss: 0.1617 - root_mean_squared_error: 0.2732
# generate data, vgrams, shuffle.
# Epoch 860/1000
# 472/472 - 2s - loss: 0.1608 - root_mean_squared_error: 0.2722
# generate data, vgrams, shuffle.
# Epoch 861/1000
# 472/472 - 2s - loss: 0.1612 - root_mean_squared_error: 0.2720
# generate data, vgrams, shuffle.
# Epoch 862/1000
# 472/472 - 2s - loss: 0.1617 - root_mean_squared_error: 0.2727
# generate data, vgrams, shuffle.
# Epoch 863/1000
# 472/472 - 2s - loss: 0.1620 - root_mean_squared_error: 0.2723
# generate data, vgrams, shuffle.
# Epoch 864/1000
# 472/472 - 2s - loss: 0.1609 - root_mean_squared_error: 0.2719
# generate data, vgrams, shuffle.
# Epoch 865/1000
# 472/472 - 2s - loss: 0.1624 - root_mean_squared_error: 0.2737
# generate data, vgrams, shuffle.
# Epoch 866/1000
# 472/472 - 2s - loss: 0.1612 - root_mean_squared_error: 0.2719
# generate data, vgrams, shuffle.
# Epoch 867/1000
# 472/472 - 2s - loss: 0.1614 - root_mean_squared_error: 0.2727
# generate data, vgrams, shuffle.
# Epoch 868/1000
# 472/472 - 2s - loss: 0.1620 - root_mean_squared_error: 0.2729
# generate data, vgrams, shuffle.
# Epoch 869/1000
# 472/472 - 2s - loss: 0.1615 - root_mean_squared_error: 0.2720
# generate data, vgrams, shuffle.
# Epoch 870/1000
# 472/472 - 2s - loss: 0.1616 - root_mean_squared_error: 0.2727
# generate data, vgrams, shuffle.
# Epoch 871/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1604 - root_mean_squared_error: 0.2715
# generate data, vgrams, shuffle.
# Epoch 872/1000
# 472/472 - 2s - loss: 0.1617 - root_mean_squared_error: 0.2728
# generate data, vgrams, shuffle.
# Epoch 873/1000
# 472/472 - 2s - loss: 0.1609 - root_mean_squared_error: 0.2720
# generate data, vgrams, shuffle.
# Epoch 874/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1602 - root_mean_squared_error: 0.2704
# generate data, vgrams, shuffle.
# Epoch 875/1000
# 472/472 - 2s - loss: 0.1622 - root_mean_squared_error: 0.2742
# generate data, vgrams, shuffle.
# Epoch 876/1000
# 472/472 - 2s - loss: 0.1604 - root_mean_squared_error: 0.2709
# generate data, vgrams, shuffle.
# Epoch 877/1000
# 472/472 - 2s - loss: 0.1612 - root_mean_squared_error: 0.2725
# generate data, vgrams, shuffle.
# Epoch 878/1000
# 472/472 - 2s - loss: 0.1610 - root_mean_squared_error: 0.2712
# generate data, vgrams, shuffle.
# Epoch 879/1000
# 472/472 - 2s - loss: 0.1611 - root_mean_squared_error: 0.2718
# generate data, vgrams, shuffle.
# Epoch 880/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1599 - root_mean_squared_error: 0.2706
# generate data, vgrams, shuffle.
# Epoch 881/1000
# 472/472 - 2s - loss: 0.1615 - root_mean_squared_error: 0.2733
# generate data, vgrams, shuffle.
# Epoch 882/1000
# 472/472 - 2s - loss: 0.1602 - root_mean_squared_error: 0.2708
# generate data, vgrams, shuffle.
# Epoch 883/1000
# 472/472 - 2s - loss: 0.1625 - root_mean_squared_error: 0.2738
# generate data, vgrams, shuffle.
# Epoch 884/1000
# 472/472 - 2s - loss: 0.1605 - root_mean_squared_error: 0.2717
# generate data, vgrams, shuffle.
# Epoch 885/1000
# 472/472 - 2s - loss: 0.1608 - root_mean_squared_error: 0.2718
# generate data, vgrams, shuffle.
# Epoch 886/1000
# 472/472 - 2s - loss: 0.1607 - root_mean_squared_error: 0.2711
# generate data, vgrams, shuffle.
# Epoch 887/1000
# 472/472 - 2s - loss: 0.1602 - root_mean_squared_error: 0.2716
# generate data, vgrams, shuffle.
# Epoch 888/1000
# 472/472 - 2s - loss: 0.1613 - root_mean_squared_error: 0.2724
# generate data, vgrams, shuffle.
# Epoch 889/1000
# 472/472 - 2s - loss: 0.1611 - root_mean_squared_error: 0.2723
# generate data, vgrams, shuffle.
# Epoch 890/1000
# 472/472 - 2s - loss: 0.1603 - root_mean_squared_error: 0.2716
# generate data, vgrams, shuffle.
# Epoch 891/1000
# 472/472 - 2s - loss: 0.1611 - root_mean_squared_error: 0.2714
# generate data, vgrams, shuffle.
# Epoch 892/1000
# 472/472 - 2s - loss: 0.1609 - root_mean_squared_error: 0.2722
# generate data, vgrams, shuffle.
# Epoch 893/1000
# 472/472 - 2s - loss: 0.1604 - root_mean_squared_error: 0.2703
# generate data, vgrams, shuffle.
# Epoch 894/1000
# 472/472 - 2s - loss: 0.1622 - root_mean_squared_error: 0.2734
# generate data, vgrams, shuffle.
# Epoch 895/1000
# 472/472 - 2s - loss: 0.1620 - root_mean_squared_error: 0.2733
# generate data, vgrams, shuffle.
# Epoch 896/1000
# 472/472 - 2s - loss: 0.1610 - root_mean_squared_error: 0.2714
# generate data, vgrams, shuffle.
# Epoch 897/1000
# 472/472 - 2s - loss: 0.1612 - root_mean_squared_error: 0.2720
# generate data, vgrams, shuffle.
# Epoch 898/1000
# 472/472 - 2s - loss: 0.1601 - root_mean_squared_error: 0.2716
# generate data, vgrams, shuffle.
# Epoch 899/1000
# 472/472 - 2s - loss: 0.1628 - root_mean_squared_error: 0.2746
# generate data, vgrams, shuffle.
# Epoch 900/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1593 - root_mean_squared_error: 0.2705
# generate data, vgrams, shuffle.
# Epoch 901/1000
# 472/472 - 2s - loss: 0.1615 - root_mean_squared_error: 0.2731
# generate data, vgrams, shuffle.
# Epoch 902/1000
# 472/472 - 2s - loss: 0.1609 - root_mean_squared_error: 0.2726
# generate data, vgrams, shuffle.
# Epoch 903/1000
# 472/472 - 2s - loss: 0.1604 - root_mean_squared_error: 0.2712
# generate data, vgrams, shuffle.
# Epoch 904/1000
# 472/472 - 2s - loss: 0.1614 - root_mean_squared_error: 0.2727
# generate data, vgrams, shuffle.
# Epoch 905/1000
# 472/472 - 2s - loss: 0.1622 - root_mean_squared_error: 0.2741
# generate data, vgrams, shuffle.
# Epoch 906/1000
# 472/472 - 2s - loss: 0.1613 - root_mean_squared_error: 0.2719
# generate data, vgrams, shuffle.
# Epoch 907/1000
# 472/472 - 2s - loss: 0.1608 - root_mean_squared_error: 0.2721
# generate data, vgrams, shuffle.
# Epoch 908/1000
# 472/472 - 2s - loss: 0.1601 - root_mean_squared_error: 0.2707
# generate data, vgrams, shuffle.
# Epoch 909/1000
# 472/472 - 2s - loss: 0.1609 - root_mean_squared_error: 0.2720
# generate data, vgrams, shuffle.
# Epoch 910/1000
# 472/472 - 2s - loss: 0.1610 - root_mean_squared_error: 0.2729
# generate data, vgrams, shuffle.
# Epoch 911/1000
# 472/472 - 2s - loss: 0.1620 - root_mean_squared_error: 0.2731
# generate data, vgrams, shuffle.
# Epoch 912/1000
# 472/472 - 2s - loss: 0.1618 - root_mean_squared_error: 0.2726
# generate data, vgrams, shuffle.
# Epoch 913/1000
# 472/472 - 2s - loss: 0.1609 - root_mean_squared_error: 0.2714
# generate data, vgrams, shuffle.
# Epoch 914/1000
# 472/472 - 2s - loss: 0.1614 - root_mean_squared_error: 0.2719
# generate data, vgrams, shuffle.
# Epoch 915/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1592 - root_mean_squared_error: 0.2700
# generate data, vgrams, shuffle.
# Epoch 916/1000
# 472/472 - 2s - loss: 0.1609 - root_mean_squared_error: 0.2714
# generate data, vgrams, shuffle.
# Epoch 917/1000
# 472/472 - 2s - loss: 0.1622 - root_mean_squared_error: 0.2739
# generate data, vgrams, shuffle.
# Epoch 918/1000
# 472/472 - 2s - loss: 0.1621 - root_mean_squared_error: 0.2742
# generate data, vgrams, shuffle.
# Epoch 919/1000
# 472/472 - 2s - loss: 0.1612 - root_mean_squared_error: 0.2733
# generate data, vgrams, shuffle.
# Epoch 920/1000
# 472/472 - 2s - loss: 0.1598 - root_mean_squared_error: 0.2707
# generate data, vgrams, shuffle.
# Epoch 921/1000
# 472/472 - 2s - loss: 0.1620 - root_mean_squared_error: 0.2730
# generate data, vgrams, shuffle.
# Epoch 922/1000
# 472/472 - 2s - loss: 0.1605 - root_mean_squared_error: 0.2714
# generate data, vgrams, shuffle.
# Epoch 923/1000
# 472/472 - 2s - loss: 0.1599 - root_mean_squared_error: 0.2708
# generate data, vgrams, shuffle.
# Epoch 924/1000
# 472/472 - 2s - loss: 0.1606 - root_mean_squared_error: 0.2720
# generate data, vgrams, shuffle.
# Epoch 925/1000
# 472/472 - 2s - loss: 0.1612 - root_mean_squared_error: 0.2721
# generate data, vgrams, shuffle.
# Epoch 926/1000
# 472/472 - 2s - loss: 0.1606 - root_mean_squared_error: 0.2709
# generate data, vgrams, shuffle.
# Epoch 927/1000
# 472/472 - 2s - loss: 0.1605 - root_mean_squared_error: 0.2713
# generate data, vgrams, shuffle.
# Epoch 928/1000
# 472/472 - 2s - loss: 0.1615 - root_mean_squared_error: 0.2724
# generate data, vgrams, shuffle.
# Epoch 929/1000
# 472/472 - 2s - loss: 0.1608 - root_mean_squared_error: 0.2711
# generate data, vgrams, shuffle.
# Epoch 930/1000
# 472/472 - 2s - loss: 0.1607 - root_mean_squared_error: 0.2712
# generate data, vgrams, shuffle.
# Epoch 931/1000
# 472/472 - 2s - loss: 0.1595 - root_mean_squared_error: 0.2697
# generate data, vgrams, shuffle.
# Epoch 932/1000
# 472/472 - 2s - loss: 0.1608 - root_mean_squared_error: 0.2711
# generate data, vgrams, shuffle.
# Epoch 933/1000
# 472/472 - 2s - loss: 0.1595 - root_mean_squared_error: 0.2696
# generate data, vgrams, shuffle.
# Epoch 934/1000
# 472/472 - 2s - loss: 0.1611 - root_mean_squared_error: 0.2721
# generate data, vgrams, shuffle.
# Epoch 935/1000
# 472/472 - 2s - loss: 0.1595 - root_mean_squared_error: 0.2701
# generate data, vgrams, shuffle.
# Epoch 936/1000
# 472/472 - 2s - loss: 0.1604 - root_mean_squared_error: 0.2720
# generate data, vgrams, shuffle.
# Epoch 937/1000
# 472/472 - 2s - loss: 0.1613 - root_mean_squared_error: 0.2721
# generate data, vgrams, shuffle.
# Epoch 938/1000
# 472/472 - 2s - loss: 0.1596 - root_mean_squared_error: 0.2699
# generate data, vgrams, shuffle.
# Epoch 939/1000
# 472/472 - 2s - loss: 0.1616 - root_mean_squared_error: 0.2722
# generate data, vgrams, shuffle.
# Epoch 940/1000
# 472/472 - 2s - loss: 0.1604 - root_mean_squared_error: 0.2714
# generate data, vgrams, shuffle.
# Epoch 941/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1588 - root_mean_squared_error: 0.2685
# generate data, vgrams, shuffle.
# Epoch 942/1000
# 472/472 - 2s - loss: 0.1593 - root_mean_squared_error: 0.2699
# generate data, vgrams, shuffle.
# Epoch 943/1000
# 472/472 - 2s - loss: 0.1608 - root_mean_squared_error: 0.2709
# generate data, vgrams, shuffle.
# Epoch 944/1000
# 472/472 - 2s - loss: 0.1611 - root_mean_squared_error: 0.2724
# generate data, vgrams, shuffle.
# Epoch 945/1000
# 472/472 - 2s - loss: 0.1601 - root_mean_squared_error: 0.2705
# generate data, vgrams, shuffle.
# Epoch 946/1000
# 472/472 - 2s - loss: 0.1622 - root_mean_squared_error: 0.2734
# generate data, vgrams, shuffle.
# Epoch 947/1000
# 472/472 - 2s - loss: 0.1609 - root_mean_squared_error: 0.2718
# generate data, vgrams, shuffle.
# Epoch 948/1000
# 472/472 - 2s - loss: 0.1620 - root_mean_squared_error: 0.2726
# generate data, vgrams, shuffle.
# Epoch 949/1000
# 472/472 - 2s - loss: 0.1609 - root_mean_squared_error: 0.2717
# generate data, vgrams, shuffle.
# Epoch 950/1000
# 472/472 - 2s - loss: 0.1602 - root_mean_squared_error: 0.2709
# generate data, vgrams, shuffle.
# Epoch 951/1000
# 472/472 - 2s - loss: 0.1602 - root_mean_squared_error: 0.2714
# generate data, vgrams, shuffle.
# Epoch 952/1000
# 472/472 - 2s - loss: 0.1599 - root_mean_squared_error: 0.2710
# generate data, vgrams, shuffle.
# Epoch 953/1000
# 472/472 - 2s - loss: 0.1608 - root_mean_squared_error: 0.2713
# generate data, vgrams, shuffle.
# Epoch 954/1000
# 472/472 - 2s - loss: 0.1614 - root_mean_squared_error: 0.2725
# generate data, vgrams, shuffle.
# Epoch 955/1000
# 472/472 - 2s - loss: 0.1592 - root_mean_squared_error: 0.2691
# generate data, vgrams, shuffle.
# Epoch 956/1000
# 472/472 - 2s - loss: 0.1606 - root_mean_squared_error: 0.2713
# generate data, vgrams, shuffle.
# Epoch 957/1000
# 472/472 - 2s - loss: 0.1619 - root_mean_squared_error: 0.2727
# generate data, vgrams, shuffle.
# Epoch 958/1000
# 472/472 - 2s - loss: 0.1608 - root_mean_squared_error: 0.2718
# generate data, vgrams, shuffle.
# Epoch 959/1000
# 472/472 - 2s - loss: 0.1602 - root_mean_squared_error: 0.2710
# generate data, vgrams, shuffle.
# Epoch 960/1000
# 472/472 - 2s - loss: 0.1597 - root_mean_squared_error: 0.2698
# generate data, vgrams, shuffle.
# Epoch 961/1000
# 472/472 - 2s - loss: 0.1599 - root_mean_squared_error: 0.2708
# generate data, vgrams, shuffle.
# Epoch 962/1000
# 472/472 - 2s - loss: 0.1595 - root_mean_squared_error: 0.2707
# generate data, vgrams, shuffle.
# Epoch 963/1000
# INFO:tensorflow:Assets written to: model_NV/assets
# 472/472 - 2s - loss: 0.1587 - root_mean_squared_error: 0.2690
# generate data, vgrams, shuffle.
# Epoch 964/1000
# 472/472 - 2s - loss: 0.1600 - root_mean_squared_error: 0.2715
# generate data, vgrams, shuffle.
# Epoch 965/1000
# 472/472 - 2s - loss: 0.1596 - root_mean_squared_error: 0.2705
# generate data, vgrams, shuffle.
# Epoch 966/1000
# 472/472 - 2s - loss: 0.1594 - root_mean_squared_error: 0.2691
# generate data, vgrams, shuffle.
# Epoch 967/1000
# 472/472 - 2s - loss: 0.1618 - root_mean_squared_error: 0.2720
# generate data, vgrams, shuffle.
# Epoch 968/1000
# 472/472 - 2s - loss: 0.1605 - root_mean_squared_error: 0.2717
# generate data, vgrams, shuffle.
# Epoch 969/1000
# 472/472 - 2s - loss: 0.1609 - root_mean_squared_error: 0.2710
# generate data, vgrams, shuffle.
# Epoch 970/1000
# 472/472 - 2s - loss: 0.1609 - root_mean_squared_error: 0.2723
# generate data, vgrams, shuffle.
# Epoch 971/1000
# 472/472 - 2s - loss: 0.1598 - root_mean_squared_error: 0.2699
# generate data, vgrams, shuffle.
# Epoch 972/1000
# 472/472 - 2s - loss: 0.1605 - root_mean_squared_error: 0.2717
# generate data, vgrams, shuffle.
# Epoch 973/1000
# 472/472 - 2s - loss: 0.1591 - root_mean_squared_error: 0.2698
# generate data, vgrams, shuffle.
# Epoch 974/1000
# 472/472 - 2s - loss: 0.1605 - root_mean_squared_error: 0.2714
# generate data, vgrams, shuffle.
# Epoch 975/1000
# 472/472 - 2s - loss: 0.1618 - root_mean_squared_error: 0.2729
# generate data, vgrams, shuffle.
# Epoch 976/1000
# 472/472 - 2s - loss: 0.1601 - root_mean_squared_error: 0.2708
# generate data, vgrams, shuffle.
# Epoch 977/1000
# 472/472 - 2s - loss: 0.1622 - root_mean_squared_error: 0.2737
# generate data, vgrams, shuffle.
# Epoch 978/1000
# 472/472 - 2s - loss: 0.1607 - root_mean_squared_error: 0.2713
# generate data, vgrams, shuffle.
# Epoch 979/1000
# 472/472 - 2s - loss: 0.1619 - root_mean_squared_error: 0.2725
# generate data, vgrams, shuffle.
# Epoch 980/1000
# 472/472 - 2s - loss: 0.1608 - root_mean_squared_error: 0.2717
# generate data, vgrams, shuffle.
# Epoch 981/1000
# 472/472 - 2s - loss: 0.1598 - root_mean_squared_error: 0.2703
# generate data, vgrams, shuffle.
# Epoch 982/1000
# 472/472 - 2s - loss: 0.1614 - root_mean_squared_error: 0.2720
# generate data, vgrams, shuffle.
# Epoch 983/1000
# 472/472 - 2s - loss: 0.1605 - root_mean_squared_error: 0.2716
# generate data, vgrams, shuffle.
# Epoch 984/1000
# 472/472 - 2s - loss: 0.1611 - root_mean_squared_error: 0.2718
# generate data, vgrams, shuffle.
# Epoch 985/1000
# 472/472 - 2s - loss: 0.1605 - root_mean_squared_error: 0.2708
# generate data, vgrams, shuffle.
# Epoch 986/1000
# 472/472 - 2s - loss: 0.1619 - root_mean_squared_error: 0.2738
# generate data, vgrams, shuffle.
# Epoch 987/1000
# 472/472 - 2s - loss: 0.1593 - root_mean_squared_error: 0.2701
# generate data, vgrams, shuffle.
# Epoch 988/1000
# 472/472 - 2s - loss: 0.1597 - root_mean_squared_error: 0.2706
# generate data, vgrams, shuffle.
# Epoch 989/1000
# 472/472 - 2s - loss: 0.1612 - root_mean_squared_error: 0.2715
# generate data, vgrams, shuffle.
# Epoch 990/1000
# 472/472 - 2s - loss: 0.1597 - root_mean_squared_error: 0.2699
# generate data, vgrams, shuffle.
# Epoch 991/1000
# 472/472 - 2s - loss: 0.1604 - root_mean_squared_error: 0.2708
# generate data, vgrams, shuffle.
# Epoch 992/1000
# 472/472 - 2s - loss: 0.1604 - root_mean_squared_error: 0.2711
# generate data, vgrams, shuffle.
# Epoch 993/1000
# 472/472 - 2s - loss: 0.1599 - root_mean_squared_error: 0.2704
# generate data, vgrams, shuffle.
# Epoch 994/1000
# 472/472 - 2s - loss: 0.1609 - root_mean_squared_error: 0.2719
# generate data, vgrams, shuffle.
# Epoch 995/1000
# 472/472 - 2s - loss: 0.1602 - root_mean_squared_error: 0.2709
# generate data, vgrams, shuffle.
# Epoch 996/1000
# 472/472 - 2s - loss: 0.1605 - root_mean_squared_error: 0.2713
# generate data, vgrams, shuffle.
# Epoch 997/1000
# 472/472 - 2s - loss: 0.1610 - root_mean_squared_error: 0.2717
# generate data, vgrams, shuffle.
# Epoch 998/1000
# 472/472 - 2s - loss: 0.1604 - root_mean_squared_error: 0.2711
# generate data, vgrams, shuffle.
# Epoch 999/1000
# 472/472 - 2s - loss: 0.1601 - root_mean_squared_error: 0.2716
# generate data, vgrams, shuffle.
# Epoch 1000/1000
# 472/472 - 2s - loss: 0.1616 - root_mean_squared_error: 0.2726
# generate data, vgrams, shuffle.
# CPU times: user 38min 33s, sys: 10min 49s, total: 49min 22s
# Wall time: 40min 46s

# %%
print(history1.history.keys())
fig = plt.figure(figsize=(10,3))
fig.subplots_adjust(hspace=100, wspace=1)
ax1 = fig.add_subplot(1, 2, 1)      
ax1.grid()
# ax1.set_ylim([.15,.2])
ax1.plot(history1.history['loss'])
ax1.set_ylabel('mae')
ax1.set_xlabel('epoch')
ax2 = fig.add_subplot(1, 2, 2)      
# ax2.set_ylim([.25,.4])
ax2.grid()
ax2.plot(history1.history['root_mean_squared_error'])
ax2.set_ylabel('root mean squared error')
ax2.set_xlabel('epoch')
plt.show()
# Out:
# dict_keys(['loss', 'root_mean_squared_error'])

# %% [markdown]
# ## Apply the model to the test data from the simulation study

# %%
# !wget -P npy/ https://www.dropbox.com/s/5kba6a2g777zshr/test_x.npy?dl=1
# !wget -P npy/ https://www.dropbox.com/s/23goi9qyx0qpbqe/test_y.npy?dl=1
test_x = np.load('npy/test_x.npy?dl=1')
test_y = np.load('npy/test_y.npy?dl=1')
# Out:
# --2020-11-11 22:20:51--  https://www.dropbox.com/s/5kba6a2g777zshr/test_x.npy?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/5kba6a2g777zshr/test_x.npy [following]
# --2020-11-11 22:20:52--  https://www.dropbox.com/s/dl/5kba6a2g777zshr/test_x.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8690babcbb2b9871769910e91b.dl.dropboxusercontent.com/cd/0/get/BDCUkemvgJO_qHxqNKrz5c1M9u4rPtBqKZr5N8amk_QYjCrSExtf6Eivw9jEFbCMgUhBhoGqXM96hP0uhOSBn-jK6D99jkw0Bjdil_KiRpw4gWQSGDQn42cbqLHBScF-Pco/file?dl=1# [following]
# --2020-11-11 22:20:52--  https://uc8690babcbb2b9871769910e91b.dl.dropboxusercontent.com/cd/0/get/BDCUkemvgJO_qHxqNKrz5c1M9u4rPtBqKZr5N8amk_QYjCrSExtf6Eivw9jEFbCMgUhBhoGqXM96hP0uhOSBn-jK6D99jkw0Bjdil_KiRpw4gWQSGDQn42cbqLHBScF-Pco/file?dl=1
# Resolving uc8690babcbb2b9871769910e91b.dl.dropboxusercontent.com (uc8690babcbb2b9871769910e91b.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc8690babcbb2b9871769910e91b.dl.dropboxusercontent.com (uc8690babcbb2b9871769910e91b.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 614400128 (586M) [application/binary]
# Saving to: ‘npy/test_x.npy?dl=1’
#
# test_x.npy?dl=1     100%[===================>] 585.94M  44.6MB/s    in 14s
#
# 2020-11-11 22:21:07 (41.5 MB/s) - ‘npy/test_x.npy?dl=1’ saved [614400128/614400128]
#
# --2020-11-11 22:21:07--  https://www.dropbox.com/s/23goi9qyx0qpbqe/test_y.npy?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/23goi9qyx0qpbqe/test_y.npy [following]
# --2020-11-11 22:21:07--  https://www.dropbox.com/s/dl/23goi9qyx0qpbqe/test_y.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc685810be28237184994e11775f.dl.dropboxusercontent.com/cd/0/get/BDA4i7E4aG5n5Mkb7T7HUctMWcKW82ZG4CE35Vw_KLlbQlYiOnUct98LUodXadPtZt4X8rwCDXLue3I9opYnfkyPLq9AGUh4gLDlF7waxW1yJf4YBO_atTIBgqqow_zBsmg/file?dl=1# [following]
# --2020-11-11 22:21:08--  https://uc685810be28237184994e11775f.dl.dropboxusercontent.com/cd/0/get/BDA4i7E4aG5n5Mkb7T7HUctMWcKW82ZG4CE35Vw_KLlbQlYiOnUct98LUodXadPtZt4X8rwCDXLue3I9opYnfkyPLq9AGUh4gLDlF7waxW1yJf4YBO_atTIBgqqow_zBsmg/file?dl=1
# Resolving uc685810be28237184994e11775f.dl.dropboxusercontent.com (uc685810be28237184994e11775f.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc685810be28237184994e11775f.dl.dropboxusercontent.com (uc685810be28237184994e11775f.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 160128 (156K) [application/binary]
# Saving to: ‘npy/test_y.npy?dl=1’
#
# test_y.npy?dl=1     100%[===================>] 156.38K   860KB/s    in 0.2s
#
# 2020-11-11 22:21:09 (860 KB/s) - ‘npy/test_y.npy?dl=1’ saved [160128/160128]

# %%
## scale test_y with same transformation as used in the generator
test_y_scaled = generator.scaler_y.transform(test_y)
print('test_y ---------> max: ', test_y.max(axis=0), ' mean: ', test_y.mean(axis=0), ', std: ', test_y.std(axis=0))
print('test_y_scaled --> max: ', test_y_scaled.max(axis=0), ' mean: ', test_y_scaled.mean(axis=0), ', std: ', test_y_scaled.std(axis=0))
# Out:
# test_y ---------> max:  [ 0.55448721 25.        ]  mean:  [-5.17562131 13.5       ] , std:  [1.81964502 6.80764402]
# test_y_scaled --> max:  [ 2.07693846 -0.00692133]  mean:  [ 0.2549513  -0.80287471] , std:  [0.57858762 0.47117976]

# %%
test_x = tf.convert_to_tensor(test_x, dtype=tf.float32)
vg_pred = np.zeros([test_x.shape[0], test_x.shape[3], 2])

# %%
for i in range(test_x.shape[3]):
  print('.', end='')
  test_x_vg, test_x_dist, test_x_w = generator.vgram(im=tf.expand_dims(test_x[:,:,:,i], 3), verbose=False)
  # print(model1.evaluate(x=test_x_vg, y=test_y_scaled, verbose=0))
  pred = model1.predict(x=test_x_vg)
  vg_pred[:,i,:] = generator.scaler_y.inverse_transform(pred)
# Out:
# ..............................

# %%
print(generator.scaler_y.inverse_transform(pred)[0:4,:])
print(vg_pred[0:4,15,:])
# Out:
# [[ 3.0102842e-02  1.8866497e+00]
#  [ 2.5889170e-01  2.9809127e+00]
#  [-1.6491783e-01  1.4679161e+00]
#  [-2.0922490e-03  1.3743740e+00]]
# [[ 0.63741362  1.25930941]
#  [ 1.13177407  2.43631124]
#  [ 0.83575165  2.73632383]
#  [-0.35240448  1.51382029]]

# %%
np.save(file='npy/test_pred_model_NV.npy', arr=vg_pred)

# %%
def rand_jitter(arr):
    stdev = .02*(max(arr)-min(arr))
    return arr + np.random.randn(len(arr)) * stdev
def abline(ax, slope=1, intercept=0):
    """Plot a line from slope and intercept"""
    x_vals = np.array(ax.get_xlim())
    y_vals = intercept + slope * x_vals
    ax.plot(x_vals, y_vals, '--', c='r')
fig = plt.figure()
fig.subplots_adjust(hspace=100, wspace=1)
fig.set_size_inches(18.5, 10.5)
for i in range(2):
           ax = fig.add_subplot(1, 4, i+1)
           ax.grid()
           ax.scatter(rand_jitter(test_y[:,i]), vg_pred[:,0,i], s=1, alpha=.2)
           ax.set_aspect('equal', 'box')
           abline(ax)

# %% [markdown]
# # Save model and predictions to google drive

# %%
! tar -zcvf model_NV.tar.gz model_NV
files.download('model_NV.tar.gz')
files.download('npy/test_pred_model_NV.npy')
pickle.dump(generator.scaler_y, open(file='npy/scaler_y_model_NV.pkl', mode='wb'))
files.download('npy/scaler_y_model_NV.pkl')
# Out:
# model_NV/
# model_NV/assets/
# model_NV/saved_model.pb
# model_NV/variables/
# model_NV/variables/variables.data-00000-of-00001
# model_NV/variables/variables.index
